# %%
import os
import sys
from pathlib import Path
import logging
import numpy as np
from transformers import AutoTokenizer
from tqdm.notebook import tqdm

# %%
notebook_dir = Path.cwd()
project_root = notebook_dir.parent  # If notebooks are in langechain/notebooks

# Add project root to Python path for imports
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

print(f"Project root: {project_root}")
# Out:
# Project root: /app

# %%
from src.data_pipline.json_loader.json_loader_epo import EPOPatentLoader
from config.json_loader_config import PatentLoaderConfig
from src.embeddings.text_Chunker import TextChunker, ChunkerConfig

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
from langchain.schema import Document

# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')
logger = logging.getLogger("patent_pipeline")

# %%
data_dir = Path(project_root) / "data" / "parsed" / "EPO"
model_name = "sentence-transformers/all-mpnet-base-v2"
vector_db_dir = Path(project_root) / "data" / "vector_db"
vector_db_dir.mkdir(parents=True, exist_ok=True)

# %%
loader_config = PatentLoaderConfig(
    max_files=200,
    
    verbose=False,
    epo_dir=data_dir,
    include_abstract=True,
    include_claims=True,
    include_description=True
)
patent_loader = EPOPatentLoader(config=loader_config)
print("✅ Patent loader initialized")
# Out:
# ✅ Patent loader initialized

# %%
json_files = patent_loader.load_raw_json_files()
# Out:
# 2025-06-19 22:34:34,057 - src.data_pipline.json_loader.json_loader_patent - INFO - Limited to 200 files out of 200 total files
# 2025-06-19 22:34:34,057 - src.data_pipline.json_loader.json_loader_patent - INFO - Limited to 200 files out of 200 total files
# 2025-06-19 22:34:34,058 - src.data_pipline.json_loader.json_loader_patent - INFO - Found 200 JSON files in /app/data/parsed/EPO
# 2025-06-19 22:34:34,058 - src.data_pipline.json_loader.json_loader_patent - INFO - Found 200 JSON files in /app/data/parsed/EPO
# 2025-06-19 22:34:34,098 - src.data_pipline.json_loader.json_loader_patent - INFO - Successfully loaded 200 raw JSON files
# 2025-06-19 22:34:34,098 - src.data_pipline.json_loader.json_loader_patent - INFO - Successfully loaded 200 raw JSON files

# %%
documents  = patent_loader.extract_document_components()
# Out:
# 2025-06-19 22:34:35,034 - src.data_pipline.json_loader.json_loader_patent - INFO - Limited to 200 files out of 200 total files
# 2025-06-19 22:34:35,034 - src.data_pipline.json_loader.json_loader_patent - INFO - Limited to 200 files out of 200 total files
# 2025-06-19 22:34:35,035 - src.data_pipline.json_loader.json_loader_patent - INFO - Found 200 JSON files in /app/data/parsed/EPO
# 2025-06-19 22:34:35,035 - src.data_pipline.json_loader.json_loader_patent - INFO - Found 200 JSON files in /app/data/parsed/EPO
# 2025-06-19 22:34:35,169 - src.data_pipline.json_loader.json_loader_patent - INFO - Successfully loaded 199 documents from 200 files
# 2025-06-19 22:34:35,169 - src.data_pipline.json_loader.json_loader_patent - INFO - Successfully loaded 199 documents from 200 files

# %%
json_files = []

# %%
print(f"✅ Loaded {len(documents)} document segments from {len(json_files)} patent files")
# Out:
# ✅ Loaded 199 document segments from 0 patent files

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
chunker_config = ChunkerConfig(
    base_chunk_size=300,  # Adjust based on your needs
    chunk_overlap=30,
    min_chunk_size=100
)
chunker = TextChunker(tokenizer, config=chunker_config)
print("✅ TextChunker initialized")
# Out:
# ✅ TextChunker initialized

# %%
print("✂️ Chunking documents...")
chunked_docs = []

for docs in tqdm(documents, desc="Chunking"):
    for doc in tqdm(docs, desc="Chunking"):
        try:
            text = doc.page_content
            metadata = doc.metadata
            
            # Use your TextChunker to split the document
            chunks = chunker.chunk_text(text, use_semantic=True)
            
            # Create LangChain Document objects from chunks
            for i, chunk_text in enumerate(chunks):
                # Copy metadata and add chunk information
                chunk_metadata = metadata.copy()
                chunk_metadata.update({
                    "chunk_index": i,
                    "total_chunks": len(chunks)
                })
                
                chunked_docs.append(Document(
                    page_content=chunk_text,
                    metadata=chunk_metadata
                ))
        except Exception as e:
            logger.error(f"Error chunking document: {str(e)}")
# Out:
# ✂️ Chunking documents...
# Chunking:   0%|          | 0/199 [00:00<?, ?it/s]
# Chunking:   0%|          | 0/180 [00:00<?, ?it/s]
# 2025-06-19 22:34:42,333 - src.embeddings.text_Chunker - INFO - Input text has 5 tokens
# 2025-06-19 22:34:42,334 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,335 - src.embeddings.text_Chunker - INFO - Input text has 33 tokens
# 2025-06-19 22:34:42,336 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,336 - src.embeddings.text_Chunker - INFO - Input text has 33 tokens
# 2025-06-19 22:34:42,339 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,340 - src.embeddings.text_Chunker - INFO - Input text has 116 tokens
# 2025-06-19 22:34:42,341 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,342 - src.embeddings.text_Chunker - INFO - Input text has 37 tokens
# 2025-06-19 22:34:42,342 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,343 - src.embeddings.text_Chunker - INFO - Input text has 88 tokens
# 2025-06-19 22:34:42,344 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,345 - src.embeddings.text_Chunker - INFO - Input text has 30 tokens
# 2025-06-19 22:34:42,345 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,346 - src.embeddings.text_Chunker - INFO - Input text has 30 tokens
# 2025-06-19 22:34:42,346 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,347 - src.embeddings.text_Chunker - INFO - Input text has 74 tokens
# 2025-06-19 22:34:42,347 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,348 - src.embeddings.text_Chunker - INFO - Input text has 25 tokens
# 2025-06-19 22:34:42,349 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,349 - src.embeddings.text_Chunker - INFO - Input text has 40 tokens
# 2025-06-19 22:34:42,349 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,350 - src.embeddings.text_Chunker - INFO - Input text has 53 tokens
# 2025-06-19 22:34:42,351 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,351 - src.embeddings.text_Chunker - INFO - Input text has 47 tokens
# 2025-06-19 22:34:42,352 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,352 - src.embeddings.text_Chunker - INFO - Input text has 18 tokens
# 2025-06-19 22:34:42,352 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,353 - src.embeddings.text_Chunker - INFO - Input text has 96 tokens
# 2025-06-19 22:34:42,353 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,354 - src.embeddings.text_Chunker - INFO - Input text has 109 tokens
# 2025-06-19 22:34:42,354 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,355 - src.embeddings.text_Chunker - INFO - Input text has 106 tokens
# 2025-06-19 22:34:42,355 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,356 - src.embeddings.text_Chunker - INFO - Input text has 35 tokens
# 2025-06-19 22:34:42,356 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,358 - src.embeddings.text_Chunker - INFO - Input text has 112 tokens
# 2025-06-19 22:34:42,358 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,359 - src.embeddings.text_Chunker - INFO - Input text has 102 tokens
# 2025-06-19 22:34:42,359 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,360 - src.embeddings.text_Chunker - INFO - Input text has 32 tokens
# 2025-06-19 22:34:42,360 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,361 - src.embeddings.text_Chunker - INFO - Input text has 231 tokens
# 2025-06-19 22:34:42,361 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,361 - src.embeddings.text_Chunker - INFO - Input text has 81 tokens
# 2025-06-19 22:34:42,362 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,363 - src.embeddings.text_Chunker - INFO - Input text has 38 tokens
# 2025-06-19 22:34:42,363 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,364 - src.embeddings.text_Chunker - INFO - Input text has 77 tokens
# 2025-06-19 22:34:42,364 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,365 - src.embeddings.text_Chunker - INFO - Input text has 162 tokens
# 2025-06-19 22:34:42,365 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,366 - src.embeddings.text_Chunker - INFO - Input text has 64 tokens
# 2025-06-19 22:34:42,366 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,366 - src.embeddings.text_Chunker - INFO - Input text has 22 tokens
# 2025-06-19 22:34:42,366 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,368 - src.embeddings.text_Chunker - INFO - Input text has 27 tokens
# 2025-06-19 22:34:42,368 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,369 - src.embeddings.text_Chunker - INFO - Input text has 76 tokens
# 2025-06-19 22:34:42,370 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,370 - src.embeddings.text_Chunker - INFO - Input text has 121 tokens
# 2025-06-19 22:34:42,371 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,372 - src.embeddings.text_Chunker - INFO - Input text has 50 tokens
# 2025-06-19 22:34:42,372 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,373 - src.embeddings.text_Chunker - INFO - Input text has 155 tokens
# 2025-06-19 22:34:42,373 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,374 - src.embeddings.text_Chunker - INFO - Input text has 19 tokens
# 2025-06-19 22:34:42,374 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,375 - src.embeddings.text_Chunker - INFO - Input text has 29 tokens
# 2025-06-19 22:34:42,375 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,375 - src.embeddings.text_Chunker - INFO - Input text has 84 tokens
# 2025-06-19 22:34:42,376 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,376 - src.embeddings.text_Chunker - INFO - Input text has 84 tokens
# 2025-06-19 22:34:42,376 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,377 - src.embeddings.text_Chunker - INFO - Input text has 91 tokens
# 2025-06-19 22:34:42,377 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,378 - src.embeddings.text_Chunker - INFO - Input text has 83 tokens
# 2025-06-19 22:34:42,378 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,379 - src.embeddings.text_Chunker - INFO - Input text has 21 tokens
# 2025-06-19 22:34:42,379 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,379 - src.embeddings.text_Chunker - INFO - Input text has 35 tokens
# 2025-06-19 22:34:42,379 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,380 - src.embeddings.text_Chunker - INFO - Input text has 144 tokens
# 2025-06-19 22:34:42,380 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,381 - src.embeddings.text_Chunker - INFO - Input text has 52 tokens
# 2025-06-19 22:34:42,381 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,381 - src.embeddings.text_Chunker - INFO - Input text has 24 tokens
# 2025-06-19 22:34:42,382 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,382 - src.embeddings.text_Chunker - INFO - Input text has 50 tokens
# 2025-06-19 22:34:42,383 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,383 - src.embeddings.text_Chunker - INFO - Input text has 22 tokens
# 2025-06-19 22:34:42,383 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,384 - src.embeddings.text_Chunker - INFO - Input text has 32 tokens
# 2025-06-19 22:34:42,384 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,385 - src.embeddings.text_Chunker - INFO - Input text has 80 tokens
# 2025-06-19 22:34:42,385 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,386 - src.embeddings.text_Chunker - INFO - Input text has 22 tokens
# 2025-06-19 22:34:42,386 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,387 - src.embeddings.text_Chunker - INFO - Input text has 17 tokens
# 2025-06-19 22:34:42,387 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,388 - src.embeddings.text_Chunker - INFO - Input text has 21 tokens
# 2025-06-19 22:34:42,388 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,389 - src.embeddings.text_Chunker - INFO - Input text has 13 tokens
# 2025-06-19 22:34:42,389 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,389 - src.embeddings.text_Chunker - INFO - Input text has 88 tokens
# 2025-06-19 22:34:42,389 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,390 - src.embeddings.text_Chunker - INFO - Input text has 170 tokens
# 2025-06-19 22:34:42,391 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,391 - src.embeddings.text_Chunker - INFO - Input text has 30 tokens
# 2025-06-19 22:34:42,391 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,392 - src.embeddings.text_Chunker - INFO - Input text has 123 tokens
# 2025-06-19 22:34:42,392 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,392 - src.embeddings.text_Chunker - INFO - Input text has 71 tokens
# 2025-06-19 22:34:42,393 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,393 - src.embeddings.text_Chunker - INFO - Input text has 95 tokens
# 2025-06-19 22:34:42,394 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,394 - src.embeddings.text_Chunker - INFO - Input text has 80 tokens
# 2025-06-19 22:34:42,394 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,395 - src.embeddings.text_Chunker - INFO - Input text has 380 tokens
# 2025-06-19 22:34:42,396 - src.embeddings.text_Chunker - INFO - Using chunk size: 190 tokens, overlap: 30
# 2025-06-19 22:34:42,398 - src.embeddings.text_Chunker - INFO - Input text has 100 tokens
# 2025-06-19 22:34:42,399 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,400 - src.embeddings.text_Chunker - INFO - Input text has 111 tokens
# 2025-06-19 22:34:42,400 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,401 - src.embeddings.text_Chunker - INFO - Input text has 119 tokens
# 2025-06-19 22:34:42,401 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,401 - src.embeddings.text_Chunker - INFO - Input text has 64 tokens
# 2025-06-19 22:34:42,402 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,402 - src.embeddings.text_Chunker - INFO - Input text has 142 tokens
# 2025-06-19 22:34:42,402 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,403 - src.embeddings.text_Chunker - INFO - Input text has 14 tokens
# 2025-06-19 22:34:42,403 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,404 - src.embeddings.text_Chunker - INFO - Input text has 85 tokens
# 2025-06-19 22:34:42,404 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,405 - src.embeddings.text_Chunker - INFO - Input text has 23 tokens
# 2025-06-19 22:34:42,405 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,406 - src.embeddings.text_Chunker - INFO - Input text has 18 tokens
# 2025-06-19 22:34:42,406 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,407 - src.embeddings.text_Chunker - INFO - Input text has 19 tokens
# 2025-06-19 22:34:42,407 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,407 - src.embeddings.text_Chunker - INFO - Input text has 21 tokens
# 2025-06-19 22:34:42,407 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,408 - src.embeddings.text_Chunker - INFO - Input text has 16 tokens
# 2025-06-19 22:34:42,408 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,409 - src.embeddings.text_Chunker - INFO - Input text has 36 tokens
# 2025-06-19 22:34:42,409 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,409 - src.embeddings.text_Chunker - INFO - Input text has 33 tokens
# 2025-06-19 22:34:42,409 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,410 - src.embeddings.text_Chunker - INFO - Input text has 47 tokens
# 2025-06-19 22:34:42,410 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,411 - src.embeddings.text_Chunker - INFO - Input text has 41 tokens
# 2025-06-19 22:34:42,411 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,412 - src.embeddings.text_Chunker - INFO - Input text has 25 tokens
# 2025-06-19 22:34:42,412 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,413 - src.embeddings.text_Chunker - INFO - Input text has 33 tokens
# 2025-06-19 22:34:42,413 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,413 - src.embeddings.text_Chunker - INFO - Input text has 53 tokens
# 2025-06-19 22:34:42,414 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,414 - src.embeddings.text_Chunker - INFO - Input text has 123 tokens
# 2025-06-19 22:34:42,414 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,415 - src.embeddings.text_Chunker - INFO - Input text has 15 tokens
# 2025-06-19 22:34:42,415 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,416 - src.embeddings.text_Chunker - INFO - Input text has 28 tokens
# 2025-06-19 22:34:42,416 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,417 - src.embeddings.text_Chunker - INFO - Input text has 42 tokens
# 2025-06-19 22:34:42,417 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,417 - src.embeddings.text_Chunker - INFO - Input text has 35 tokens
# 2025-06-19 22:34:42,417 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,418 - src.embeddings.text_Chunker - INFO - Input text has 24 tokens
# 2025-06-19 22:34:42,418 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,419 - src.embeddings.text_Chunker - INFO - Input text has 79 tokens
# 2025-06-19 22:34:42,419 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,419 - src.embeddings.text_Chunker - INFO - Input text has 51 tokens
# 2025-06-19 22:34:42,420 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,420 - src.embeddings.text_Chunker - INFO - Input text has 147 tokens
# 2025-06-19 22:34:42,421 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,421 - src.embeddings.text_Chunker - INFO - Input text has 82 tokens
# 2025-06-19 22:34:42,421 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,422 - src.embeddings.text_Chunker - INFO - Input text has 76 tokens
# 2025-06-19 22:34:42,422 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,423 - src.embeddings.text_Chunker - INFO - Input text has 63 tokens
# 2025-06-19 22:34:42,423 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,423 - src.embeddings.text_Chunker - INFO - Input text has 34 tokens
# 2025-06-19 22:34:42,423 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,424 - src.embeddings.text_Chunker - INFO - Input text has 64 tokens
# 2025-06-19 22:34:42,425 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,425 - src.embeddings.text_Chunker - INFO - Input text has 23 tokens
# 2025-06-19 22:34:42,425 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,426 - src.embeddings.text_Chunker - INFO - Input text has 13 tokens
# 2025-06-19 22:34:42,426 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,427 - src.embeddings.text_Chunker - INFO - Input text has 26 tokens
# 2025-06-19 22:34:42,428 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,428 - src.embeddings.text_Chunker - INFO - Input text has 37 tokens
# 2025-06-19 22:34:42,428 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,428 - src.embeddings.text_Chunker - INFO - Input text has 30 tokens
# 2025-06-19 22:34:42,429 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,429 - src.embeddings.text_Chunker - INFO - Input text has 46 tokens
# 2025-06-19 22:34:42,429 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,430 - src.embeddings.text_Chunker - INFO - Input text has 45 tokens
# 2025-06-19 22:34:42,430 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,431 - src.embeddings.text_Chunker - INFO - Input text has 60 tokens
# 2025-06-19 22:34:42,431 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,431 - src.embeddings.text_Chunker - INFO - Input text has 38 tokens
# 2025-06-19 22:34:42,431 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,432 - src.embeddings.text_Chunker - INFO - Input text has 30 tokens
# 2025-06-19 22:34:42,432 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,433 - src.embeddings.text_Chunker - INFO - Input text has 50 tokens
# 2025-06-19 22:34:42,433 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,434 - src.embeddings.text_Chunker - INFO - Input text has 27 tokens
# 2025-06-19 22:34:42,434 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,435 - src.embeddings.text_Chunker - INFO - Input text has 18 tokens
# 2025-06-19 22:34:42,435 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,435 - src.embeddings.text_Chunker - INFO - Input text has 53 tokens
# 2025-06-19 22:34:42,436 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,437 - src.embeddings.text_Chunker - INFO - Input text has 128 tokens
# 2025-06-19 22:34:42,437 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,437 - src.embeddings.text_Chunker - INFO - Input text has 72 tokens
# 2025-06-19 22:34:42,437 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,438 - src.embeddings.text_Chunker - INFO - Input text has 63 tokens
# 2025-06-19 22:34:42,438 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,438 - src.embeddings.text_Chunker - INFO - Input text has 59 tokens
# 2025-06-19 22:34:42,439 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,440 - src.embeddings.text_Chunker - INFO - Input text has 114 tokens
# 2025-06-19 22:34:42,440 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,440 - src.embeddings.text_Chunker - INFO - Input text has 90 tokens
# 2025-06-19 22:34:42,441 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,442 - src.embeddings.text_Chunker - INFO - Input text has 28 tokens
# 2025-06-19 22:34:42,442 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,443 - src.embeddings.text_Chunker - INFO - Input text has 150 tokens
# 2025-06-19 22:34:42,443 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,443 - src.embeddings.text_Chunker - INFO - Input text has 36 tokens
# 2025-06-19 22:34:42,444 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,444 - src.embeddings.text_Chunker - INFO - Input text has 40 tokens
# 2025-06-19 22:34:42,444 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,445 - src.embeddings.text_Chunker - INFO - Input text has 34 tokens
# 2025-06-19 22:34:42,445 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,445 - src.embeddings.text_Chunker - INFO - Input text has 88 tokens
# 2025-06-19 22:34:42,446 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,446 - src.embeddings.text_Chunker - INFO - Input text has 81 tokens
# 2025-06-19 22:34:42,447 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,447 - src.embeddings.text_Chunker - INFO - Input text has 61 tokens
# 2025-06-19 22:34:42,448 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,449 - src.embeddings.text_Chunker - INFO - Input text has 76 tokens
# 2025-06-19 22:34:42,449 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,449 - src.embeddings.text_Chunker - INFO - Input text has 65 tokens
# 2025-06-19 22:34:42,450 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,450 - src.embeddings.text_Chunker - INFO - Input text has 53 tokens
# 2025-06-19 22:34:42,450 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,451 - src.embeddings.text_Chunker - INFO - Input text has 20 tokens
# 2025-06-19 22:34:42,451 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,452 - src.embeddings.text_Chunker - INFO - Input text has 67 tokens
# 2025-06-19 22:34:42,452 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,452 - src.embeddings.text_Chunker - INFO - Input text has 18 tokens
# 2025-06-19 22:34:42,453 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,453 - src.embeddings.text_Chunker - INFO - Input text has 19 tokens
# 2025-06-19 22:34:42,453 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,454 - src.embeddings.text_Chunker - INFO - Input text has 34 tokens
# 2025-06-19 22:34:42,454 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,455 - src.embeddings.text_Chunker - INFO - Input text has 65 tokens
# 2025-06-19 22:34:42,455 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,455 - src.embeddings.text_Chunker - INFO - Input text has 32 tokens
# 2025-06-19 22:34:42,456 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,456 - src.embeddings.text_Chunker - INFO - Input text has 30 tokens
# 2025-06-19 22:34:42,457 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,457 - src.embeddings.text_Chunker - INFO - Input text has 90 tokens
# 2025-06-19 22:34:42,457 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,458 - src.embeddings.text_Chunker - INFO - Input text has 83 tokens
# 2025-06-19 22:34:42,459 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,459 - src.embeddings.text_Chunker - INFO - Input text has 21 tokens
# 2025-06-19 22:34:42,459 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,460 - src.embeddings.text_Chunker - INFO - Input text has 40 tokens
# 2025-06-19 22:34:42,460 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,461 - src.embeddings.text_Chunker - INFO - Input text has 40 tokens
# 2025-06-19 22:34:42,461 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,461 - src.embeddings.text_Chunker - INFO - Input text has 20 tokens
# 2025-06-19 22:34:42,462 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,462 - src.embeddings.text_Chunker - INFO - Input text has 26 tokens
# 2025-06-19 22:34:42,462 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,463 - src.embeddings.text_Chunker - INFO - Input text has 38 tokens
# 2025-06-19 22:34:42,463 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,464 - src.embeddings.text_Chunker - INFO - Input text has 20 tokens
# 2025-06-19 22:34:42,464 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,464 - src.embeddings.text_Chunker - INFO - Input text has 35 tokens
# 2025-06-19 22:34:42,465 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,465 - src.embeddings.text_Chunker - INFO - Input text has 28 tokens
# 2025-06-19 22:34:42,465 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,466 - src.embeddings.text_Chunker - INFO - Input text has 27 tokens
# 2025-06-19 22:34:42,467 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,467 - src.embeddings.text_Chunker - INFO - Input text has 27 tokens
# 2025-06-19 22:34:42,467 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,468 - src.embeddings.text_Chunker - INFO - Input text has 46 tokens
# 2025-06-19 22:34:42,468 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,469 - src.embeddings.text_Chunker - INFO - Input text has 23 tokens
# 2025-06-19 22:34:42,469 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,470 - src.embeddings.text_Chunker - INFO - Input text has 26 tokens
# 2025-06-19 22:34:42,470 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,470 - src.embeddings.text_Chunker - INFO - Input text has 38 tokens
# 2025-06-19 22:34:42,470 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,471 - src.embeddings.text_Chunker - INFO - Input text has 19 tokens
# 2025-06-19 22:34:42,472 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,472 - src.embeddings.text_Chunker - INFO - Input text has 58 tokens
# 2025-06-19 22:34:42,472 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,472 - src.embeddings.text_Chunker - INFO - Input text has 22 tokens
# 2025-06-19 22:34:42,473 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,473 - src.embeddings.text_Chunker - INFO - Input text has 38 tokens
# 2025-06-19 22:34:42,474 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,474 - src.embeddings.text_Chunker - INFO - Input text has 50 tokens
# 2025-06-19 22:34:42,474 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,475 - src.embeddings.text_Chunker - INFO - Input text has 27 tokens
# 2025-06-19 22:34:42,475 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,475 - src.embeddings.text_Chunker - INFO - Input text has 33 tokens
# 2025-06-19 22:34:42,475 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,476 - src.embeddings.text_Chunker - INFO - Input text has 67 tokens
# 2025-06-19 22:34:42,477 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,477 - src.embeddings.text_Chunker - INFO - Input text has 47 tokens
# 2025-06-19 22:34:42,477 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,478 - src.embeddings.text_Chunker - INFO - Input text has 80 tokens
# 2025-06-19 22:34:42,478 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,479 - src.embeddings.text_Chunker - INFO - Input text has 146 tokens
# 2025-06-19 22:34:42,479 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,480 - src.embeddings.text_Chunker - INFO - Input text has 104 tokens
# 2025-06-19 22:34:42,480 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,481 - src.embeddings.text_Chunker - INFO - Input text has 33 tokens
# 2025-06-19 22:34:42,481 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,481 - src.embeddings.text_Chunker - INFO - Input text has 47 tokens
# 2025-06-19 22:34:42,482 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,482 - src.embeddings.text_Chunker - INFO - Input text has 33 tokens
# 2025-06-19 22:34:42,482 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,483 - src.embeddings.text_Chunker - INFO - Input text has 170 tokens
# 2025-06-19 22:34:42,483 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,484 - src.embeddings.text_Chunker - INFO - Input text has 104 tokens
# 2025-06-19 22:34:42,484 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,485 - src.embeddings.text_Chunker - INFO - Input text has 133 tokens
# 2025-06-19 22:34:42,485 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,485 - src.embeddings.text_Chunker - INFO - Input text has 72 tokens
# 2025-06-19 22:34:42,486 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,486 - src.embeddings.text_Chunker - INFO - Input text has 116 tokens
# 2025-06-19 22:34:42,487 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,487 - src.embeddings.text_Chunker - INFO - Input text has 29 tokens
# 2025-06-19 22:34:42,487 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,488 - src.embeddings.text_Chunker - INFO - Input text has 134 tokens
# 2025-06-19 22:34:42,488 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,489 - src.embeddings.text_Chunker - INFO - Input text has 79 tokens
# 2025-06-19 22:34:42,489 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# Token indices sequence length is longer than the specified maximum sequence length for this model (691 > 512). Running this sequence through the model will result in indexing errors
# 2025-06-19 22:34:42,491 - src.embeddings.text_Chunker - INFO - Input text has 691 tokens
# 2025-06-19 22:34:42,491 - src.embeddings.text_Chunker - INFO - Using chunk size: 231 tokens, overlap: 30
# 2025-06-19 22:34:42,494 - src.embeddings.text_Chunker - INFO - Input text has 38 tokens
# 2025-06-19 22:34:42,494 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,495 - src.embeddings.text_Chunker - INFO - Input text has 59 tokens
# 2025-06-19 22:34:42,495 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,496 - src.embeddings.text_Chunker - INFO - Input text has 82 tokens
# 2025-06-19 22:34:42,496 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,497 - src.embeddings.text_Chunker - INFO - Input text has 791 tokens
# 2025-06-19 22:34:42,498 - src.embeddings.text_Chunker - INFO - Using chunk size: 264 tokens, overlap: 30
# 2025-06-19 22:34:42,501 - src.embeddings.text_Chunker - INFO - Input text has 129 tokens
# 2025-06-19 22:34:42,501 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,502 - src.embeddings.text_Chunker - INFO - Input text has 66 tokens
# 2025-06-19 22:34:42,502 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,503 - src.embeddings.text_Chunker - INFO - Input text has 82 tokens
# 2025-06-19 22:34:42,503 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# Chunking:   0%|          | 0/16 [00:00<?, ?it/s]
# 2025-06-19 22:34:42,508 - src.embeddings.text_Chunker - INFO - Input text has 5 tokens
# 2025-06-19 22:34:42,508 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,509 - src.embeddings.text_Chunker - INFO - Input text has 479 tokens
# 2025-06-19 22:34:42,510 - src.embeddings.text_Chunker - INFO - Using chunk size: 240 tokens, overlap: 30
# 2025-06-19 22:34:42,513 - src.embeddings.text_Chunker - INFO - Input text has 149 tokens
# 2025-06-19 22:34:42,513 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,514 - src.embeddings.text_Chunker - INFO - Input text has 98 tokens
# 2025-06-19 22:34:42,514 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,514 - src.embeddings.text_Chunker - INFO - Input text has 142 tokens
# 2025-06-19 22:34:42,514 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,515 - src.embeddings.text_Chunker - INFO - Input text has 148 tokens
# 2025-06-19 22:34:42,516 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,516 - src.embeddings.text_Chunker - INFO - Input text has 83 tokens
# 2025-06-19 22:34:42,516 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,516 - src.embeddings.text_Chunker - INFO - Input text has 103 tokens
# 2025-06-19 22:34:42,517 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,517 - src.embeddings.text_Chunker - INFO - Input text has 92 tokens
# 2025-06-19 22:34:42,518 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,518 - src.embeddings.text_Chunker - INFO - Input text has 94 tokens
# 2025-06-19 22:34:42,518 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,519 - src.embeddings.text_Chunker - INFO - Input text has 60 tokens
# 2025-06-19 22:34:42,519 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,520 - src.embeddings.text_Chunker - INFO - Input text has 62 tokens
# 2025-06-19 22:34:42,520 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,521 - src.embeddings.text_Chunker - INFO - Input text has 69 tokens
# 2025-06-19 22:34:42,521 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,521 - src.embeddings.text_Chunker - INFO - Input text has 43 tokens
# 2025-06-19 22:34:42,522 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,523 - src.embeddings.text_Chunker - INFO - Input text has 51 tokens
# 2025-06-19 22:34:42,523 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,524 - src.embeddings.text_Chunker - INFO - Input text has 84 tokens
# 2025-06-19 22:34:42,524 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# Chunking:   0%|          | 0/2 [00:00<?, ?it/s]
# 2025-06-19 22:34:42,530 - src.embeddings.text_Chunker - INFO - Input text has 15 tokens
# 2025-06-19 22:34:42,531 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,531 - src.embeddings.text_Chunker - INFO - Input text has 72 tokens
# 2025-06-19 22:34:42,531 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# Chunking:   0%|          | 0/2 [00:00<?, ?it/s]
# 2025-06-19 22:34:42,538 - src.embeddings.text_Chunker - INFO - Input text has 12 tokens
# 2025-06-19 22:34:42,538 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,538 - src.embeddings.text_Chunker - INFO - Input text has 255 tokens
# 2025-06-19 22:34:42,539 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# Chunking:   0%|          | 0/16 [00:00<?, ?it/s]
# 2025-06-19 22:34:42,546 - src.embeddings.text_Chunker - INFO - Input text has 13 tokens
# 2025-06-19 22:34:42,547 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,547 - src.embeddings.text_Chunker - INFO - Input text has 219 tokens
# 2025-06-19 22:34:42,548 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,548 - src.embeddings.text_Chunker - INFO - Input text has 172 tokens
# 2025-06-19 22:34:42,548 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,549 - src.embeddings.text_Chunker - INFO - Input text has 18 tokens
# 2025-06-19 22:34:42,549 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,550 - src.embeddings.text_Chunker - INFO - Input text has 19 tokens
# 2025-06-19 22:34:42,550 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,550 - src.embeddings.text_Chunker - INFO - Input text has 194 tokens
# 2025-06-19 22:34:42,551 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,551 - src.embeddings.text_Chunker - INFO - Input text has 12 tokens
# 2025-06-19 22:34:42,551 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,552 - src.embeddings.text_Chunker - INFO - Input text has 12 tokens
# 2025-06-19 22:34:42,552 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,553 - src.embeddings.text_Chunker - INFO - Input text has 12 tokens
# 2025-06-19 22:34:42,553 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,553 - src.embeddings.text_Chunker - INFO - Input text has 7 tokens
# 2025-06-19 22:34:42,554 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,554 - src.embeddings.text_Chunker - INFO - Input text has 12 tokens
# 2025-06-19 22:34:42,554 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,555 - src.embeddings.text_Chunker - INFO - Input text has 452 tokens
# 2025-06-19 22:34:42,556 - src.embeddings.text_Chunker - INFO - Using chunk size: 226 tokens, overlap: 30
# 2025-06-19 22:34:42,558 - src.embeddings.text_Chunker - INFO - Input text has 65 tokens
# 2025-06-19 22:34:42,559 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,560 - src.embeddings.text_Chunker - INFO - Input text has 76 tokens
# 2025-06-19 22:34:42,560 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,561 - src.embeddings.text_Chunker - INFO - Input text has 63 tokens
# 2025-06-19 22:34:42,561 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,561 - src.embeddings.text_Chunker - INFO - Input text has 32 tokens
# 2025-06-19 22:34:42,561 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# Chunking:   0%|          | 0/111 [00:00<?, ?it/s]
# 2025-06-19 22:34:42,565 - src.embeddings.text_Chunker - INFO - Input text has 20 tokens
# 2025-06-19 22:34:42,566 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,566 - src.embeddings.text_Chunker - INFO - Input text has 56 tokens
# 2025-06-19 22:34:42,567 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,567 - src.embeddings.text_Chunker - INFO - Input text has 70 tokens
# 2025-06-19 22:34:42,568 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,568 - src.embeddings.text_Chunker - INFO - Input text has 103 tokens
# 2025-06-19 22:34:42,569 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,569 - src.embeddings.text_Chunker - INFO - Input text has 134 tokens
# 2025-06-19 22:34:42,569 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,570 - src.embeddings.text_Chunker - INFO - Input text has 105 tokens
# 2025-06-19 22:34:42,570 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,571 - src.embeddings.text_Chunker - INFO - Input text has 110 tokens
# 2025-06-19 22:34:42,571 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,572 - src.embeddings.text_Chunker - INFO - Input text has 66 tokens
# 2025-06-19 22:34:42,572 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,573 - src.embeddings.text_Chunker - INFO - Input text has 56 tokens
# 2025-06-19 22:34:42,573 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,573 - src.embeddings.text_Chunker - INFO - Input text has 51 tokens
# 2025-06-19 22:34:42,574 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,574 - src.embeddings.text_Chunker - INFO - Input text has 47 tokens
# 2025-06-19 22:34:42,574 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,575 - src.embeddings.text_Chunker - INFO - Input text has 79 tokens
# 2025-06-19 22:34:42,575 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,576 - src.embeddings.text_Chunker - INFO - Input text has 118 tokens
# 2025-06-19 22:34:42,576 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,577 - src.embeddings.text_Chunker - INFO - Input text has 73 tokens
# 2025-06-19 22:34:42,577 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,578 - src.embeddings.text_Chunker - INFO - Input text has 48 tokens
# 2025-06-19 22:34:42,578 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,578 - src.embeddings.text_Chunker - INFO - Input text has 85 tokens
# 2025-06-19 22:34:42,579 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,579 - src.embeddings.text_Chunker - INFO - Input text has 62 tokens
# 2025-06-19 22:34:42,579 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,579 - src.embeddings.text_Chunker - INFO - Input text has 110 tokens
# 2025-06-19 22:34:42,580 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,580 - src.embeddings.text_Chunker - INFO - Input text has 28 tokens
# 2025-06-19 22:34:42,581 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,581 - src.embeddings.text_Chunker - INFO - Input text has 58 tokens
# 2025-06-19 22:34:42,581 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,584 - src.embeddings.text_Chunker - INFO - Input text has 1840 tokens
# 2025-06-19 22:34:42,584 - src.embeddings.text_Chunker - INFO - Using chunk size: 263 tokens, overlap: 30
# 2025-06-19 22:34:42,589 - src.embeddings.text_Chunker - INFO - Input text has 553 tokens
# 2025-06-19 22:34:42,589 - src.embeddings.text_Chunker - INFO - Using chunk size: 277 tokens, overlap: 30
# 2025-06-19 22:34:42,591 - src.embeddings.text_Chunker - INFO - Input text has 108 tokens
# 2025-06-19 22:34:42,591 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,592 - src.embeddings.text_Chunker - INFO - Input text has 129 tokens
# 2025-06-19 22:34:42,592 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,593 - src.embeddings.text_Chunker - INFO - Input text has 127 tokens
# 2025-06-19 22:34:42,593 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,594 - src.embeddings.text_Chunker - INFO - Input text has 56 tokens
# 2025-06-19 22:34:42,594 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,595 - src.embeddings.text_Chunker - INFO - Input text has 56 tokens
# 2025-06-19 22:34:42,595 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,596 - src.embeddings.text_Chunker - INFO - Input text has 176 tokens
# 2025-06-19 22:34:42,596 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,596 - src.embeddings.text_Chunker - INFO - Input text has 36 tokens
# 2025-06-19 22:34:42,596 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,597 - src.embeddings.text_Chunker - INFO - Input text has 14 tokens
# 2025-06-19 22:34:42,597 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,598 - src.embeddings.text_Chunker - INFO - Input text has 159 tokens
# 2025-06-19 22:34:42,598 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,599 - src.embeddings.text_Chunker - INFO - Input text has 23 tokens
# 2025-06-19 22:34:42,599 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,599 - src.embeddings.text_Chunker - INFO - Input text has 64 tokens
# 2025-06-19 22:34:42,600 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,600 - src.embeddings.text_Chunker - INFO - Input text has 90 tokens
# 2025-06-19 22:34:42,600 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,601 - src.embeddings.text_Chunker - INFO - Input text has 165 tokens
# 2025-06-19 22:34:42,602 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,602 - src.embeddings.text_Chunker - INFO - Input text has 72 tokens
# 2025-06-19 22:34:42,602 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,602 - src.embeddings.text_Chunker - INFO - Input text has 21 tokens
# 2025-06-19 22:34:42,602 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,603 - src.embeddings.text_Chunker - INFO - Input text has 179 tokens
# 2025-06-19 22:34:42,604 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,604 - src.embeddings.text_Chunker - INFO - Input text has 61 tokens
# 2025-06-19 22:34:42,604 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,605 - src.embeddings.text_Chunker - INFO - Input text has 72 tokens
# 2025-06-19 22:34:42,605 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,606 - src.embeddings.text_Chunker - INFO - Input text has 30 tokens
# 2025-06-19 22:34:42,606 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,607 - src.embeddings.text_Chunker - INFO - Input text has 180 tokens
# 2025-06-19 22:34:42,607 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,607 - src.embeddings.text_Chunker - INFO - Input text has 82 tokens
# 2025-06-19 22:34:42,608 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,608 - src.embeddings.text_Chunker - INFO - Input text has 49 tokens
# 2025-06-19 22:34:42,608 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,609 - src.embeddings.text_Chunker - INFO - Input text has 260 tokens
# 2025-06-19 22:34:42,609 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,610 - src.embeddings.text_Chunker - INFO - Input text has 228 tokens
# 2025-06-19 22:34:42,610 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,611 - src.embeddings.text_Chunker - INFO - Input text has 142 tokens
# 2025-06-19 22:34:42,611 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,612 - src.embeddings.text_Chunker - INFO - Input text has 78 tokens
# 2025-06-19 22:34:42,612 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,613 - src.embeddings.text_Chunker - INFO - Input text has 67 tokens
# 2025-06-19 22:34:42,613 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,614 - src.embeddings.text_Chunker - INFO - Input text has 107 tokens
# 2025-06-19 22:34:42,614 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:42,615 - src.embeddings.text_Chunker - INFO - Input text has 87 tokens
# 2025-06-19 22:34:42,615 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# ...
# 2025-06-19 22:34:53,326 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,327 - src.embeddings.text_Chunker - INFO - Input text has 83 tokens
# 2025-06-19 22:34:53,327 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,327 - src.embeddings.text_Chunker - INFO - Input text has 160 tokens
# 2025-06-19 22:34:53,328 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,328 - src.embeddings.text_Chunker - INFO - Input text has 42 tokens
# 2025-06-19 22:34:53,328 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,329 - src.embeddings.text_Chunker - INFO - Input text has 153 tokens
# 2025-06-19 22:34:53,329 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,329 - src.embeddings.text_Chunker - INFO - Input text has 205 tokens
# 2025-06-19 22:34:53,330 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,330 - src.embeddings.text_Chunker - INFO - Input text has 129 tokens
# 2025-06-19 22:34:53,330 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,331 - src.embeddings.text_Chunker - INFO - Input text has 85 tokens
# 2025-06-19 22:34:53,331 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,331 - src.embeddings.text_Chunker - INFO - Input text has 58 tokens
# 2025-06-19 22:34:53,332 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,332 - src.embeddings.text_Chunker - INFO - Input text has 98 tokens
# 2025-06-19 22:34:53,333 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,333 - src.embeddings.text_Chunker - INFO - Input text has 179 tokens
# 2025-06-19 22:34:53,333 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,333 - src.embeddings.text_Chunker - INFO - Input text has 72 tokens
# 2025-06-19 22:34:53,334 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,334 - src.embeddings.text_Chunker - INFO - Input text has 188 tokens
# 2025-06-19 22:34:53,335 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,335 - src.embeddings.text_Chunker - INFO - Input text has 97 tokens
# 2025-06-19 22:34:53,335 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,336 - src.embeddings.text_Chunker - INFO - Input text has 180 tokens
# 2025-06-19 22:34:53,336 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,337 - src.embeddings.text_Chunker - INFO - Input text has 116 tokens
# 2025-06-19 22:34:53,337 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,337 - src.embeddings.text_Chunker - INFO - Input text has 58 tokens
# 2025-06-19 22:34:53,337 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,338 - src.embeddings.text_Chunker - INFO - Input text has 91 tokens
# 2025-06-19 22:34:53,338 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,339 - src.embeddings.text_Chunker - INFO - Input text has 29 tokens
# 2025-06-19 22:34:53,339 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,339 - src.embeddings.text_Chunker - INFO - Input text has 9 tokens
# 2025-06-19 22:34:53,339 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,340 - src.embeddings.text_Chunker - INFO - Input text has 70 tokens
# 2025-06-19 22:34:53,340 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,341 - src.embeddings.text_Chunker - INFO - Input text has 36 tokens
# 2025-06-19 22:34:53,341 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,341 - src.embeddings.text_Chunker - INFO - Input text has 40 tokens
# 2025-06-19 22:34:53,342 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,342 - src.embeddings.text_Chunker - INFO - Input text has 41 tokens
# 2025-06-19 22:34:53,342 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,343 - src.embeddings.text_Chunker - INFO - Input text has 170 tokens
# 2025-06-19 22:34:53,343 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,344 - src.embeddings.text_Chunker - INFO - Input text has 181 tokens
# 2025-06-19 22:34:53,344 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,345 - src.embeddings.text_Chunker - INFO - Input text has 19 tokens
# 2025-06-19 22:34:53,345 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,346 - src.embeddings.text_Chunker - INFO - Input text has 92 tokens
# 2025-06-19 22:34:53,346 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,346 - src.embeddings.text_Chunker - INFO - Input text has 11 tokens
# 2025-06-19 22:34:53,346 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,347 - src.embeddings.text_Chunker - INFO - Input text has 27 tokens
# 2025-06-19 22:34:53,347 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,347 - src.embeddings.text_Chunker - INFO - Input text has 9 tokens
# 2025-06-19 22:34:53,348 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,348 - src.embeddings.text_Chunker - INFO - Input text has 76 tokens
# 2025-06-19 22:34:53,348 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,349 - src.embeddings.text_Chunker - INFO - Input text has 159 tokens
# 2025-06-19 22:34:53,349 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,350 - src.embeddings.text_Chunker - INFO - Input text has 358 tokens
# 2025-06-19 22:34:53,351 - src.embeddings.text_Chunker - INFO - Using chunk size: 179 tokens, overlap: 30
# 2025-06-19 22:34:53,353 - src.embeddings.text_Chunker - INFO - Input text has 88 tokens
# 2025-06-19 22:34:53,353 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,353 - src.embeddings.text_Chunker - INFO - Input text has 117 tokens
# 2025-06-19 22:34:53,354 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,354 - src.embeddings.text_Chunker - INFO - Input text has 57 tokens
# 2025-06-19 22:34:53,354 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,355 - src.embeddings.text_Chunker - INFO - Input text has 45 tokens
# 2025-06-19 22:34:53,355 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,356 - src.embeddings.text_Chunker - INFO - Input text has 88 tokens
# 2025-06-19 22:34:53,356 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,356 - src.embeddings.text_Chunker - INFO - Input text has 31 tokens
# 2025-06-19 22:34:53,357 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,357 - src.embeddings.text_Chunker - INFO - Input text has 54 tokens
# 2025-06-19 22:34:53,357 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,358 - src.embeddings.text_Chunker - INFO - Input text has 119 tokens
# 2025-06-19 22:34:53,358 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,359 - src.embeddings.text_Chunker - INFO - Input text has 160 tokens
# 2025-06-19 22:34:53,359 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,359 - src.embeddings.text_Chunker - INFO - Input text has 46 tokens
# 2025-06-19 22:34:53,360 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,360 - src.embeddings.text_Chunker - INFO - Input text has 50 tokens
# 2025-06-19 22:34:53,361 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,361 - src.embeddings.text_Chunker - INFO - Input text has 23 tokens
# 2025-06-19 22:34:53,361 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,361 - src.embeddings.text_Chunker - INFO - Input text has 128 tokens
# 2025-06-19 22:34:53,362 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,362 - src.embeddings.text_Chunker - INFO - Input text has 64 tokens
# 2025-06-19 22:34:53,363 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,363 - src.embeddings.text_Chunker - INFO - Input text has 61 tokens
# 2025-06-19 22:34:53,364 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,364 - src.embeddings.text_Chunker - INFO - Input text has 155 tokens
# 2025-06-19 22:34:53,364 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,364 - src.embeddings.text_Chunker - INFO - Input text has 16 tokens
# 2025-06-19 22:34:53,365 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,366 - src.embeddings.text_Chunker - INFO - Input text has 123 tokens
# 2025-06-19 22:34:53,366 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,367 - src.embeddings.text_Chunker - INFO - Input text has 108 tokens
# 2025-06-19 22:34:53,367 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,367 - src.embeddings.text_Chunker - INFO - Input text has 65 tokens
# 2025-06-19 22:34:53,368 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,368 - src.embeddings.text_Chunker - INFO - Input text has 89 tokens
# 2025-06-19 22:34:53,368 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,369 - src.embeddings.text_Chunker - INFO - Input text has 157 tokens
# 2025-06-19 22:34:53,369 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,370 - src.embeddings.text_Chunker - INFO - Input text has 86 tokens
# 2025-06-19 22:34:53,370 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,370 - src.embeddings.text_Chunker - INFO - Input text has 88 tokens
# 2025-06-19 22:34:53,371 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,371 - src.embeddings.text_Chunker - INFO - Input text has 48 tokens
# 2025-06-19 22:34:53,371 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,372 - src.embeddings.text_Chunker - INFO - Input text has 172 tokens
# 2025-06-19 22:34:53,372 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,372 - src.embeddings.text_Chunker - INFO - Input text has 53 tokens
# 2025-06-19 22:34:53,373 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,373 - src.embeddings.text_Chunker - INFO - Input text has 11 tokens
# 2025-06-19 22:34:53,374 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,374 - src.embeddings.text_Chunker - INFO - Input text has 69 tokens
# 2025-06-19 22:34:53,374 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,374 - src.embeddings.text_Chunker - INFO - Input text has 133 tokens
# 2025-06-19 22:34:53,375 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,375 - src.embeddings.text_Chunker - INFO - Input text has 18 tokens
# 2025-06-19 22:34:53,376 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,376 - src.embeddings.text_Chunker - INFO - Input text has 47 tokens
# 2025-06-19 22:34:53,376 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,376 - src.embeddings.text_Chunker - INFO - Input text has 46 tokens
# 2025-06-19 22:34:53,377 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,377 - src.embeddings.text_Chunker - INFO - Input text has 8 tokens
# 2025-06-19 22:34:53,377 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,378 - src.embeddings.text_Chunker - INFO - Input text has 51 tokens
# 2025-06-19 22:34:53,378 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,378 - src.embeddings.text_Chunker - INFO - Input text has 97 tokens
# 2025-06-19 22:34:53,379 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,380 - src.embeddings.text_Chunker - INFO - Input text has 133 tokens
# 2025-06-19 22:34:53,380 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,380 - src.embeddings.text_Chunker - INFO - Input text has 65 tokens
# 2025-06-19 22:34:53,380 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,381 - src.embeddings.text_Chunker - INFO - Input text has 10 tokens
# 2025-06-19 22:34:53,381 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,381 - src.embeddings.text_Chunker - INFO - Input text has 14 tokens
# 2025-06-19 22:34:53,382 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,382 - src.embeddings.text_Chunker - INFO - Input text has 17 tokens
# 2025-06-19 22:34:53,382 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,382 - src.embeddings.text_Chunker - INFO - Input text has 58 tokens
# 2025-06-19 22:34:53,383 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,384 - src.embeddings.text_Chunker - INFO - Input text has 173 tokens
# 2025-06-19 22:34:53,384 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,384 - src.embeddings.text_Chunker - INFO - Input text has 111 tokens
# 2025-06-19 22:34:53,384 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,385 - src.embeddings.text_Chunker - INFO - Input text has 40 tokens
# 2025-06-19 22:34:53,385 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,386 - src.embeddings.text_Chunker - INFO - Input text has 33 tokens
# 2025-06-19 22:34:53,386 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,387 - src.embeddings.text_Chunker - INFO - Input text has 70 tokens
# 2025-06-19 22:34:53,387 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,387 - src.embeddings.text_Chunker - INFO - Input text has 57 tokens
# 2025-06-19 22:34:53,388 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,388 - src.embeddings.text_Chunker - INFO - Input text has 57 tokens
# 2025-06-19 22:34:53,388 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,389 - src.embeddings.text_Chunker - INFO - Input text has 44 tokens
# 2025-06-19 22:34:53,389 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,390 - src.embeddings.text_Chunker - INFO - Input text has 32 tokens
# 2025-06-19 22:34:53,390 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,390 - src.embeddings.text_Chunker - INFO - Input text has 68 tokens
# 2025-06-19 22:34:53,391 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,391 - src.embeddings.text_Chunker - INFO - Input text has 8 tokens
# 2025-06-19 22:34:53,391 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,392 - src.embeddings.text_Chunker - INFO - Input text has 9 tokens
# 2025-06-19 22:34:53,392 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-19 22:34:53,393 - src.embeddings.text_Chunker - INFO - Input text has 117 tokens
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
documents = []
chunked_docs[0]
# Out:
# Document(metadata={'doc_id': 'EP13899497B9W1', 'language': 'en', 'country': 'EP', 'doc_number': '3084761', 'application_number': '13899497.5', 'publication_date': '20250611', 'ipc_classes': 'G10L  19/038       20130101AFI20170426BHEP, G10L  19/07        20130101ALI20170426BHEP', 'file': 'EP13899497W1B9.xml', 'filePath': '/app/data/parsed/EPO/EPRTBJV2025000024001001/EPW1B9/EP13899497W1B9/EP13899497W1B9.json', 'title': 'AUDIO SIGNAL ENCODER', 'section': 'title', 'chunk_index': 0, 'total_chunks': 1}, page_content='AUDIO SIGNAL ENCODER')

# %%
print(f"✅ Created {len(chunked_docs)} chunks from {len(documents)} document segments")
# Out:
# ✅ Created 17428 chunks from 0 document segments

# %%
embeddings = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs={"device": "cpu"},
    encode_kwargs={"batch_size": 32, "normalize_embeddings": True}
)
print("✅ LangChain embeddings initialized")
# Out:
# /tmp/ipykernel_3966/3069164953.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# 2025-06-19 22:34:55,595 - sentence_transformers.SentenceTransformer - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-mpnet-base-v2
# ✅ LangChain embeddings initialized

# %%
# 7. Create vector store with chunked documents - connect to Docker ChromaDB
print("💾 Creating vector store using dockerized ChromaDB...")

# Import ChromaDB client directly (needed for Docker connection)
import chromadb
from chromadb.config import Settings

# When running inside Docker
chroma_client = chromadb.HttpClient(
    host="vector_db",  # Docker service name
    port=8000,         # Internal container port
    settings=Settings(anonymized_telemetry=False)
)
# Out:
# 💾 Creating vector store using dockerized ChromaDB...
# 2025-06-19 22:34:57,467 - httpx - INFO - HTTP Request: GET http://vector_db:8000/api/v2/auth/identity "HTTP/1.1 200 OK"
# 2025-06-19 22:34:57,495 - httpx - INFO - HTTP Request: GET http://vector_db:8000/api/v2/tenants/default_tenant "HTTP/1.1 200 OK"
# 2025-06-19 22:34:57,498 - httpx - INFO - HTTP Request: GET http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database "HTTP/1.1 200 OK"

# %%
collection_name = "patents"

vectorstore = Chroma(
    client=chroma_client,
    collection_name=collection_name,
    embedding_function=embeddings
)
# Out:
# /tmp/ipykernel_3966/978458448.py:3: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vectorstore = Chroma(
# 2025-06-19 22:35:01,431 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections "HTTP/1.1 200 OK"

# %%
# Add documents to the vectorstore (if we have any)
if chunked_docs:
    # Add in smaller batches to avoid memory issues
    batch_size = 100
    for i in tqdm(range(0, len(chunked_docs), batch_size), desc="Adding to vector store"):
        batch = chunked_docs[i:i+batch_size]
        vectorstore.add_documents(documents=batch)
    
    print(f"✅ Added {len(chunked_docs)} document chunks to ChromaDB collection '{collection_name}'")
else:
    print("⚠️ No document chunks to add to the vector store!")
# Out:
# Adding to vector store:   0%|          | 0/175 [00:00<?, ?it/s]
# 2025-06-19 22:35:50,142 - httpx - INFO - HTTP Request: GET http://vector_db:8000/api/v2/pre-flight-checks "HTTP/1.1 200 OK"
# 2025-06-19 22:35:50,250 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:35:56,690 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:36:05,187 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:36:13,551 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:36:22,098 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:36:29,227 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:36:35,308 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:36:41,398 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:36:48,860 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:36:54,696 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:37:00,879 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:37:08,453 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:37:14,762 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:37:21,995 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:37:30,683 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:37:39,981 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:37:48,807 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:37:56,967 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:38:04,593 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:38:11,503 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:38:17,865 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:38:27,048 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:38:35,595 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:38:42,893 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:38:50,073 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:39:00,213 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:39:09,374 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:39:14,937 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:39:26,768 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:39:33,953 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:39:41,082 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:39:46,692 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:39:54,915 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:40:03,983 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:40:14,295 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:40:21,591 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:40:26,966 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:40:35,878 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:40:45,533 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:40:59,627 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:41:11,062 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:41:18,475 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:41:30,302 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:41:41,725 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:41:50,502 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:41:55,626 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:41:58,029 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:42:03,869 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:42:09,540 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:42:16,087 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:42:23,767 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:42:31,334 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:42:38,324 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:42:47,474 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:42:54,644 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:43:02,170 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:43:09,209 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:43:14,432 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:43:21,604 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:43:29,704 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:43:37,418 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:43:46,655 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:43:56,213 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:44:05,303 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:44:11,032 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:44:14,812 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:44:21,994 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:44:28,528 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:44:38,558 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:44:46,111 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:44:53,942 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:45:01,974 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:45:09,061 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:45:16,818 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:45:25,028 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:45:36,128 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:45:45,954 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:45:53,458 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:46:01,974 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:46:09,107 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:46:15,745 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:46:22,078 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:46:27,657 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:46:32,176 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:46:38,674 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:46:47,483 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:46:55,848 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:47:00,512 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:47:05,925 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:47:12,757 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:47:20,111 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:47:25,895 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:47:31,731 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:47:38,278 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:47:44,154 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:47:48,617 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:47:55,531 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:48:02,165 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:48:09,688 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:48:17,652 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:48:24,722 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:48:29,846 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:48:37,110 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:48:44,918 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:48:50,975 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:48:57,696 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:49:08,288 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:49:15,458 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:49:22,030 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:49:28,242 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:49:34,977 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:49:43,354 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:49:50,071 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:49:56,730 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:50:03,237 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:50:08,828 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:50:12,827 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:50:18,458 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:50:23,352 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:50:29,633 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:50:35,454 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:50:40,766 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:50:46,305 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:50:52,992 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:50:59,690 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:51:05,043 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:51:08,609 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:51:14,577 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:51:23,832 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:51:33,300 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:51:41,121 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:51:48,544 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:51:56,396 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:52:05,391 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:52:14,900 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:52:23,736 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:52:31,538 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:52:37,800 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:52:45,208 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:52:51,517 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:52:59,397 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:53:09,211 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:53:15,958 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:53:24,759 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:53:32,527 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:53:38,025 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:53:46,641 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:53:56,036 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:54:02,952 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:54:08,657 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:54:16,540 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:54:23,843 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:54:30,183 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:54:35,163 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:54:43,833 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:54:50,005 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:54:56,782 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:55:01,339 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:55:07,720 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:55:16,812 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:55:26,010 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:55:34,497 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:55:42,810 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:55:50,540 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:55:58,047 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:56:08,828 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:56:18,017 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:56:26,281 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:56:33,278 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:56:40,550 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:56:47,839 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:56:57,735 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:57:05,979 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:57:13,951 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# 2025-06-19 22:57:17,444 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/ed371e4e-de10-48d9-84f5-ceb6d5b769cd/upsert "HTTP/1.1 200 OK"
# ✅ Added 17428 document chunks to ChromaDB collection 'patents'

# %%
# 8. Test retrieval (only if we have documents)
if chunked_docs:
    print("\n🔍 Testing vector store with sample queries...")

    test_queries = [
        "Audio signal encoding methods",
        "Image compression techniques",
        "Wireless communication protocols"
    ]

    for query in test_queries:
        print(f"\nQuery: '{query}'")
        # Get top 3 results
        results = vectorstore.similarity_search_with_score(query, k=3)
        
        print(f"Top {len(results)} results:")
        for i, (doc, score) in enumerate(results):
            print(f"\nResult {i+1} (similarity: {score:.4f})")
            print(f"Title: {doc.metadata.get('title', 'N/A')}")
            print(f"Section: {doc.metadata.get('section', 'N/A')}")
            print(f"Patent ID: {doc.metadata.get('doc_id', 'N/A')}")
            print(f"Content preview: {doc.page_content[:150]}...")
else:
    print("\n⚠️ No documents in vector store to search!")

# %%
vectorstore.delete_collection()
# Out:
# 2025-06-19 22:04:58,996 - httpx - INFO - HTTP Request: DELETE http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/patents "HTTP/1.1 200 OK"
