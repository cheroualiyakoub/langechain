# %%
import os
import sys
from pathlib import Path
import logging
import numpy as np
from transformers import AutoTokenizer
from tqdm.notebook import tqdm

# %%
notebook_dir = Path.cwd()
project_root = notebook_dir.parent  # If notebooks are in langechain/notebooks

# Add project root to Python path for imports
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

print(f"Project root: {project_root}")
# Out:
# Project root: /app

# %%
from src.data_pipline.json_loader.json_loader_epo import EPOPatentLoader
from config.json_loader_config import PatentLoaderConfig
from src.embeddings.text_Chunker import TextChunker, ChunkerConfig

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
from langchain.schema import Document

# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')
logger = logging.getLogger("patent_pipeline")

# %%
data_dir = Path(project_root) / "data" / "parsed" / "EPO"
model_name = "sentence-transformers/all-mpnet-base-v2"
vector_db_dir = Path(project_root) / "data" / "vector_db"
vector_db_dir.mkdir(parents=True, exist_ok=True)

# %%
loader_config = PatentLoaderConfig(
    max_files=50,
    
    verbose=False,
    epo_dir=data_dir,
    include_abstract=True,
    include_claims=True,
    include_description=True
)
patent_loader = EPOPatentLoader(config=loader_config)
print("✅ Patent loader initialized")
# Out:
# ✅ Patent loader initialized

# %%
json_files = patent_loader.load_raw_json_files()
# Out:
# 2025-06-20 08:25:20,774 - src.data_pipline.json_loader.json_loader_patent - INFO - Limited to 50 files out of 50 total files
# 2025-06-20 08:25:20,774 - src.data_pipline.json_loader.json_loader_patent - INFO - Limited to 50 files out of 50 total files
# 2025-06-20 08:25:20,774 - src.data_pipline.json_loader.json_loader_patent - INFO - Found 50 JSON files in /app/data/parsed/EPO
# 2025-06-20 08:25:20,774 - src.data_pipline.json_loader.json_loader_patent - INFO - Found 50 JSON files in /app/data/parsed/EPO
# 2025-06-20 08:25:20,787 - src.data_pipline.json_loader.json_loader_patent - INFO - Successfully loaded 50 raw JSON files
# 2025-06-20 08:25:20,787 - src.data_pipline.json_loader.json_loader_patent - INFO - Successfully loaded 50 raw JSON files

# %%
documents  = patent_loader.extract_document_components()
# Out:
# 2025-06-20 08:25:22,392 - src.data_pipline.json_loader.json_loader_patent - INFO - Limited to 50 files out of 50 total files
# 2025-06-20 08:25:22,392 - src.data_pipline.json_loader.json_loader_patent - INFO - Limited to 50 files out of 50 total files
# 2025-06-20 08:25:22,393 - src.data_pipline.json_loader.json_loader_patent - INFO - Found 50 JSON files in /app/data/parsed/EPO
# 2025-06-20 08:25:22,393 - src.data_pipline.json_loader.json_loader_patent - INFO - Found 50 JSON files in /app/data/parsed/EPO
# 2025-06-20 08:25:22,405 - src.data_pipline.json_loader.json_loader_patent - INFO - Successfully loaded 50 documents from 50 files
# 2025-06-20 08:25:22,405 - src.data_pipline.json_loader.json_loader_patent - INFO - Successfully loaded 50 documents from 50 files

# %%
json_files = []

# %%
documents[0][0]
# Out:
# Document(metadata={'doc_id': 'EP13899497B9W1', 'language': 'en', 'country': 'EP', 'doc_number': '3084761', 'application_number': '13899497.5', 'publication_date': '20250611', 'ipc_classes': 'G10L  19/038       20130101AFI20170426BHEP, G10L  19/07        20130101ALI20170426BHEP', 'file': 'EP13899497W1B9.xml', 'filePath': '/app/data/parsed/EPO/EPRTBJV2025000024001001/EPW1B9/EP13899497W1B9/EP13899497W1B9.json', 'title': 'AUDIO SIGNAL ENCODER', 'section': 'title'}, page_content='AUDIO SIGNAL ENCODER')

# %%
print(f"✅ Loaded {len(documents)} document segments from {len(json_files)} patent files")
# Out:
# ✅ Loaded 50 document segments from 0 patent files

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
chunker_config = ChunkerConfig(
    base_chunk_size=512,  # Adjust based on your needs
    chunk_overlap=50,
    min_chunk_size=100
)
chunker = TextChunker(tokenizer, config=chunker_config)
print("✅ TextChunker initialized")
# Out:
# ✅ TextChunker initialized

# %%
print("✂️ Chunking documents...")
chunked_docs = []

for docs in tqdm(documents, desc="Chunking"):
    for doc in tqdm(docs, desc="Chunking"):
        try:
            text = doc.page_content
            metadata = doc.metadata
            
            # Use your TextChunker to split the document
            chunks = chunker.chunk_text(text, use_semantic=True)
            
            # Create LangChain Document objects from chunks
            for i, chunk_text in enumerate(chunks):
                # Copy metadata and add chunk information
                chunk_metadata = metadata.copy()
                chunk_metadata.update({
                    "chunk_index": i,
                    "total_chunks": len(chunks)
                })
                
                chunked_docs.append(Document(
                    page_content=chunk_text,
                    metadata=chunk_metadata
                ))
        except Exception as e:
            logger.error(f"Error chunking document: {str(e)}")
# Out:
# ✂️ Chunking documents...
# Chunking:   0%|          | 0/50 [00:00<?, ?it/s]
# Chunking:   0%|          | 0/180 [00:00<?, ?it/s]
# 2025-06-20 08:26:30,094 - src.embeddings.text_Chunker - INFO - Input text has 5 tokens
# 2025-06-20 08:26:30,095 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,095 - src.embeddings.text_Chunker - INFO - Input text has 33 tokens
# 2025-06-20 08:26:30,096 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,096 - src.embeddings.text_Chunker - INFO - Input text has 33 tokens
# 2025-06-20 08:26:30,096 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,097 - src.embeddings.text_Chunker - INFO - Input text has 116 tokens
# 2025-06-20 08:26:30,097 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,098 - src.embeddings.text_Chunker - INFO - Input text has 37 tokens
# 2025-06-20 08:26:30,099 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,099 - src.embeddings.text_Chunker - INFO - Input text has 88 tokens
# 2025-06-20 08:26:30,099 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,100 - src.embeddings.text_Chunker - INFO - Input text has 30 tokens
# 2025-06-20 08:26:30,100 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,100 - src.embeddings.text_Chunker - INFO - Input text has 30 tokens
# 2025-06-20 08:26:30,101 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,101 - src.embeddings.text_Chunker - INFO - Input text has 74 tokens
# 2025-06-20 08:26:30,101 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,102 - src.embeddings.text_Chunker - INFO - Input text has 25 tokens
# 2025-06-20 08:26:30,102 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,102 - src.embeddings.text_Chunker - INFO - Input text has 40 tokens
# 2025-06-20 08:26:30,102 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,103 - src.embeddings.text_Chunker - INFO - Input text has 53 tokens
# 2025-06-20 08:26:30,103 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,103 - src.embeddings.text_Chunker - INFO - Input text has 47 tokens
# 2025-06-20 08:26:30,103 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,104 - src.embeddings.text_Chunker - INFO - Input text has 18 tokens
# 2025-06-20 08:26:30,104 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,104 - src.embeddings.text_Chunker - INFO - Input text has 96 tokens
# 2025-06-20 08:26:30,105 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,105 - src.embeddings.text_Chunker - INFO - Input text has 109 tokens
# 2025-06-20 08:26:30,106 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,106 - src.embeddings.text_Chunker - INFO - Input text has 106 tokens
# 2025-06-20 08:26:30,106 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,107 - src.embeddings.text_Chunker - INFO - Input text has 35 tokens
# 2025-06-20 08:26:30,107 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,107 - src.embeddings.text_Chunker - INFO - Input text has 112 tokens
# 2025-06-20 08:26:30,107 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,108 - src.embeddings.text_Chunker - INFO - Input text has 102 tokens
# 2025-06-20 08:26:30,108 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,108 - src.embeddings.text_Chunker - INFO - Input text has 32 tokens
# 2025-06-20 08:26:30,109 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,109 - src.embeddings.text_Chunker - INFO - Input text has 231 tokens
# 2025-06-20 08:26:30,109 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,110 - src.embeddings.text_Chunker - INFO - Input text has 81 tokens
# 2025-06-20 08:26:30,110 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,110 - src.embeddings.text_Chunker - INFO - Input text has 38 tokens
# 2025-06-20 08:26:30,110 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,111 - src.embeddings.text_Chunker - INFO - Input text has 77 tokens
# 2025-06-20 08:26:30,111 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,112 - src.embeddings.text_Chunker - INFO - Input text has 162 tokens
# 2025-06-20 08:26:30,112 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,112 - src.embeddings.text_Chunker - INFO - Input text has 64 tokens
# 2025-06-20 08:26:30,112 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,113 - src.embeddings.text_Chunker - INFO - Input text has 22 tokens
# 2025-06-20 08:26:30,113 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,113 - src.embeddings.text_Chunker - INFO - Input text has 27 tokens
# 2025-06-20 08:26:30,113 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,114 - src.embeddings.text_Chunker - INFO - Input text has 76 tokens
# 2025-06-20 08:26:30,114 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,115 - src.embeddings.text_Chunker - INFO - Input text has 121 tokens
# 2025-06-20 08:26:30,115 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,115 - src.embeddings.text_Chunker - INFO - Input text has 50 tokens
# 2025-06-20 08:26:30,115 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,116 - src.embeddings.text_Chunker - INFO - Input text has 155 tokens
# 2025-06-20 08:26:30,116 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,116 - src.embeddings.text_Chunker - INFO - Input text has 19 tokens
# 2025-06-20 08:26:30,116 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,117 - src.embeddings.text_Chunker - INFO - Input text has 29 tokens
# 2025-06-20 08:26:30,117 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,117 - src.embeddings.text_Chunker - INFO - Input text has 84 tokens
# 2025-06-20 08:26:30,117 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,118 - src.embeddings.text_Chunker - INFO - Input text has 84 tokens
# 2025-06-20 08:26:30,118 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,118 - src.embeddings.text_Chunker - INFO - Input text has 91 tokens
# 2025-06-20 08:26:30,118 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,119 - src.embeddings.text_Chunker - INFO - Input text has 83 tokens
# 2025-06-20 08:26:30,119 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,119 - src.embeddings.text_Chunker - INFO - Input text has 21 tokens
# 2025-06-20 08:26:30,119 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,120 - src.embeddings.text_Chunker - INFO - Input text has 35 tokens
# 2025-06-20 08:26:30,120 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,120 - src.embeddings.text_Chunker - INFO - Input text has 144 tokens
# 2025-06-20 08:26:30,120 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,121 - src.embeddings.text_Chunker - INFO - Input text has 52 tokens
# 2025-06-20 08:26:30,121 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,121 - src.embeddings.text_Chunker - INFO - Input text has 24 tokens
# 2025-06-20 08:26:30,121 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,121 - src.embeddings.text_Chunker - INFO - Input text has 50 tokens
# 2025-06-20 08:26:30,121 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,122 - src.embeddings.text_Chunker - INFO - Input text has 22 tokens
# 2025-06-20 08:26:30,122 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,122 - src.embeddings.text_Chunker - INFO - Input text has 32 tokens
# 2025-06-20 08:26:30,122 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,123 - src.embeddings.text_Chunker - INFO - Input text has 80 tokens
# 2025-06-20 08:26:30,123 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,123 - src.embeddings.text_Chunker - INFO - Input text has 22 tokens
# 2025-06-20 08:26:30,123 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,124 - src.embeddings.text_Chunker - INFO - Input text has 17 tokens
# 2025-06-20 08:26:30,124 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,124 - src.embeddings.text_Chunker - INFO - Input text has 21 tokens
# 2025-06-20 08:26:30,124 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,125 - src.embeddings.text_Chunker - INFO - Input text has 13 tokens
# 2025-06-20 08:26:30,125 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,125 - src.embeddings.text_Chunker - INFO - Input text has 88 tokens
# 2025-06-20 08:26:30,125 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,127 - src.embeddings.text_Chunker - INFO - Input text has 170 tokens
# 2025-06-20 08:26:30,127 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,127 - src.embeddings.text_Chunker - INFO - Input text has 30 tokens
# 2025-06-20 08:26:30,127 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,128 - src.embeddings.text_Chunker - INFO - Input text has 123 tokens
# 2025-06-20 08:26:30,128 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,128 - src.embeddings.text_Chunker - INFO - Input text has 71 tokens
# 2025-06-20 08:26:30,128 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,129 - src.embeddings.text_Chunker - INFO - Input text has 95 tokens
# 2025-06-20 08:26:30,129 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,129 - src.embeddings.text_Chunker - INFO - Input text has 80 tokens
# 2025-06-20 08:26:30,129 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,130 - src.embeddings.text_Chunker - INFO - Input text has 380 tokens
# 2025-06-20 08:26:30,130 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,130 - src.embeddings.text_Chunker - INFO - Input text has 100 tokens
# 2025-06-20 08:26:30,130 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,131 - src.embeddings.text_Chunker - INFO - Input text has 111 tokens
# 2025-06-20 08:26:30,131 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,131 - src.embeddings.text_Chunker - INFO - Input text has 119 tokens
# 2025-06-20 08:26:30,132 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,132 - src.embeddings.text_Chunker - INFO - Input text has 64 tokens
# 2025-06-20 08:26:30,132 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,132 - src.embeddings.text_Chunker - INFO - Input text has 142 tokens
# 2025-06-20 08:26:30,133 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,133 - src.embeddings.text_Chunker - INFO - Input text has 14 tokens
# 2025-06-20 08:26:30,133 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,133 - src.embeddings.text_Chunker - INFO - Input text has 85 tokens
# 2025-06-20 08:26:30,134 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,134 - src.embeddings.text_Chunker - INFO - Input text has 23 tokens
# 2025-06-20 08:26:30,134 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,134 - src.embeddings.text_Chunker - INFO - Input text has 18 tokens
# 2025-06-20 08:26:30,134 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,135 - src.embeddings.text_Chunker - INFO - Input text has 19 tokens
# 2025-06-20 08:26:30,135 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,135 - src.embeddings.text_Chunker - INFO - Input text has 21 tokens
# 2025-06-20 08:26:30,135 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,136 - src.embeddings.text_Chunker - INFO - Input text has 16 tokens
# 2025-06-20 08:26:30,136 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,136 - src.embeddings.text_Chunker - INFO - Input text has 36 tokens
# 2025-06-20 08:26:30,136 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,137 - src.embeddings.text_Chunker - INFO - Input text has 33 tokens
# 2025-06-20 08:26:30,137 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,137 - src.embeddings.text_Chunker - INFO - Input text has 47 tokens
# 2025-06-20 08:26:30,137 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,138 - src.embeddings.text_Chunker - INFO - Input text has 41 tokens
# 2025-06-20 08:26:30,138 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,138 - src.embeddings.text_Chunker - INFO - Input text has 25 tokens
# 2025-06-20 08:26:30,138 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,139 - src.embeddings.text_Chunker - INFO - Input text has 33 tokens
# 2025-06-20 08:26:30,139 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,139 - src.embeddings.text_Chunker - INFO - Input text has 53 tokens
# 2025-06-20 08:26:30,139 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,140 - src.embeddings.text_Chunker - INFO - Input text has 123 tokens
# 2025-06-20 08:26:30,140 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,140 - src.embeddings.text_Chunker - INFO - Input text has 15 tokens
# 2025-06-20 08:26:30,140 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,141 - src.embeddings.text_Chunker - INFO - Input text has 28 tokens
# 2025-06-20 08:26:30,141 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,141 - src.embeddings.text_Chunker - INFO - Input text has 42 tokens
# 2025-06-20 08:26:30,141 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,142 - src.embeddings.text_Chunker - INFO - Input text has 35 tokens
# 2025-06-20 08:26:30,142 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,142 - src.embeddings.text_Chunker - INFO - Input text has 24 tokens
# 2025-06-20 08:26:30,142 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,143 - src.embeddings.text_Chunker - INFO - Input text has 79 tokens
# 2025-06-20 08:26:30,143 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,143 - src.embeddings.text_Chunker - INFO - Input text has 51 tokens
# 2025-06-20 08:26:30,143 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,144 - src.embeddings.text_Chunker - INFO - Input text has 147 tokens
# 2025-06-20 08:26:30,144 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,144 - src.embeddings.text_Chunker - INFO - Input text has 82 tokens
# 2025-06-20 08:26:30,144 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,145 - src.embeddings.text_Chunker - INFO - Input text has 76 tokens
# 2025-06-20 08:26:30,145 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,145 - src.embeddings.text_Chunker - INFO - Input text has 63 tokens
# 2025-06-20 08:26:30,145 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,146 - src.embeddings.text_Chunker - INFO - Input text has 34 tokens
# 2025-06-20 08:26:30,146 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,146 - src.embeddings.text_Chunker - INFO - Input text has 64 tokens
# 2025-06-20 08:26:30,146 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,147 - src.embeddings.text_Chunker - INFO - Input text has 23 tokens
# 2025-06-20 08:26:30,147 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,147 - src.embeddings.text_Chunker - INFO - Input text has 13 tokens
# 2025-06-20 08:26:30,147 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,148 - src.embeddings.text_Chunker - INFO - Input text has 26 tokens
# 2025-06-20 08:26:30,148 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,148 - src.embeddings.text_Chunker - INFO - Input text has 37 tokens
# 2025-06-20 08:26:30,148 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,149 - src.embeddings.text_Chunker - INFO - Input text has 30 tokens
# 2025-06-20 08:26:30,149 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,149 - src.embeddings.text_Chunker - INFO - Input text has 46 tokens
# 2025-06-20 08:26:30,149 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,150 - src.embeddings.text_Chunker - INFO - Input text has 45 tokens
# 2025-06-20 08:26:30,150 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,150 - src.embeddings.text_Chunker - INFO - Input text has 60 tokens
# 2025-06-20 08:26:30,150 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,151 - src.embeddings.text_Chunker - INFO - Input text has 38 tokens
# 2025-06-20 08:26:30,151 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,151 - src.embeddings.text_Chunker - INFO - Input text has 30 tokens
# 2025-06-20 08:26:30,151 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,152 - src.embeddings.text_Chunker - INFO - Input text has 50 tokens
# 2025-06-20 08:26:30,152 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,152 - src.embeddings.text_Chunker - INFO - Input text has 27 tokens
# 2025-06-20 08:26:30,152 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,153 - src.embeddings.text_Chunker - INFO - Input text has 18 tokens
# 2025-06-20 08:26:30,153 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,153 - src.embeddings.text_Chunker - INFO - Input text has 53 tokens
# 2025-06-20 08:26:30,153 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,153 - src.embeddings.text_Chunker - INFO - Input text has 128 tokens
# 2025-06-20 08:26:30,154 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,154 - src.embeddings.text_Chunker - INFO - Input text has 72 tokens
# 2025-06-20 08:26:30,154 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,154 - src.embeddings.text_Chunker - INFO - Input text has 63 tokens
# 2025-06-20 08:26:30,155 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,155 - src.embeddings.text_Chunker - INFO - Input text has 59 tokens
# 2025-06-20 08:26:30,155 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,155 - src.embeddings.text_Chunker - INFO - Input text has 114 tokens
# 2025-06-20 08:26:30,156 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,156 - src.embeddings.text_Chunker - INFO - Input text has 90 tokens
# 2025-06-20 08:26:30,156 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,156 - src.embeddings.text_Chunker - INFO - Input text has 28 tokens
# 2025-06-20 08:26:30,157 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,157 - src.embeddings.text_Chunker - INFO - Input text has 150 tokens
# 2025-06-20 08:26:30,157 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,157 - src.embeddings.text_Chunker - INFO - Input text has 36 tokens
# 2025-06-20 08:26:30,158 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,158 - src.embeddings.text_Chunker - INFO - Input text has 40 tokens
# 2025-06-20 08:26:30,158 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,159 - src.embeddings.text_Chunker - INFO - Input text has 34 tokens
# 2025-06-20 08:26:30,159 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,159 - src.embeddings.text_Chunker - INFO - Input text has 88 tokens
# 2025-06-20 08:26:30,159 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,160 - src.embeddings.text_Chunker - INFO - Input text has 81 tokens
# 2025-06-20 08:26:30,160 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,160 - src.embeddings.text_Chunker - INFO - Input text has 61 tokens
# 2025-06-20 08:26:30,160 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,161 - src.embeddings.text_Chunker - INFO - Input text has 76 tokens
# 2025-06-20 08:26:30,161 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,161 - src.embeddings.text_Chunker - INFO - Input text has 65 tokens
# 2025-06-20 08:26:30,161 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,162 - src.embeddings.text_Chunker - INFO - Input text has 53 tokens
# 2025-06-20 08:26:30,162 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,162 - src.embeddings.text_Chunker - INFO - Input text has 20 tokens
# 2025-06-20 08:26:30,162 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,163 - src.embeddings.text_Chunker - INFO - Input text has 67 tokens
# 2025-06-20 08:26:30,163 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,163 - src.embeddings.text_Chunker - INFO - Input text has 18 tokens
# 2025-06-20 08:26:30,163 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,163 - src.embeddings.text_Chunker - INFO - Input text has 19 tokens
# 2025-06-20 08:26:30,164 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,164 - src.embeddings.text_Chunker - INFO - Input text has 34 tokens
# 2025-06-20 08:26:30,164 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,164 - src.embeddings.text_Chunker - INFO - Input text has 65 tokens
# 2025-06-20 08:26:30,165 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,165 - src.embeddings.text_Chunker - INFO - Input text has 32 tokens
# 2025-06-20 08:26:30,165 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,165 - src.embeddings.text_Chunker - INFO - Input text has 30 tokens
# 2025-06-20 08:26:30,166 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,166 - src.embeddings.text_Chunker - INFO - Input text has 90 tokens
# 2025-06-20 08:26:30,166 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,167 - src.embeddings.text_Chunker - INFO - Input text has 83 tokens
# 2025-06-20 08:26:30,167 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,167 - src.embeddings.text_Chunker - INFO - Input text has 21 tokens
# 2025-06-20 08:26:30,167 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,167 - src.embeddings.text_Chunker - INFO - Input text has 40 tokens
# 2025-06-20 08:26:30,168 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,168 - src.embeddings.text_Chunker - INFO - Input text has 40 tokens
# 2025-06-20 08:26:30,168 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,168 - src.embeddings.text_Chunker - INFO - Input text has 20 tokens
# 2025-06-20 08:26:30,169 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,169 - src.embeddings.text_Chunker - INFO - Input text has 26 tokens
# 2025-06-20 08:26:30,169 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,169 - src.embeddings.text_Chunker - INFO - Input text has 38 tokens
# 2025-06-20 08:26:30,170 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,170 - src.embeddings.text_Chunker - INFO - Input text has 20 tokens
# 2025-06-20 08:26:30,170 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,170 - src.embeddings.text_Chunker - INFO - Input text has 35 tokens
# 2025-06-20 08:26:30,171 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,171 - src.embeddings.text_Chunker - INFO - Input text has 28 tokens
# 2025-06-20 08:26:30,171 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,171 - src.embeddings.text_Chunker - INFO - Input text has 27 tokens
# 2025-06-20 08:26:30,172 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,172 - src.embeddings.text_Chunker - INFO - Input text has 27 tokens
# 2025-06-20 08:26:30,172 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,173 - src.embeddings.text_Chunker - INFO - Input text has 46 tokens
# 2025-06-20 08:26:30,173 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,173 - src.embeddings.text_Chunker - INFO - Input text has 23 tokens
# 2025-06-20 08:26:30,173 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,173 - src.embeddings.text_Chunker - INFO - Input text has 26 tokens
# 2025-06-20 08:26:30,174 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,174 - src.embeddings.text_Chunker - INFO - Input text has 38 tokens
# 2025-06-20 08:26:30,174 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,174 - src.embeddings.text_Chunker - INFO - Input text has 19 tokens
# 2025-06-20 08:26:30,175 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,175 - src.embeddings.text_Chunker - INFO - Input text has 58 tokens
# 2025-06-20 08:26:30,175 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,175 - src.embeddings.text_Chunker - INFO - Input text has 22 tokens
# 2025-06-20 08:26:30,175 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,176 - src.embeddings.text_Chunker - INFO - Input text has 38 tokens
# 2025-06-20 08:26:30,176 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,176 - src.embeddings.text_Chunker - INFO - Input text has 50 tokens
# 2025-06-20 08:26:30,176 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,177 - src.embeddings.text_Chunker - INFO - Input text has 27 tokens
# 2025-06-20 08:26:30,177 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,177 - src.embeddings.text_Chunker - INFO - Input text has 33 tokens
# 2025-06-20 08:26:30,178 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,178 - src.embeddings.text_Chunker - INFO - Input text has 67 tokens
# 2025-06-20 08:26:30,178 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,178 - src.embeddings.text_Chunker - INFO - Input text has 47 tokens
# 2025-06-20 08:26:30,178 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,179 - src.embeddings.text_Chunker - INFO - Input text has 80 tokens
# 2025-06-20 08:26:30,179 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,180 - src.embeddings.text_Chunker - INFO - Input text has 146 tokens
# 2025-06-20 08:26:30,180 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,180 - src.embeddings.text_Chunker - INFO - Input text has 104 tokens
# 2025-06-20 08:26:30,180 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,180 - src.embeddings.text_Chunker - INFO - Input text has 33 tokens
# 2025-06-20 08:26:30,180 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,181 - src.embeddings.text_Chunker - INFO - Input text has 47 tokens
# 2025-06-20 08:26:30,181 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,181 - src.embeddings.text_Chunker - INFO - Input text has 33 tokens
# 2025-06-20 08:26:30,182 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,182 - src.embeddings.text_Chunker - INFO - Input text has 170 tokens
# 2025-06-20 08:26:30,182 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,182 - src.embeddings.text_Chunker - INFO - Input text has 104 tokens
# 2025-06-20 08:26:30,183 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,183 - src.embeddings.text_Chunker - INFO - Input text has 133 tokens
# 2025-06-20 08:26:30,183 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,184 - src.embeddings.text_Chunker - INFO - Input text has 72 tokens
# 2025-06-20 08:26:30,184 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,184 - src.embeddings.text_Chunker - INFO - Input text has 116 tokens
# 2025-06-20 08:26:30,184 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,185 - src.embeddings.text_Chunker - INFO - Input text has 29 tokens
# 2025-06-20 08:26:30,185 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,185 - src.embeddings.text_Chunker - INFO - Input text has 134 tokens
# 2025-06-20 08:26:30,185 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,186 - src.embeddings.text_Chunker - INFO - Input text has 79 tokens
# 2025-06-20 08:26:30,186 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# Token indices sequence length is longer than the specified maximum sequence length for this model (691 > 512). Running this sequence through the model will result in indexing errors
# 2025-06-20 08:26:30,187 - src.embeddings.text_Chunker - INFO - Input text has 691 tokens
# 2025-06-20 08:26:30,187 - src.embeddings.text_Chunker - INFO - Using chunk size: 346 tokens, overlap: 50
# 2025-06-20 08:26:30,190 - src.embeddings.text_Chunker - INFO - Input text has 38 tokens
# 2025-06-20 08:26:30,190 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,191 - src.embeddings.text_Chunker - INFO - Input text has 59 tokens
# 2025-06-20 08:26:30,191 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,191 - src.embeddings.text_Chunker - INFO - Input text has 82 tokens
# 2025-06-20 08:26:30,191 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,192 - src.embeddings.text_Chunker - INFO - Input text has 791 tokens
# 2025-06-20 08:26:30,193 - src.embeddings.text_Chunker - INFO - Using chunk size: 396 tokens, overlap: 50
# 2025-06-20 08:26:30,195 - src.embeddings.text_Chunker - INFO - Input text has 129 tokens
# 2025-06-20 08:26:30,195 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,196 - src.embeddings.text_Chunker - INFO - Input text has 66 tokens
# 2025-06-20 08:26:30,196 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,196 - src.embeddings.text_Chunker - INFO - Input text has 82 tokens
# 2025-06-20 08:26:30,196 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# Chunking:   0%|          | 0/16 [00:00<?, ?it/s]
# 2025-06-20 08:26:30,200 - src.embeddings.text_Chunker - INFO - Input text has 5 tokens
# 2025-06-20 08:26:30,200 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,201 - src.embeddings.text_Chunker - INFO - Input text has 479 tokens
# 2025-06-20 08:26:30,201 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,201 - src.embeddings.text_Chunker - INFO - Input text has 149 tokens
# 2025-06-20 08:26:30,201 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,202 - src.embeddings.text_Chunker - INFO - Input text has 98 tokens
# 2025-06-20 08:26:30,202 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,202 - src.embeddings.text_Chunker - INFO - Input text has 142 tokens
# 2025-06-20 08:26:30,202 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,203 - src.embeddings.text_Chunker - INFO - Input text has 148 tokens
# 2025-06-20 08:26:30,203 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,203 - src.embeddings.text_Chunker - INFO - Input text has 83 tokens
# 2025-06-20 08:26:30,204 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,204 - src.embeddings.text_Chunker - INFO - Input text has 103 tokens
# 2025-06-20 08:26:30,204 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,204 - src.embeddings.text_Chunker - INFO - Input text has 92 tokens
# 2025-06-20 08:26:30,205 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,205 - src.embeddings.text_Chunker - INFO - Input text has 94 tokens
# 2025-06-20 08:26:30,205 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,205 - src.embeddings.text_Chunker - INFO - Input text has 60 tokens
# 2025-06-20 08:26:30,206 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,206 - src.embeddings.text_Chunker - INFO - Input text has 62 tokens
# 2025-06-20 08:26:30,206 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,206 - src.embeddings.text_Chunker - INFO - Input text has 69 tokens
# 2025-06-20 08:26:30,207 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,207 - src.embeddings.text_Chunker - INFO - Input text has 43 tokens
# 2025-06-20 08:26:30,207 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,207 - src.embeddings.text_Chunker - INFO - Input text has 51 tokens
# 2025-06-20 08:26:30,208 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,208 - src.embeddings.text_Chunker - INFO - Input text has 84 tokens
# 2025-06-20 08:26:30,208 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# Chunking:   0%|          | 0/2 [00:00<?, ?it/s]
# 2025-06-20 08:26:30,211 - src.embeddings.text_Chunker - INFO - Input text has 15 tokens
# 2025-06-20 08:26:30,211 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,212 - src.embeddings.text_Chunker - INFO - Input text has 72 tokens
# 2025-06-20 08:26:30,212 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# Chunking:   0%|          | 0/2 [00:00<?, ?it/s]
# 2025-06-20 08:26:30,215 - src.embeddings.text_Chunker - INFO - Input text has 12 tokens
# 2025-06-20 08:26:30,215 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,215 - src.embeddings.text_Chunker - INFO - Input text has 255 tokens
# 2025-06-20 08:26:30,215 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# Chunking:   0%|          | 0/16 [00:00<?, ?it/s]
# 2025-06-20 08:26:30,218 - src.embeddings.text_Chunker - INFO - Input text has 13 tokens
# 2025-06-20 08:26:30,218 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,219 - src.embeddings.text_Chunker - INFO - Input text has 219 tokens
# 2025-06-20 08:26:30,219 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,219 - src.embeddings.text_Chunker - INFO - Input text has 172 tokens
# 2025-06-20 08:26:30,219 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,220 - src.embeddings.text_Chunker - INFO - Input text has 18 tokens
# 2025-06-20 08:26:30,220 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,220 - src.embeddings.text_Chunker - INFO - Input text has 19 tokens
# 2025-06-20 08:26:30,220 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,221 - src.embeddings.text_Chunker - INFO - Input text has 194 tokens
# 2025-06-20 08:26:30,221 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,221 - src.embeddings.text_Chunker - INFO - Input text has 12 tokens
# 2025-06-20 08:26:30,221 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,222 - src.embeddings.text_Chunker - INFO - Input text has 12 tokens
# 2025-06-20 08:26:30,222 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,222 - src.embeddings.text_Chunker - INFO - Input text has 12 tokens
# 2025-06-20 08:26:30,222 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,223 - src.embeddings.text_Chunker - INFO - Input text has 7 tokens
# 2025-06-20 08:26:30,223 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,223 - src.embeddings.text_Chunker - INFO - Input text has 12 tokens
# 2025-06-20 08:26:30,223 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,224 - src.embeddings.text_Chunker - INFO - Input text has 452 tokens
# 2025-06-20 08:26:30,224 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,225 - src.embeddings.text_Chunker - INFO - Input text has 65 tokens
# 2025-06-20 08:26:30,225 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,225 - src.embeddings.text_Chunker - INFO - Input text has 76 tokens
# 2025-06-20 08:26:30,225 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,226 - src.embeddings.text_Chunker - INFO - Input text has 63 tokens
# 2025-06-20 08:26:30,226 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,226 - src.embeddings.text_Chunker - INFO - Input text has 32 tokens
# 2025-06-20 08:26:30,226 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# Chunking:   0%|          | 0/111 [00:00<?, ?it/s]
# 2025-06-20 08:26:30,229 - src.embeddings.text_Chunker - INFO - Input text has 20 tokens
# 2025-06-20 08:26:30,230 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,230 - src.embeddings.text_Chunker - INFO - Input text has 56 tokens
# 2025-06-20 08:26:30,230 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,230 - src.embeddings.text_Chunker - INFO - Input text has 70 tokens
# 2025-06-20 08:26:30,231 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,231 - src.embeddings.text_Chunker - INFO - Input text has 103 tokens
# 2025-06-20 08:26:30,231 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,231 - src.embeddings.text_Chunker - INFO - Input text has 134 tokens
# 2025-06-20 08:26:30,232 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,232 - src.embeddings.text_Chunker - INFO - Input text has 105 tokens
# 2025-06-20 08:26:30,232 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,232 - src.embeddings.text_Chunker - INFO - Input text has 110 tokens
# 2025-06-20 08:26:30,233 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,233 - src.embeddings.text_Chunker - INFO - Input text has 66 tokens
# 2025-06-20 08:26:30,233 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,233 - src.embeddings.text_Chunker - INFO - Input text has 56 tokens
# 2025-06-20 08:26:30,233 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,234 - src.embeddings.text_Chunker - INFO - Input text has 51 tokens
# 2025-06-20 08:26:30,234 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,234 - src.embeddings.text_Chunker - INFO - Input text has 47 tokens
# 2025-06-20 08:26:30,234 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,235 - src.embeddings.text_Chunker - INFO - Input text has 79 tokens
# 2025-06-20 08:26:30,235 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,235 - src.embeddings.text_Chunker - INFO - Input text has 118 tokens
# 2025-06-20 08:26:30,235 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,236 - src.embeddings.text_Chunker - INFO - Input text has 73 tokens
# 2025-06-20 08:26:30,236 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,236 - src.embeddings.text_Chunker - INFO - Input text has 48 tokens
# 2025-06-20 08:26:30,237 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,237 - src.embeddings.text_Chunker - INFO - Input text has 85 tokens
# 2025-06-20 08:26:30,237 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,237 - src.embeddings.text_Chunker - INFO - Input text has 62 tokens
# 2025-06-20 08:26:30,238 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,238 - src.embeddings.text_Chunker - INFO - Input text has 110 tokens
# 2025-06-20 08:26:30,238 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,238 - src.embeddings.text_Chunker - INFO - Input text has 28 tokens
# 2025-06-20 08:26:30,239 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,239 - src.embeddings.text_Chunker - INFO - Input text has 58 tokens
# 2025-06-20 08:26:30,239 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,240 - src.embeddings.text_Chunker - INFO - Input text has 1840 tokens
# 2025-06-20 08:26:30,241 - src.embeddings.text_Chunker - INFO - Using chunk size: 460 tokens, overlap: 50
# 2025-06-20 08:26:30,245 - src.embeddings.text_Chunker - INFO - Input text has 553 tokens
# 2025-06-20 08:26:30,245 - src.embeddings.text_Chunker - INFO - Using chunk size: 277 tokens, overlap: 50
# 2025-06-20 08:26:30,247 - src.embeddings.text_Chunker - INFO - Input text has 108 tokens
# 2025-06-20 08:26:30,247 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,248 - src.embeddings.text_Chunker - INFO - Input text has 129 tokens
# 2025-06-20 08:26:30,248 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,248 - src.embeddings.text_Chunker - INFO - Input text has 127 tokens
# 2025-06-20 08:26:30,248 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,249 - src.embeddings.text_Chunker - INFO - Input text has 56 tokens
# 2025-06-20 08:26:30,249 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,249 - src.embeddings.text_Chunker - INFO - Input text has 56 tokens
# 2025-06-20 08:26:30,249 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,250 - src.embeddings.text_Chunker - INFO - Input text has 176 tokens
# 2025-06-20 08:26:30,250 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,250 - src.embeddings.text_Chunker - INFO - Input text has 36 tokens
# 2025-06-20 08:26:30,251 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,251 - src.embeddings.text_Chunker - INFO - Input text has 14 tokens
# 2025-06-20 08:26:30,251 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,251 - src.embeddings.text_Chunker - INFO - Input text has 159 tokens
# 2025-06-20 08:26:30,252 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,252 - src.embeddings.text_Chunker - INFO - Input text has 23 tokens
# 2025-06-20 08:26:30,252 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,252 - src.embeddings.text_Chunker - INFO - Input text has 64 tokens
# 2025-06-20 08:26:30,252 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,253 - src.embeddings.text_Chunker - INFO - Input text has 90 tokens
# 2025-06-20 08:26:30,253 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,253 - src.embeddings.text_Chunker - INFO - Input text has 165 tokens
# 2025-06-20 08:26:30,254 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,254 - src.embeddings.text_Chunker - INFO - Input text has 72 tokens
# 2025-06-20 08:26:30,254 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,254 - src.embeddings.text_Chunker - INFO - Input text has 21 tokens
# 2025-06-20 08:26:30,255 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,255 - src.embeddings.text_Chunker - INFO - Input text has 179 tokens
# 2025-06-20 08:26:30,255 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,255 - src.embeddings.text_Chunker - INFO - Input text has 61 tokens
# 2025-06-20 08:26:30,256 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,256 - src.embeddings.text_Chunker - INFO - Input text has 72 tokens
# 2025-06-20 08:26:30,256 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,257 - src.embeddings.text_Chunker - INFO - Input text has 30 tokens
# 2025-06-20 08:26:30,257 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,257 - src.embeddings.text_Chunker - INFO - Input text has 180 tokens
# 2025-06-20 08:26:30,257 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,258 - src.embeddings.text_Chunker - INFO - Input text has 82 tokens
# 2025-06-20 08:26:30,258 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,258 - src.embeddings.text_Chunker - INFO - Input text has 49 tokens
# 2025-06-20 08:26:30,258 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,259 - src.embeddings.text_Chunker - INFO - Input text has 260 tokens
# 2025-06-20 08:26:30,259 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,260 - src.embeddings.text_Chunker - INFO - Input text has 228 tokens
# 2025-06-20 08:26:30,260 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,260 - src.embeddings.text_Chunker - INFO - Input text has 142 tokens
# 2025-06-20 08:26:30,260 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,261 - src.embeddings.text_Chunker - INFO - Input text has 78 tokens
# 2025-06-20 08:26:30,261 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,261 - src.embeddings.text_Chunker - INFO - Input text has 67 tokens
# 2025-06-20 08:26:30,261 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,261 - src.embeddings.text_Chunker - INFO - Input text has 107 tokens
# 2025-06-20 08:26:30,262 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:30,262 - src.embeddings.text_Chunker - INFO - Input text has 87 tokens
# 2025-06-20 08:26:30,262 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# ...
# 2025-06-20 08:26:31,047 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,048 - src.embeddings.text_Chunker - INFO - Input text has 41 tokens
# 2025-06-20 08:26:31,048 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,048 - src.embeddings.text_Chunker - INFO - Input text has 62 tokens
# 2025-06-20 08:26:31,048 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,049 - src.embeddings.text_Chunker - INFO - Input text has 17 tokens
# 2025-06-20 08:26:31,049 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,049 - src.embeddings.text_Chunker - INFO - Input text has 73 tokens
# 2025-06-20 08:26:31,050 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,050 - src.embeddings.text_Chunker - INFO - Input text has 79 tokens
# 2025-06-20 08:26:31,050 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,051 - src.embeddings.text_Chunker - INFO - Input text has 38 tokens
# 2025-06-20 08:26:31,051 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,052 - src.embeddings.text_Chunker - INFO - Input text has 322 tokens
# 2025-06-20 08:26:31,052 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,052 - src.embeddings.text_Chunker - INFO - Input text has 63 tokens
# 2025-06-20 08:26:31,052 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,053 - src.embeddings.text_Chunker - INFO - Input text has 47 tokens
# 2025-06-20 08:26:31,053 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,053 - src.embeddings.text_Chunker - INFO - Input text has 37 tokens
# 2025-06-20 08:26:31,053 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,054 - src.embeddings.text_Chunker - INFO - Input text has 46 tokens
# 2025-06-20 08:26:31,054 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,054 - src.embeddings.text_Chunker - INFO - Input text has 61 tokens
# 2025-06-20 08:26:31,055 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,055 - src.embeddings.text_Chunker - INFO - Input text has 76 tokens
# 2025-06-20 08:26:31,055 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,056 - src.embeddings.text_Chunker - INFO - Input text has 61 tokens
# 2025-06-20 08:26:31,056 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,056 - src.embeddings.text_Chunker - INFO - Input text has 25 tokens
# 2025-06-20 08:26:31,056 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,057 - src.embeddings.text_Chunker - INFO - Input text has 38 tokens
# 2025-06-20 08:26:31,057 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,057 - src.embeddings.text_Chunker - INFO - Input text has 15 tokens
# 2025-06-20 08:26:31,057 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,058 - src.embeddings.text_Chunker - INFO - Input text has 118 tokens
# 2025-06-20 08:26:31,058 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,058 - src.embeddings.text_Chunker - INFO - Input text has 54 tokens
# 2025-06-20 08:26:31,058 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# Chunking:   0%|          | 0/6 [00:00<?, ?it/s]
# 2025-06-20 08:26:31,062 - src.embeddings.text_Chunker - INFO - Input text has 18 tokens
# 2025-06-20 08:26:31,063 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,064 - src.embeddings.text_Chunker - INFO - Input text has 495 tokens
# 2025-06-20 08:26:31,064 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,064 - src.embeddings.text_Chunker - INFO - Input text has 10 tokens
# 2025-06-20 08:26:31,065 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,065 - src.embeddings.text_Chunker - INFO - Input text has 10 tokens
# 2025-06-20 08:26:31,065 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,065 - src.embeddings.text_Chunker - INFO - Input text has 10 tokens
# 2025-06-20 08:26:31,065 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,066 - src.embeddings.text_Chunker - INFO - Input text has 8 tokens
# 2025-06-20 08:26:31,066 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# Chunking:   0%|          | 0/62 [00:00<?, ?it/s]
# 2025-06-20 08:26:31,069 - src.embeddings.text_Chunker - INFO - Input text has 4 tokens
# 2025-06-20 08:26:31,069 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,070 - src.embeddings.text_Chunker - INFO - Input text has 40 tokens
# 2025-06-20 08:26:31,070 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,070 - src.embeddings.text_Chunker - INFO - Input text has 96 tokens
# 2025-06-20 08:26:31,071 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,071 - src.embeddings.text_Chunker - INFO - Input text has 99 tokens
# 2025-06-20 08:26:31,071 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,072 - src.embeddings.text_Chunker - INFO - Input text has 57 tokens
# 2025-06-20 08:26:31,072 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,072 - src.embeddings.text_Chunker - INFO - Input text has 65 tokens
# 2025-06-20 08:26:31,072 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,073 - src.embeddings.text_Chunker - INFO - Input text has 98 tokens
# 2025-06-20 08:26:31,073 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,074 - src.embeddings.text_Chunker - INFO - Input text has 139 tokens
# 2025-06-20 08:26:31,074 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,074 - src.embeddings.text_Chunker - INFO - Input text has 129 tokens
# 2025-06-20 08:26:31,074 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,075 - src.embeddings.text_Chunker - INFO - Input text has 157 tokens
# 2025-06-20 08:26:31,075 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,075 - src.embeddings.text_Chunker - INFO - Input text has 92 tokens
# 2025-06-20 08:26:31,076 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,076 - src.embeddings.text_Chunker - INFO - Input text has 35 tokens
# 2025-06-20 08:26:31,076 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,076 - src.embeddings.text_Chunker - INFO - Input text has 31 tokens
# 2025-06-20 08:26:31,077 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,077 - src.embeddings.text_Chunker - INFO - Input text has 60 tokens
# 2025-06-20 08:26:31,077 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,078 - src.embeddings.text_Chunker - INFO - Input text has 41 tokens
# 2025-06-20 08:26:31,078 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,078 - src.embeddings.text_Chunker - INFO - Input text has 39 tokens
# 2025-06-20 08:26:31,078 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,079 - src.embeddings.text_Chunker - INFO - Input text has 30 tokens
# 2025-06-20 08:26:31,079 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,079 - src.embeddings.text_Chunker - INFO - Input text has 42 tokens
# 2025-06-20 08:26:31,079 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,080 - src.embeddings.text_Chunker - INFO - Input text has 9 tokens
# 2025-06-20 08:26:31,080 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,080 - src.embeddings.text_Chunker - INFO - Input text has 149 tokens
# 2025-06-20 08:26:31,081 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,081 - src.embeddings.text_Chunker - INFO - Input text has 9 tokens
# 2025-06-20 08:26:31,081 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,082 - src.embeddings.text_Chunker - INFO - Input text has 147 tokens
# 2025-06-20 08:26:31,082 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,082 - src.embeddings.text_Chunker - INFO - Input text has 56 tokens
# 2025-06-20 08:26:31,082 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,083 - src.embeddings.text_Chunker - INFO - Input text has 9 tokens
# 2025-06-20 08:26:31,083 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,084 - src.embeddings.text_Chunker - INFO - Input text has 140 tokens
# 2025-06-20 08:26:31,084 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,084 - src.embeddings.text_Chunker - INFO - Input text has 9 tokens
# 2025-06-20 08:26:31,084 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,085 - src.embeddings.text_Chunker - INFO - Input text has 116 tokens
# 2025-06-20 08:26:31,085 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,085 - src.embeddings.text_Chunker - INFO - Input text has 149 tokens
# 2025-06-20 08:26:31,086 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,086 - src.embeddings.text_Chunker - INFO - Input text has 204 tokens
# 2025-06-20 08:26:31,086 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,087 - src.embeddings.text_Chunker - INFO - Input text has 192 tokens
# 2025-06-20 08:26:31,087 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,087 - src.embeddings.text_Chunker - INFO - Input text has 321 tokens
# 2025-06-20 08:26:31,088 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,088 - src.embeddings.text_Chunker - INFO - Input text has 195 tokens
# 2025-06-20 08:26:31,088 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,089 - src.embeddings.text_Chunker - INFO - Input text has 69 tokens
# 2025-06-20 08:26:31,089 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,089 - src.embeddings.text_Chunker - INFO - Input text has 38 tokens
# 2025-06-20 08:26:31,089 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,090 - src.embeddings.text_Chunker - INFO - Input text has 40 tokens
# 2025-06-20 08:26:31,090 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,090 - src.embeddings.text_Chunker - INFO - Input text has 102 tokens
# 2025-06-20 08:26:31,090 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,091 - src.embeddings.text_Chunker - INFO - Input text has 29 tokens
# 2025-06-20 08:26:31,091 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,091 - src.embeddings.text_Chunker - INFO - Input text has 182 tokens
# 2025-06-20 08:26:31,091 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,092 - src.embeddings.text_Chunker - INFO - Input text has 151 tokens
# 2025-06-20 08:26:31,092 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,093 - src.embeddings.text_Chunker - INFO - Input text has 84 tokens
# 2025-06-20 08:26:31,093 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,093 - src.embeddings.text_Chunker - INFO - Input text has 134 tokens
# 2025-06-20 08:26:31,093 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,094 - src.embeddings.text_Chunker - INFO - Input text has 88 tokens
# 2025-06-20 08:26:31,094 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,094 - src.embeddings.text_Chunker - INFO - Input text has 112 tokens
# 2025-06-20 08:26:31,094 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,095 - src.embeddings.text_Chunker - INFO - Input text has 122 tokens
# 2025-06-20 08:26:31,095 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,095 - src.embeddings.text_Chunker - INFO - Input text has 55 tokens
# 2025-06-20 08:26:31,095 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,096 - src.embeddings.text_Chunker - INFO - Input text has 205 tokens
# 2025-06-20 08:26:31,096 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,096 - src.embeddings.text_Chunker - INFO - Input text has 103 tokens
# 2025-06-20 08:26:31,097 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,097 - src.embeddings.text_Chunker - INFO - Input text has 172 tokens
# 2025-06-20 08:26:31,097 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,098 - src.embeddings.text_Chunker - INFO - Input text has 188 tokens
# 2025-06-20 08:26:31,098 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,098 - src.embeddings.text_Chunker - INFO - Input text has 55 tokens
# 2025-06-20 08:26:31,099 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,099 - src.embeddings.text_Chunker - INFO - Input text has 138 tokens
# 2025-06-20 08:26:31,099 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,100 - src.embeddings.text_Chunker - INFO - Input text has 113 tokens
# 2025-06-20 08:26:31,100 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,100 - src.embeddings.text_Chunker - INFO - Input text has 87 tokens
# 2025-06-20 08:26:31,100 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,101 - src.embeddings.text_Chunker - INFO - Input text has 274 tokens
# 2025-06-20 08:26:31,101 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,102 - src.embeddings.text_Chunker - INFO - Input text has 113 tokens
# 2025-06-20 08:26:31,102 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,102 - src.embeddings.text_Chunker - INFO - Input text has 59 tokens
# 2025-06-20 08:26:31,102 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,103 - src.embeddings.text_Chunker - INFO - Input text has 270 tokens
# 2025-06-20 08:26:31,103 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,103 - src.embeddings.text_Chunker - INFO - Input text has 16 tokens
# 2025-06-20 08:26:31,104 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,104 - src.embeddings.text_Chunker - INFO - Input text has 107 tokens
# 2025-06-20 08:26:31,104 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,104 - src.embeddings.text_Chunker - INFO - Input text has 19 tokens
# 2025-06-20 08:26:31,105 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,105 - src.embeddings.text_Chunker - INFO - Input text has 115 tokens
# 2025-06-20 08:26:31,105 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# 2025-06-20 08:26:31,106 - src.embeddings.text_Chunker - INFO - Input text has 16 tokens
# 2025-06-20 08:26:31,106 - src.embeddings.text_Chunker - INFO - Text fits in single chunk
# Chunking:   0%|          | 0/77 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
documents = []
chunked_docs[0]
# Out:
# Document(metadata={'doc_id': 'EP13899497B9W1', 'language': 'en', 'country': 'EP', 'doc_number': '3084761', 'application_number': '13899497.5', 'publication_date': '20250611', 'ipc_classes': 'G10L  19/038       20130101AFI20170426BHEP, G10L  19/07        20130101ALI20170426BHEP', 'file': 'EP13899497W1B9.xml', 'filePath': '/app/data/parsed/EPO/EPRTBJV2025000024001001/EPW1B9/EP13899497W1B9/EP13899497W1B9.json', 'title': 'AUDIO SIGNAL ENCODER', 'section': 'title', 'chunk_index': 0, 'total_chunks': 1}, page_content='AUDIO SIGNAL ENCODER')

# %%
print(f"✅ Created {len(chunked_docs)} chunks from {len(documents)} document segments")
# Out:
# ✅ Created 1409 chunks from 0 document segments

# %%
embeddings = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs={"device": "cpu"},
    encode_kwargs={"batch_size": 32, "normalize_embeddings": True}
)
print("✅ LangChain embeddings initialized")
# Out:
# /tmp/ipykernel_4798/3069164953.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# 2025-06-20 08:30:07,970 - sentence_transformers.SentenceTransformer - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-mpnet-base-v2
# ✅ LangChain embeddings initialized

# %%
# 7. Create vector store with chunked documents - connect to Docker ChromaDB
print("💾 Creating vector store using dockerized ChromaDB...")

# Import ChromaDB client directly (needed for Docker connection)
import chromadb
from chromadb.config import Settings

# When running inside Docker
chroma_client = chromadb.HttpClient(
    host="vector_db",  # Docker service name
    port=8000,         # Internal container port
    settings=Settings(anonymized_telemetry=False)
)
# Out:
# 💾 Creating vector store using dockerized ChromaDB...

# %%
collection_name = "patents"

vectorstore = Chroma(
    client=chroma_client,
    collection_name=collection_name,
    embedding_function=embeddings
)
# Out:
# 2025-06-20 08:30:50,248 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections "HTTP/1.1 200 OK"

# %%
# Add documents to the vectorstore (if we have any)
if chunked_docs:
    # Add in smaller batches to avoid memory issues
    batch_size = 100
    for i in tqdm(range(0, len(chunked_docs), batch_size), desc="Adding to vector store"):
        batch = chunked_docs[i:i+batch_size]
        vectorstore.add_documents(documents=batch)
    
    print(f"✅ Added {len(chunked_docs)} document chunks to ChromaDB collection '{collection_name}'")
else:
    print("⚠️ No document chunks to add to the vector store!")
# Out:
# Adding to vector store:   0%|          | 0/15 [00:00<?, ?it/s]
# 2025-06-20 08:31:05,094 - httpx - INFO - HTTP Request: GET http://vector_db:8000/api/v2/pre-flight-checks "HTTP/1.1 200 OK"
# 2025-06-20 08:31:05,250 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/34b877df-69c0-4489-8a41-83afcc841670/upsert "HTTP/1.1 200 OK"
# 2025-06-20 08:31:14,596 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/34b877df-69c0-4489-8a41-83afcc841670/upsert "HTTP/1.1 200 OK"
# 2025-06-20 08:31:25,186 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/34b877df-69c0-4489-8a41-83afcc841670/upsert "HTTP/1.1 200 OK"
# 2025-06-20 08:31:35,209 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/34b877df-69c0-4489-8a41-83afcc841670/upsert "HTTP/1.1 200 OK"
# 2025-06-20 08:31:46,008 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/34b877df-69c0-4489-8a41-83afcc841670/upsert "HTTP/1.1 200 OK"
# 2025-06-20 08:31:54,239 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/34b877df-69c0-4489-8a41-83afcc841670/upsert "HTTP/1.1 200 OK"
# 2025-06-20 08:31:58,042 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/34b877df-69c0-4489-8a41-83afcc841670/upsert "HTTP/1.1 200 OK"
# 2025-06-20 08:32:04,899 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/34b877df-69c0-4489-8a41-83afcc841670/upsert "HTTP/1.1 200 OK"
# 2025-06-20 08:32:14,930 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/34b877df-69c0-4489-8a41-83afcc841670/upsert "HTTP/1.1 200 OK"
# 2025-06-20 08:32:21,024 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/34b877df-69c0-4489-8a41-83afcc841670/upsert "HTTP/1.1 200 OK"
# 2025-06-20 08:32:31,167 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/34b877df-69c0-4489-8a41-83afcc841670/upsert "HTTP/1.1 200 OK"
# 2025-06-20 08:32:40,631 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/34b877df-69c0-4489-8a41-83afcc841670/upsert "HTTP/1.1 200 OK"
# 2025-06-20 08:32:49,683 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/34b877df-69c0-4489-8a41-83afcc841670/upsert "HTTP/1.1 200 OK"
# 2025-06-20 08:33:00,228 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/34b877df-69c0-4489-8a41-83afcc841670/upsert "HTTP/1.1 200 OK"
# 2025-06-20 08:33:00,396 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/34b877df-69c0-4489-8a41-83afcc841670/upsert "HTTP/1.1 200 OK"
# ✅ Added 1409 document chunks to ChromaDB collection 'patents'

# %%
# 8. Test retrieval (only if we have documents)
if chunked_docs:
    print("\n🔍 Testing vector store with sample queries...")

    test_queries = [
        "Audio signal encoding methods",
        # "Image compression techniques",
        # "Wireless communication protocols"
    ]

    for query in test_queries:
        print(f"\nQuery: '{query}'")
        # Get top 3 results
        results = vectorstore.similarity_search_with_score(query, k=3)
        
        print(f"Top {len(results)} results:")
        for i, (doc, score) in enumerate(results):
            print(f"\nResult {i+1} (similarity: {score:.4f})")
            print(f"Title: {doc.metadata.get('title', 'N/A')}")
            print(f"Section: {doc.metadata.get('section', 'N/A')}")
            print(f"Patent ID: {doc.metadata.get('doc_id', 'N/A')}")
            print(f"file Path: {doc.metadata.get('filePath', 'N/A')}")
            print(f"Content preview: {doc.page_content[:150]}...")
else:
    print("\n⚠️ No documents in vector store to search!")
# Out:
# 2025-06-20 08:36:15,588 - httpx - INFO - HTTP Request: POST http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/34b877df-69c0-4489-8a41-83afcc841670/query "HTTP/1.1 200 OK"
# 🔍 Testing vector store with sample queries...
#
# Query: 'Audio signal encoding methods'
# Top 3 results:
#
# Result 1 (similarity: 0.4964)
# Title: AUDIO SIGNAL ENCODER
# Section: Description of Some Embodiments of the Application
# Patent ID: EP13899497B9W1
# file Path: /app/data/parsed/EPO/EPRTBJV2025000024001001/EPW1B9/EP13899497W1B9/EP13899497W1B9.json
# Content preview: Description of Some Embodiments of the Application
# The concept for the embodiments as described herein is to determine and apply encoding to audio sig...
#
# Result 2 (similarity: 0.5347)
# Title: AUDIO SIGNAL ENCODER
# Section: Background
# Patent ID: EP13899497B9W1
# file Path: /app/data/parsed/EPO/EPRTBJV2025000024001001/EPW1B9/EP13899497W1B9/EP13899497W1B9.json
# Content preview: Background
# Audio signals, like speech or music, are encoded for example to enable efficient transmission or storage of the audio signals. Examples of ...
#
# Result 3 (similarity: 0.5472)
# Title: AUDIO SIGNAL ENCODER
# Section: Summary
# Patent ID: EP13899497B9W1
# file Path: /app/data/parsed/EPO/EPRTBJV2025000024001001/EPW1B9/EP13899497W1B9/EP13899497W1B9.json
# Content preview: Summary
# According to a first aspect there is provided a processor-implemented method for encoding at least one audio signal, as set forth in independe...

# %%
# vectorstore.delete_collection()
# Out:
# 2025-06-20 08:30:44,712 - httpx - INFO - HTTP Request: DELETE http://vector_db:8000/api/v2/tenants/default_tenant/databases/default_database/collections/patents "HTTP/1.1 200 OK"
