# %%
import xml.etree.ElementTree as ET
import os

def extract_headings_from_xml(xml_file_path):
    """
    Extract and print all headings from an XML file.
    Works with various heading tag types commonly found in patent documents.
    """
    try:
        # Parse the XML file
        tree = ET.parse(xml_file_path)
        root = tree.getroot()
        
        # Common heading tags in patent XML files
        heading_tags = ['heading', 'title', 'claim', 'table', 'h1', 'h2', 'h3', 'h4', 'h5', 'h6']
        
        print(f"\n=== Headings found in {os.path.basename(xml_file_path)} ===")
        print("-" * 60)
        
        heading_count = 0
        
        # Search for all elements that might be headings
        for elem in root.iter():
            # Check if element tag is a common heading tag
            if elem.tag.lower() in heading_tags:
                text_content = (elem.text or '').strip()
                if text_content:
                    heading_count += 1
                    print(f"{heading_count:2d}. [{elem.tag}] {text_content}")
            
            # Also check for elements with 'title' or 'heading' in attributes
            elif any('title' in str(attr).lower() or 'heading' in str(attr).lower() 
                     for attr in elem.attrib.values()):
                text_content = (elem.text or '').strip()
                if text_content:
                    heading_count += 1
                    print(f"{heading_count:2d}. [{elem.tag}] {text_content}")
        
        if heading_count == 0:
            print("No headings found using common heading tags.")
            print("\nAnalyzing XML structure...")
            
            # If no standard headings found, show all elements with text
            # that might be headings (short text, typically < 100 characters)
            potential_headings = []
            for elem in root.iter():
                text_content = (elem.text or '').strip()
                if text_content and len(text_content) < 100 and '\n' not in text_content:
                    potential_headings.append((elem.tag, text_content))
            
            if potential_headings:
                print("\nPotential headings (short text elements):")
                for i, (tag, text) in enumerate(potential_headings[:20], 1):  # Show first 20
                    print(f"{i:2d}. [{tag}] {text}")
                if len(potential_headings) > 20:
                    print(f"... and {len(potential_headings) - 20} more")
        else:
            print(f"\nTotal headings found: {heading_count}")
            
    except ET.ParseError as e:
        print(f"Error parsing XML file: {e}")
    except FileNotFoundError:
        print(f"File not found: {xml_file_path}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage - replace with your XML file path
xml_file_path = "EP18823397W1B9.xml"  # Change this to your file path

# Extract and print headings
extract_headings_from_xml(xml_file_path)
# Out:
# === Headings found in EP18823397W1B9.xml ===
# ------------------------------------------------------------
#  1. [heading] (2s)-2-(2,6-dichloro-4-(2-(hydroxy(phenyl)phosphoryl)ethyl)benzamido)-3-(3-(methylsulfon yl)phenyl)propionic acid
#  2. [heading] Step A: methoxyphenylphosphoryl chloride (Compound 1.1)
#  3. [heading] Step B: Methyl 2,6-dichloro-4-((phenyl(methoxy)phosphoryl)ethynyl)benzoate (Compound 1.2)
#  4. [heading] Step C: 2,6-dichloro-4-((hydroxy(phenyl)phosphoryl)ethynyl)benzoic acid (Compound 1.3)
#  5. [heading] Step D:
#  6. [heading] (2s)-2-(2,6-dichloro-4-((hydroxy(phenyl)phosphoryl)ethynyl)benzamido)-3-(3-(methylsulfon yl)phenyl)benzyl propionate (Compound 1.4)
#  7. [heading] Step E:
#  8. [heading] (2s)-2-(2,6-dichloro-4-(2-(hydroxy(phenyl)phosphoryl)ethyl)benzamido)-3-(3-(methylsulfon yl)phenyl)propionic acid (Compound 1)
#  9. [heading] (2s)-2-(2,6-dichloro-4-((hydroxy(3-hydroxyphenyl)phosphoryl)ethynyl)benzylamino)-3-(3-( methylsulfonyl)phenyl)propionic acid
# 10. [heading] Step A: (m-methoxyphenyl)ethoxyphosphoryl chloride (Compound 2.1)
# 11. [heading] Step B: methyl 2,6-dichloro-4-(((m-methoxyphenyl)(ethoxy)phosphoryl)ethynyl)benzoate
# 12. [heading] (Compound 2.2)
# 13. [heading] Step C: 2,6-dichloro-4-((hydroxy(m-methoxyphenyl)phosphoryl)ethynyl)benzoic acid
# 14. [heading] (Compound 2.3)
# 15. [heading] Step D: benzyl
# 16. [heading] (2s)-2-(2,6-dichloro-4-((hydroxy(m-methoxyphenyl)phosphoryl)ethynyl)benzamido)-3-(3-(m ethylsulfonyl)phenyl)propionate (Compound 2.4)
# 17. [heading] Step E:
# 18. [heading] (2s)-2-(2,6-dichloro-4-((hydroxy(3-hydroxyphenyl)phosphoryl)ethynyl)benzylamino)-3-(3-( methylsulfonyl)phenyl)propionic acid (Compound 2)
# 19. [heading] (2s)-2-(2,6-dichloro-4-(2-(hydroxy(m-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(3-(me thylsulfonyl)phenyl)propionic acid
# 20. [heading] (2s)-2-(2,6-dichloro-4-(2-(methoxy(phenyl)phosphoryl)ethyl)benzamido)-3-(3-(methylsulfon yl)phenyl)propionic acid
# 21. [heading] Step A: benzyl
# 22. [heading] (2s)-2-(2,6-dichloro-4-((methoxy(phenyl)phosphoryl)ethynyl)benzamido)-3-(3-(methylsulfon yl)phenyl)propionate (Compound 4.1)
# 23. [heading] Step B:
# 24. [heading] (2s)-2-(2,6-dichloro-4-(2-(methoxy(phenyl)phosphoryl)ethyl)benzamido)-3-(3-(methylsulfon yl)phenyl)propionic acid (compound 4)
# 25. [heading] (2s)-2-(2,6-dichloro-4-(methoxy(phenyl)phosphoryl)ethynyl)benzamido)-3-(3-(methylsulfon yl)phenyl)propanoic acid
# 26. [heading] (2s)-2-(2,6-dichloro-4-(2-(ethoxy(m-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(3-(met hylsulfonyl)phenyl)propionic acid
# 27. [heading] Step A: 2,6-dichloro-4-(((m-hydroxyphenyl)(ethoxy)phosphoryl)ethynyl)benzoic acid
# 28. [heading] (Compound 6.1)
# 29. [heading] Step B: benzyl
# 30. [heading] (2s)-2-(2,6-dichloro-4-((ethoxy(m-hydroxyphenyl)phosphoryl)ethynyl)benzamido)-3-(3-(met hylsulfonyl)phenyl)propionate (Compound 6.2)
# 31. [heading] Step C:
# 32. [heading] (2s)-2-(2,6-dichloro-4-(2-(ethoxy(m-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(3-(met hylsulfonyl)phenyl)propionic acid (Compound 6)
# 33. [heading] (2s)-2-(2,6-dichloro-4-((methoxy(3-hydroxyphenyl)phosphoryl)ethynyl)benzylamino)-3-(3-( methylsulfonyl)phenyl)propionic acid
# 34. [heading] Step A: benzyl
# 35. [heading] (2s)-2-(2,6-dichloro-4-((methoxy(3-hydroxyphenyl)phosphoryl)ethynyl)benzylamino)-3-(3-( methylsulfonyl)phenyl)propanoate (Compound 7.1)
# 36. [heading] Step B:
# 37. [heading] (2s)-2-(2,6-dichloro-4-((methoxy(3-hydroxyphenyl)phosphoryl)ethynyl)benzylamino)-3-(3-( methylsulfonyl)phenyl)propionic acid (Compound 7)
# 38. [heading] (2s)-2-(2,6-dichloro-4-(2-(methoxy(3-hydroxyphenyl)phosphoryl)ethyl)benzylamido)-3-(3-( methylsulfonyl)phenyl)propionic acid
# 39. [heading] (2s)-2-(2,6-dichloro-4-(methyl(phenyl)phosphoryl)ethynyl)benzamido)-3-(3-(methylsulfonyl) phenyl)propanoic acid
# 40. [heading] Step A: methylphenylphosphoryl chloride (Compound 9.1)
# 41. [heading] Step B: methyl 2,6-dichloro-4-((phenyl(methyl)phosphoryl)ethynyl)benzoate (Compound 9.2)
# 42. [heading] Step C: 2,6-dichloro-4-((methyl(phenyl)phosphoryl)ethynyl)benzoic acid (Compound 9.3)
# 43. [heading] Step D: benzyl
# 44. [heading] (2s)-2-(2,6-dichloro-4-((methyl(phenyl)phosphoryl)ethynyl)benzamido)-3-(3-(methylsulfonyl )phenyl)propionate (Compound 9.4)
# 45. [heading] Step E:
# 46. [heading] (2s)-2-(2,6-dichloro-4-((methyl(phenyl)phosphoryl)ethynyl)benzamido)-3-(3-(methylsulfonyl )propionic acid (Compound 9)
# 47. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(phenyl)phosphoryl)ethyl)benzamide)-3-(3-(methylsulfonyl )phenyl)propionic acid
# 48. [heading] (2s)-2-(2,6-dichloro-4-((methyl(3-hydroxyphenyl)phosphoryl)ethynyl)benzylamino)-3-(3-(m ethylsulfonyl)phenyl)propionic acid
# 49. [heading] Step A: ethyl (m-methoxyphenyl)methyl phosphate (Compound 11.1)
# 50. [heading] Step B: (m-methoxyphenyl)methylphosphoryl chloride (Compound 11.2)
# 51. [heading] Step C: methyl 2,6-dichloro-4-(((m-methoxyphenyl)(methyl)phosphoryl)ethynyl)benzoate
# 52. [heading] (Compound 11.3)
# 53. [heading] Step D: 2,6-dichloro-4-((methyl(m-hydroxyphenyl)phosphoryl)ethynyl)benzoic acid
# 54. [heading] (Compound 11.4)
# 55. [heading] Step E: benzyl
# 56. [heading] (2s)-2-(2,6-dichloro-4-((methyl(3-hydroxyphenyl)phosphoryl)ethynyl)benzylamino)-3-(3-(m ethylsulfonyl)phenyl)propionate (Compound 11.5)
# 57. [heading] Step F:
# 58. [heading] (2s)-2-(2,6-dichloro-4-((methyl(3-hydroxyphenyl)phosphoryl)ethynyl)benzylamino)-3-(3-(m ethylsulfonyl)phenyl)propionic acid (Compound 11)
# 59. [heading] (2s)-2-(2,6-dichloro-4-((methoxy(3-methoxyphenyl)phosphoryl)ethynyl)benzylamino)-3-(3-( methylsulfonyl)phenyl)propionic acid
# 60. [heading] (2s)-2-(2,6-dichloro-4-((hydroxy(3-methoxyphenyl)phosphoryl)ethynyl)benzylamino)-3-(3-( methylsulfonyl)phenyl)propionic acid
# 61. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzylamino)-3-(3-(me thylsulfonyl)phenyl)propionic acid
# 62. [heading] (2s)-2-(2,6-dichloro-4-((methyl(4-hydroxyphenyl)phosphoryl)ethynyl)benzylamino)-3-(3-(m ethylsulfonyl)phenyl)propionic acid
# 63. [heading] benzyl
# 64. [heading] (2s)-2-(2,6-dichloro-4-((hydroxy(phenyl)phosphoryl)ethynyl)benzamide)-3-(3-(methylsulfon yl)phenyl)propionate
# 65. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(2-theno ylamide)propyl acid
# 66. [heading] Step A: methyl 3-(2- thenoylamide)-N-[(1,1-dimethylethoxy)carbonyl]-L-alanine (Compound 17.1)
# 67. [heading] Step B: methyl (S)-2-amino-3-(2-thenoylamide)propionic acid (Compound 17.2)
# 68. [heading] Step C: methyl 2,6-dichloro-4-(((m-methoxyphenyl)(ethoxy)phosphoryl)ethyl)benzoate (Compound 17.3)
# 69. [heading] Step D: methyl 2,6-dichloro-4-(((m-hydroxyphenyl)(ethoxy)phosphoryl)ethyl)benzoate
# 70. [heading] (Compound 17.4)
# 71. [heading] Step E: methyl
# 72. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(2-theno ylamide)propionate (Compound 17.5)
# 73. [heading] Step F:
# 74. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(2-thenoylamide)propionic acid (compound 17)
# 75. [heading] LCMS ESI(+) m/z: 569 (M+1)
# 76. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(1-(meth ylsulfonamide)-1,2,5,6-tetrahydropyridin-3-yl)propionic acid
# 77. [heading] Step A: methyl
# 78. [heading] (S)-2-((tert-butyloxycarbonyl)amino)-3-(1-methyl-1,2,5,6-tetrahydropyridin-3-yl)propionate)
# 79. [heading] (Compound 18.1)
# 80. [heading] Step B: methyl
# 81. [heading] (S)-2-((tertbutyloxycarbonyl)amino)-3-(1-(methylsulfonylamide)-1,2,5,6-tetrahydropyridin-3-yl)propionate (Compound 18.2)
# 82. [heading] Step C: methyl
# 83. [heading] (S)-2-amino-3-(1-(methylsulfonylamide)-1,2,5,6-tetrahydropyridin-3-yl)propionate
# 84. [heading] (Compound 18.3)
# 85. [heading] Step D:
# 86. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(1-(meth ylsulfonylamide)-1,2,5,6-tetrahydropyridin-3-yl)propionic acid (Compound 18)
# 87. [heading] (2s)-3-((R)-N'-cyano-3-hydroxytetrahydropyrrol-1-formamidino)-2-(2,6-dichloro-4-(2-(methy l(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)propionic acid
# 88. [heading] Step A: methyl
# 89. [heading] 1-cyano-9,9-dimethyl-2-(methylthio)-7-carbonyl-8-oxy-1,3,6-triazadecane-1-ene-5-carboxyl ate (Compound 19.1)
# 90. [heading] Step B: methyl
# 91. [heading] 1-cyano-2-((R)-3-hydroxytetrahydropyrrol-1-yl)-9,9-dimethyl-7-carbonyl-8-oxy-1,3,6-triazad odecane-1-ene-5-carboxylate.
# 92. [heading] Step C:
# 93. [heading] (2s)-2-amino-3-((R)-N'-cyano-3-hydroxytetrahydropyrrol-1-formamidino)benzamido)propan oic acid (Compound 19.3)
# 94. [heading] Step D:
# 95. [heading] (2s)-3-((R)-N'-cyano-3-hydroxytetrahydropyrrol-1-formamidino)-2-(2,6-dichloro-4-(2-(methy l(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)propionic acid (Compound 19)
# 96. [heading] (2s)-2-(2,6-dichloro-4-(ethyl(3-hydroxyphenyl)phosphoryl)ethynyl)benzamido)-3-(3-(methyl sulfonylamide)phenyl)propionic acid
# 97. [heading] Step A: methyl ethyl(3-methoxyphenyl)phosphate (Compound 20.1)
# 98. [heading] Step B: Ethyl(3-methoxyphenyl)phosphoryl chloride (Compound 20.2)
# 99. [heading] Step C:
# 100. [heading] (2s)-2-(2,6-dichloro-4-(ethyl(3-hydroxyphenyl)phosphoryl)ethynyl)benzamido)-3-(3-(methyl sulfonyl)phenyl)propionic acid (Compound 20)
# 101. [heading] (2s)-2-(2,6-dichloro-4-(ethyl(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(3-(methylsul fonyl)phenyl)propionic acid
# 102. [heading] (2s)-2-(2,6-dichloro-4-(cyclopropyl(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(3-(me thylsulfonyl)phenyl)propionic acid
# 103. [heading] (2s)-2-(2,6-dichloro-4-(butyl(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(3-(methylsul fonyl)phenyl)propionic acid
# 104. [heading] (2s)-2-(2,6-dichloro-4-((methyl(benzofuran-6-yl)phosphoryl)ethynyl)benzylamino)-3-(3-(met hylsulfonyl)phenyl)propionic acid
# 105. [heading] Step A: Diethyl benzofuran-6-yl phosphonate (Compound 24.1)
# 106. [heading] Step B: methyl(benzofuran-6-yl) phosphonoacetate (Compound 24.2)
# 107. [heading] Step C: methyl(benzofuran-6-yl)phosphoryl chloride (Compound 24.3)
# 108. [heading] Step D:
# 109. [heading] (2s)-2-(2,6-dichloro-4-((methyl(benzofuran-6-yl)phosphoryl)ethynyl)benzylamino)-3-(3-(sulf onyl)phenyl)propionic acid (Compound 24)
# 110. [heading] (2s)-2-(2,6-dichloro-4-((methyl(benzofuran-6-yl)phosphoryl)ethyl)benzylamino)-3-(3-(methy lsulfonyl)phenyl)propionic acid
# 111. [heading] (2s)-2-(2,6-dichloro-4-((methyl(benzofuran-2-yl)phosphoryl)ethyl)benzamido)-3-(3-(methyls ulfonyl))phenyl)propionic acid
# 112. [heading] (2s)-2-(2,6-dichloro-4-((methyl(1H-indol-5-yl)phosphoryl)ethyl)benzylamino)-3-(3-(methylsu lfonyl)phenyl)propionic acid
# 113. [heading] (2S)-2-(2,6-dichloro-4-(((methyl(phenyl)phosphoryl)oxy)methyl)benzamido)-3-(3-(methylsul fonyl)phenyl)propionic acid
# 114. [heading] Step A: methyl 2,6-dichloro-(4-hydroxymethyl)benzoate (Compound 28.1)
# 115. [heading] Step B: 2,6-dichloro-(4-hydroxymethyl)benzoic acid (Compound 28.2)
# 116. [heading] Step C: methyl
# 117. [heading] (S)-2-(2,6-dichloro-4-(hydroxymethyl)benzamido)-3-(3-(3-(3-(methylsulfonyl)phenyl)propio nate (Compound 28.3)
# 118. [heading] Step D:
# 119. [heading] (S)-2-(2,6-dichloro-4-(hydroxymethyl)benzamido)-3-(3-(3-(3-(methylsulfonyl)phenyl)propan oic acid (Compound 28.4)
# 120. [heading] Step E:
# 121. [heading] (2S)-2-(2,6-dichloro-4-(((methyl(phenyl)phosphoryl)oxy)methyl)benzamido)-3-(3-(methylsul fonyl)phenyl)propionic acid (Compound 28).
# 122. [heading] (2S)-2-(2,6-dichloro-4-(((3-hydroxyphenyl))(methyl)phosphoryl)methyl)amino) benzamido)-3-(3-(methylsulfonyl)phenyl)propionic acid
# 123. [heading] Step A: (chloromethyl)(3-methoxyphenyl)(methyl)phosphorus oxide (Compound 29.1)
# 124. [heading] Step B: methyl
# 125. [heading] 2,6-dichloro-4-((((3-methoxyphenyl)(methyl)phosphoryl)methyl)amino)benzoate
# 126. [heading] (Compound 29.2)
# 127. [heading] Step C: 2,6-dichloro-4-((((3-methoxyphenyl)(methyl)phosphoryl)methyl)amino)benzoic acid
# 128. [heading] (Compound 29.3)
# 129. [heading] Step D: methyl
# 130. [heading] (2S)-2-(2,6-dichloro-4-((((3-hydroxyphenyl)(methyl)phosphoryl)methyl)amino)benzamido)-3-(3-(methylsulfonyl)phenyl)propanoate (Compound 29.4)
# 131. [heading] Step E:
# 132. [heading] (2S)-2-(2,6-dichloro-4-(((3-hydroxyphenyl)(methyl)phosphoryl)methyl)amino)benzamido)-3 -(3-(methylsulfonyl)phenyl)propionic acid (Compound 29)
# 133. [heading] (S,E)-2-(4-(2-(3-hydroxyphenyl)phosphonovinyl)-2,6-dichlorobenzamide)-3-(3-(methylsulfo nyl)phenyl)propionic acid
# 134. [heading] Step A: methyl (E)-2,6-dichloro-4-(2-(diethoxyphosphono)vinyl)benzoate (Compound 32.1)
# 135. [heading] Step B: methyl (E)-2,6-dichloro-4-(2-(chloroethoxyphosphonyl)vinyl)benzoate (Compound 32.2)
# 136. [heading] Step C: methyl (E)-4-(2-(3-methoxyphenyl)phosphonovinyl)-2,6-dichlorobenzoate
# 137. [heading] (Compound 32.3)
# 138. [heading] Step D: (E)-4-(2-(3-hydroxyphenyl)ethoxyphosphonovinyl)-2,6-dichlorobenzoate
# 139. [heading] (Compound 32.4)
# 140. [heading] Step E: benzyl
# 141. [heading] (S, E)-2-(4-(2-(3-hydroxyphenyl)ethoxyphosphonylvinyl)-2,6-dichlorobenzamido)-3-(3-(meth ylsulfonyl)phenyl)propionate (Compound 32.5)
# 142. [heading] Step F:
# 143. [heading] (S,E)-2-(4-(2-(3-hydroxyphenyl)ethoxyphosphonylvinyl)-2,6-dichlorobenzamido)-3-(3-(meth ylsulfonyl)phenyl)propionic acid (Compound 32)
# 144. [heading] (2s)-2-(2,6-dichloro-4-(2-(hydroxy(4-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(3-(met hylsulfonyl)phenyl)propionic acid
# 145. [heading] LCMS ESI(+) m/z: 597.6(M+1).
# 146. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(3-hydro xybenzamido)propionic acid
# 147. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(3,5-dih ydroxybenzamido)propionic acid
# 148. [heading] 2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzylamino)-3-(3,5-(dimet hylsulfonyl)phenyl)propionic acid
# 149. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzylamino)-6-(methy Isulfonylamide)hexanoic acid
# 150. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzylamino)-3-(5-(me thylsulfonyl)pyridine -3-yl)propionic acid
# 151. [heading] Example 39
# 152. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzylamino)-3-(1-(me thylsulfonyl)-1H-pyrrol-3-yl)propionic acid
# 153. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzylamino)-3-(1-(me thylsulfonyl)-1H-pyrazol-3-yl)propionic acid
# 154. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzylamino)-3-(1-(me thylsulfonyl)-1H-pyrazol-4-yl)propionic acid
# 155. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzylamino)-3-(1-(me thylsulfonyl)pyrrolidin-3-yl)propionic acid
# 156. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-((S)-3-h ydroxylpyrrolidine-1-carboxamide)propionic acid
# 157. [heading] (2s)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyphenyl)phosphoryl)ethyl)benzylamino)-5(methyl sulfonamide)pentanoic acid
# 158. [heading] (2s)-3-((trans)-N'-cyano-3,4-dihydroxypyrrolidine-1-formamidino)-2-(2,6-dichloro-4-(2-(met hyl(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)propionic acid
# 159. [heading] (2s)-3-(2-cyano-3,3-bis(2-hydroxyethyl)guanidino)-2-(2,6-dichloro-4-(2-(methyl(3-hydroxyp henyl)phosphoryl)ethyl)benzamido)propionic acid
# 160. [heading] (2s)-2-(2,6-dichloro-4-((methoxy(2-hydroxyphenyl)phosphoryl)ethynyl)benzylamino)-3-(3-( methylsulfonyl)phenyl)propionic acid
# 161. [heading] Step A: methyl 2,6-dichloro-4-(((o-methoxyphenyl)(ethoxy)phosphoryl)ethynyl)benzoate
# 162. [heading] (Compound 47.2)
# 163. [heading] Step B: 2,6-dichloro-4-((hydroxy(o-methoxyphenyl)phosphoryl)ethynyl)benzoic acid
# 164. [heading] (Compound 47.3)
# 165. [heading] Step C: benzyl
# 166. [heading] (2s)-2-(2,6-dichloro-4-((hydroxy(o-methoxyphenyl)phosphoryl)ethynyl)benzamido)-3-(3-(m ethylsulfonyl)phenyl)propionate (Compound 47.4)
# 167. [heading] Step D: benzyl
# 168. [heading] (2s)-2-(2,6-dichloro-4-((methoxy(2-methoxyphenyl)phosphoryl)ethynyl)benzylamino)-3-(3-( methylsulphonyl)phenyl)propionate (Compound 47.5)
# 169. [heading] Step E:
# 170. [heading] (2s)-2-(2,6-dichloro-4-((methoxy(2-hydroxyphenyl)phosphoryl)ethynyl)benzylamino)-3-(3-( methylsulfonyl)phenyl)propionic acid (Compound 47)
# 171. [heading] (2s)-2-(2,6-dichloro-4-((methyl(4-hydroxy-3-chlorophenyl)phosphoryl)ethynyl)benzylamino) -3-(3-(methylsulfonyl)phenyl)propionic acid
# 172. [heading] (2s)-2-(2,6-dichloro-4-((hydroxy(benzofuran-6-yl)phosphoryl)ethynyl)benzylamino)-3-(3-(m ethylsulfonyl)phenyl)propionic acid
# 173. [heading] Step A: methyl 2,6-dichloro-4-(((benzofuran-6-yl)(ethoxy)phosphoryl)ethynyl)benzoate(Compound 49.1)
# 174. [heading] Step B: 2,6-dichloro-4-((hydroxy(benzofuran-6-yl)phosphoryl)ethynyl)benzoic acid
# 175. [heading] (Compound 49.2)
# 176. [heading] Step C: benzyl
# 177. [heading] (2s)-2-(2,6-dichloro-4-((hydroxy(benzofuran-6-yl)phosphoryl)ethynyl)benzamido)-3-(3-(met hylsulfonyl)phenyl)propionate (Compound 49.3)
# 178. [heading] Step D:
# 179. [heading] (2s)-2-(2,6-dichloro-4-((hydroxy(benzofuran-6-yl)phosphoryl)ethynyl)benzylamino)-3-(3-(m ethylsulfonyl)phenyl)propionic acid (Compound 49)
# 180. [heading] (2s)-2-(2,6-dichloro-4-(1-hydroxy
# 181. [heading] 2-(hydroxy(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(3-(methylsulfonyl)phenyl)pro pionic acid
# 182. [heading] Step A: methyl 2,6-dichloro-4-(1-hydroxy
# 183. [heading] 2-(methoxy(3-methoxyphenyl)phosphoryl)ethyl)benzoate (Compound 50.1)
# 184. [heading] Step B: 2,6-dichloro-4-(1-hydroxy 2-(hydroxy(3-hydroxyphenyl)phosphoryl)ethyl)benzoic acid (Compound 50.2)
# 185. [heading] Step C: benzyl (2s)-2-(2,6-dichloro-4-(1-hydroxy
# 186. [heading] 2-(hydroxy(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(3-(methanesulfonyl)phenyl)p ropanoic acid (Compound 50.3)
# 187. [heading] Step D:
# 188. [heading] (2s)-2-(2,6-dichloro-4-(1-hydroxy2-(hydroxy(3-hydroxyphenyl)phosphoryl)ethyl)benzamido) -3-(3-(methanesulfonyl)phenyl)propionic acid (Compound 50)
# 189. [heading] (2s)-2-(2,6-dichloro-4-(2-(hydroxy(m-hydroxyphenyl)phosphoryl)vinyl)benzamido)-3-(3-(me thylsulfonyl)phenyl)propionic acid
# 190. [heading] (S,E)-2-(4-(2-(bis(3-hydroxyphenyl)phosphonyl)vinyl)-2,6-dichlorobenzamido)-3-(3-(methyl sulfonyl)phenyl)propionic acid
# 191. [heading] Step A: methyl (E)-4-(2-(bis(3-methoxyphenyl)phosphonyl)vinyl)-2,6-dichlorobenzoate
# 192. [heading] (Compound 52.1)
# 193. [heading] Step B: (E)-4-(2-(bis(3-hydroxyphenyl)phosphonyl)vinyl)-2,6-dichlorobenzoic acid
# 194. [heading] (Compound 52.2)
# 195. [heading] Step C: benzyl
# 196. [heading] (S,E)-2-(4-(2-(bis(3-hydroxyphenyl)phosphonyl)vinyl)-2,6-dichlorobenzamido)-3-(3-(methyl sulfonyl)phenyl)propionate (Compound 52.3)
# 197. [heading] Step D:
# 198. [heading] (S,E)-2-(4-(2-(bis(3-hydroxyphenyl)phosphonyl)vinyl)-2,6-dichlorobenzamido)-3-(3-(methyl sulfonyl)phenyl)propionic acid (Compound 52)
# 199. [heading] (S,E)-2-(4-(2-(bis(3-hydroxyphenyl)phosphonyl)ethyl)-2,6-dichlorobenzamido)-3-(3-(methyl sulfonyl)phenyl)propionic acid
# 200. [heading] (S,E)-2-(4-(2-(4-hydroxyphenyl)phosphonovinyl)-2,6-dichlorobenzamido)-3-(3-(methylsulfo nyl)phenyl)propionic acid
# 201. [heading] (2s)-2-(2,6-dichloro-4-(1-hydroxy2-(methyl(benzofuran-3-yl)phosphoryl)ethyl)benzamido)-3 -(3-(methylsulphonyl)phenyl)propionic acid
# 202. [heading] Step A: dimethyl (benzofuran-3-yl)phosphine oxide (Compound 55.1)
# 203. [heading] Step B:
# 204. [heading] (2s)-2-(2,6-dichloro-4-(1-hydroxy2-(methyl(benzofuran-3-yl)phosphoryl)ethyl)benzamido)-3 -(3-(methylsulfonyl)phenyl)propionic acid (Compound 55)
# 205. [heading] (2s)-2-(2,6-dichloro-4-(isopropyl(3-hydroxyphenyl)phosphoryl)ethyl)benzamido)-3-(3-(meth ylsulfonyl)phenyl)propionic acid
# 206. [heading] (2s)-2-(2,6-dichloro-4-(cyclopropyl(3-hydroxyphenyl)phosphoryl)vinyl)benzamido)-3-(3-(me thylsulfonyl)phenyl)propionic acid
# 207. [heading] Step A: methyl (E)-4-(2-(3-methoxyphenyl)chlorophosphonylvinyl)-2,6-dichlorobenzoate
# 208. [heading] (Compound 57.1)
# 209. [heading] Step B: methyl
# 210. [heading] (E)-4-(2-(3-methoxyphenyl)cyclopropylphosphorylvinyl)-2,6-dichlorobenzoate (Compound 57.2)
# 211. [heading] Step C: (E)-4-(2-((3-hydroxyphenyl)cyclopropylphosphonyl)vinyl)-2,6-dichlorobenzoic acid
# 212. [heading] (Compound 57.3)
# 213. [heading] Step D: benzyl
# 214. [heading] (S,E)-2-(4-(2-(3-hydroxyphenyl)cyclopropylphosphonyl)vinyl)-2,6-dichlorobenzamido)-3-(3-(methylsulphonyl)phenyl)propanoate (Compound 57.4)
# 215. [heading] Step E:
# 216. [heading] (S,E)-2-(4-(2-(3-hydroxyphenyl)cyclopropylphosphonyl)vinyl)-2,6-dichlorobenzamido)-3-(3-(methanesulfonyl)phenyl)propionic acid (Compound 57)
# 217. [heading] (2s)-2-(2,6-dichloro-4-(methyl(3-hydroxyphenyl)phosphoryl)vinyl)benzamido)-3-(3-(methyls ulfonyl)phenyl)propionic acid
# 218. [title] Table 1: EC
# 219. [title] Table 1 (continued)
# 220. [heading] Example: Formulation Preparation
#
# Total headings found: 220
