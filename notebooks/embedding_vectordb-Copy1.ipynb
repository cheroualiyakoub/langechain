# %% [markdown]
# 1. Extract semantic chunks from your JSON (e.g., abstract, claim, paragraph).
#
# 2. Use HuggingFaceEmbeddings or OpenAIEmbeddings.
#
# 3. Store structured info as metadata.
#
# 4. Use metadata filtering + vector similarity for retrieval.

# %%
import sys
import os
from pathlib import Path
import time
import json

# Add source directories to Python path
current_dir = Path.cwd()
project_root = current_dir.parent  # Go up one level from notebooks to project root
src_dir = project_root / "src"

# Add paths
sys.path.append(str(src_dir / "data_pipline"))
sys.path.append(str(src_dir / "EU_XML_data_loader"))


from data_pipline import DataPipeline
import get_raw_data_paths_EPO  
from xml_loader_EPO import process_xml_files_list


print(f"📁 Current directory: {current_dir}")
print(f"📁 Project root: {project_root}")
print(f"📁 Source directory: {src_dir}")
print(f"✅ Python paths configured")
# Out:
# 📁 Current directory: /app/notebooks
# 📁 Project root: /app
# 📁 Source directory: /app/src
# ✅ Python paths configured

# %%
import json
import glob
import os
from langchain.docstore.document import Document
import sys
# Prepare .json file for embedding
def extract_documents(json_data):
    bibliographic = json_data.get("bibliographic_data", {})
    doc_id = bibliographic.get("doc_id", "UNKNOWN")
    documents = []

    # Common metadata to propagate
    common_meta = {
        "doc_id": doc_id,
        "language": bibliographic.get("language"),
        "country": bibliographic.get("country"),
        "doc_number": bibliographic.get("doc_number"),
        "application_number": bibliographic.get("application_number"),
        "publication_date": bibliographic.get("publication_date"),
        "ipc_classes": bibliographic.get("ipc_classes", []),
        "file":bibliographic.get("file")
    }

    # Title (en preferred)
    title_dict = bibliographic.get("title", {})
    title = title_dict.get("en") or next(iter(title_dict.values()), "")
    if title:
        documents.append(Document(
            page_content=title,
            metadata={**common_meta, "section": "title"}
        ))

    # Abstract
    abstract = bibliographic.get("abstract")
    if abstract:
        documents.append(Document(
            page_content=abstract,
            metadata={**common_meta, "section": "abstract"}
        ))

    # Claims
    for claim in json_data.get("claims", []):
        documents.append(Document(
            page_content=claim["text"],
            metadata={**common_meta, "section": "claim", "claim_number": claim.get("claim_number")}
        ))

    # Main sections
    for section in json_data.get("main_sections", []):
        section_name = section.get("heading_text", "UNKNOWN_SECTION")
        for p in section.get("paragraphs", []):
            documents.append(Document(
                page_content=f"{section_name}\n{p['text']}",
                metadata={**common_meta, "section": section_name, "p_id": p.get("p_id")}
            ))

    return documents

# %%
# Test the new JSON loading functionality
sys.path.append(str(src_dir / "data_pipline" / "json_loader"))

# Import the JSON loader functions
from json_loader_epo import get_epo_json_file_paths, get_all_json_file_paths, load_json_documents

print("🔍 Testing JSON File Loading Functions")
print("=" * 50)
# Out:
# 🔍 Testing JSON File Loading Functions
# ==================================================

# %%
def get_chunk_size(text: str, total_tokens: int, base_chunk_size: int = 1000, min_chunk_size: int = 300) -> int:
    # total_tokens = count_tokens(text)

    # If it's small enough, return as one chunk
    if total_tokens <= base_chunk_size:
        return total_tokens

    # Try to divide the tokens into balanced parts
    num_splits = total_tokens // base_chunk_size
    if total_tokens % base_chunk_size != 0:
        num_splits += 1

    # Compute new balanced chunk size
    balanced_chunk_size = total_tokens // num_splits

    # Make sure it doesn't go below a minimum
    balanced_chunk_size = int(max(min_chunk_size, balanced_chunk_size))


    return balanced_chunk_size

# %%
# chunk documents
from transformers import AutoTokenizer
from langchain.text_splitter import RecursiveCharacterTextSplitter

def chunk_documents(documents):
    # Load tokenizer
    tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")

    processed_docs = []
    for doc in documents:
        token_count =len(str(doc))
        balanced_chunk_size = get_chunk_size(doc, token_count)
        print("Token Count: ", token_count)
        print("balanced_chunk_size: ", balanced_chunk_size)
        splitter = RecursiveCharacterTextSplitter(
            chunk_size=balanced_chunk_size,
            # chunk_size=500,
            chunk_overlap=50
            )

        chunks = splitter.split_documents([doc])
        # print("Chunks: ", chunks)
        print(len(processed_docs))
        processed_docs.extend(chunks)
        print(len(processed_docs))
        # processed_docs.append(doc)
    return processed_docs

# %%
import os
os.environ["TRANSFORMERS_HTTP_TIMEOUT"] = "60"
# load the .json documents
file_list = get_epo_json_file_paths()[:100]
# file_list = glob.glob(json_files_path)

all_documents = []

for file_path in file_list:
    with open(file_path, "r") as f:
        data = json.load(f)
        docs = extract_documents(data)
        chunked_docs = chunk_documents(docs)
        all_documents.extend(chunked_docs)
# Out:
# 📁 Found 1286 EPO JSON files
# Token Count:  360
# balanced_chunk_size:  360
# 0
# 1
# Token Count:  4152
# balanced_chunk_size:  830
# 1
# 6
# Token Count:  553
# balanced_chunk_size:  553
# 6
# 7
# Token Count:  687
# balanced_chunk_size:  687
# 7
# 8
# Token Count:  833
# balanced_chunk_size:  833
# 8
# 9
# Token Count:  4756
# balanced_chunk_size:  951
# 9
# 14
# Token Count:  1055
# balanced_chunk_size:  527
# 14
# 16
# Token Count:  733
# balanced_chunk_size:  733
# 16
# 17
# Token Count:  832
# balanced_chunk_size:  832
# 17
# 18
# Token Count:  519
# balanced_chunk_size:  519
# 18
# 19
# Token Count:  558
# balanced_chunk_size:  558
# 19
# 20
# Token Count:  908
# balanced_chunk_size:  908
# 20
# 21
# Token Count:  566
# balanced_chunk_size:  566
# 21
# 22
# Token Count:  867
# balanced_chunk_size:  867
# 22
# 23
# Token Count:  520
# balanced_chunk_size:  520
# 23
# 24
# Token Count:  544
# balanced_chunk_size:  544
# 24
# 25
# Token Count:  752
# balanced_chunk_size:  752
# 25
# 26
# Token Count:  501
# balanced_chunk_size:  501
# 26
# 27
# Token Count:  618
# balanced_chunk_size:  618
# 27
# 28
# Token Count:  704
# balanced_chunk_size:  704
# 28
# 29
# Token Count:  660
# balanced_chunk_size:  660
# 29
# 30
# Token Count:  494
# balanced_chunk_size:  494
# 30
# 31
# Token Count:  857
# balanced_chunk_size:  857
# 31
# 32
# Token Count:  830
# balanced_chunk_size:  830
# 32
# 33
# Token Count:  945
# balanced_chunk_size:  945
# 33
# 34
# Token Count:  565
# balanced_chunk_size:  565
# 34
# 35
# Token Count:  937
# balanced_chunk_size:  937
# 35
# 36
# Token Count:  912
# balanced_chunk_size:  912
# 36
# 37
# Token Count:  567
# balanced_chunk_size:  567
# 37
# 38
# Token Count:  1568
# balanced_chunk_size:  784
# 38
# 41
# Token Count:  812
# balanced_chunk_size:  812
# 41
# 42
# Token Count:  596
# balanced_chunk_size:  596
# 42
# 43
# Token Count:  777
# balanced_chunk_size:  777
# 43
# 44
# Token Count:  1153
# balanced_chunk_size:  576
# 44
# 47
# Token Count:  722
# balanced_chunk_size:  722
# 47
# 48
# Token Count:  519
# balanced_chunk_size:  519
# 48
# 49
# Token Count:  529
# balanced_chunk_size:  529
# 49
# 50
# Token Count:  730
# balanced_chunk_size:  730
# 50
# 51
# Token Count:  985
# balanced_chunk_size:  985
# 51
# 52
# Token Count:  657
# balanced_chunk_size:  657
# 52
# 53
# Token Count:  1199
# balanced_chunk_size:  599
# 53
# 56
# Token Count:  505
# balanced_chunk_size:  505
# 56
# 57
# Token Count:  534
# balanced_chunk_size:  534
# 57
# 58
# Token Count:  830
# balanced_chunk_size:  830
# 58
# 59
# Token Count:  846
# balanced_chunk_size:  846
# 59
# 60
# Token Count:  838
# balanced_chunk_size:  838
# 60
# 61
# Token Count:  859
# balanced_chunk_size:  859
# 61
# 62
# Token Count:  533
# balanced_chunk_size:  533
# 62
# 63
# Token Count:  556
# balanced_chunk_size:  556
# 63
# 64
# Token Count:  1101
# balanced_chunk_size:  550
# 64
# 67
# Token Count:  654
# balanced_chunk_size:  654
# 67
# 68
# Token Count:  526
# balanced_chunk_size:  526
# 68
# 69
# Token Count:  656
# balanced_chunk_size:  656
# 69
# 70
# Token Count:  526
# balanced_chunk_size:  526
# 70
# 71
# Token Count:  545
# balanced_chunk_size:  545
# 71
# 72
# Token Count:  782
# balanced_chunk_size:  782
# 72
# 73
# Token Count:  511
# balanced_chunk_size:  511
# 73
# 74
# Token Count:  486
# balanced_chunk_size:  486
# 74
# 75
# Token Count:  511
# balanced_chunk_size:  511
# 75
# 76
# Token Count:  470
# balanced_chunk_size:  470
# 76
# 77
# Token Count:  902
# balanced_chunk_size:  902
# 77
# 78
# Token Count:  1321
# balanced_chunk_size:  660
# 78
# 81
# Token Count:  560
# balanced_chunk_size:  560
# 81
# 82
# Token Count:  1064
# balanced_chunk_size:  532
# 82
# 85
# Token Count:  780
# balanced_chunk_size:  780
# 85
# 86
# Token Count:  920
# balanced_chunk_size:  920
# 86
# 87
# Token Count:  830
# balanced_chunk_size:  830
# 87
# 88
# Token Count:  2372
# balanced_chunk_size:  790
# 88
# 92
# Token Count:  999
# balanced_chunk_size:  999
# 92
# 93
# Token Count:  1019
# balanced_chunk_size:  509
# 93
# 96
# Token Count:  1089
# balanced_chunk_size:  544
# 96
# 99
# Token Count:  785
# balanced_chunk_size:  785
# 99
# 100
# Token Count:  1180
# balanced_chunk_size:  590
# 100
# 103
# Token Count:  471
# balanced_chunk_size:  471
# 103
# 104
# Token Count:  813
# balanced_chunk_size:  813
# 104
# 105
# Token Count:  517
# balanced_chunk_size:  517
# 105
# 106
# Token Count:  487
# balanced_chunk_size:  487
# 106
# 107
# Token Count:  475
# balanced_chunk_size:  475
# 107
# 108
# Token Count:  495
# balanced_chunk_size:  495
# 108
# 109
# Token Count:  488
# balanced_chunk_size:  488
# 109
# 110
# Token Count:  585
# balanced_chunk_size:  585
# 110
# 111
# Token Count:  544
# balanced_chunk_size:  544
# 111
# 112
# Token Count:  636
# balanced_chunk_size:  636
# 112
# 113
# Token Count:  622
# balanced_chunk_size:  622
# 113
# 114
# Token Count:  547
# balanced_chunk_size:  547
# 114
# 115
# Token Count:  601
# balanced_chunk_size:  601
# 115
# 116
# Token Count:  698
# balanced_chunk_size:  698
# 116
# 117
# Token Count:  1087
# balanced_chunk_size:  543
# 117
# 120
# Token Count:  471
# balanced_chunk_size:  471
# 120
# 121
# Token Count:  553
# balanced_chunk_size:  553
# 121
# 122
# Token Count:  617
# balanced_chunk_size:  617
# 122
# 123
# Token Count:  582
# balanced_chunk_size:  582
# 123
# 124
# Token Count:  503
# balanced_chunk_size:  503
# 124
# 125
# Token Count:  872
# balanced_chunk_size:  872
# 125
# 126
# Token Count:  703
# balanced_chunk_size:  703
# 126
# 127
# Token Count:  1144
# balanced_chunk_size:  572
# 127
# 130
# Token Count:  869
# balanced_chunk_size:  869
# 130
# 131
# Token Count:  820
# balanced_chunk_size:  820
# 131
# 132
# Token Count:  739
# balanced_chunk_size:  739
# 132
# 133
# Token Count:  581
# balanced_chunk_size:  581
# 133
# 134
# Token Count:  761
# balanced_chunk_size:  761
# 134
# 135
# Token Count:  518
# balanced_chunk_size:  518
# 135
# 136
# Token Count:  464
# balanced_chunk_size:  464
# 136
# 137
# Token Count:  526
# balanced_chunk_size:  526
# 137
# 138
# Token Count:  565
# balanced_chunk_size:  565
# 138
# 139
# Token Count:  542
# balanced_chunk_size:  542
# 139
# 140
# Token Count:  543
# balanced_chunk_size:  543
# 140
# 141
# Token Count:  594
# balanced_chunk_size:  594
# 141
# 142
# Token Count:  648
# balanced_chunk_size:  648
# 142
# 143
# Token Count:  581
# balanced_chunk_size:  581
# 143
# 144
# Token Count:  553
# balanced_chunk_size:  553
# 144
# 145
# Token Count:  658
# balanced_chunk_size:  658
# 145
# 146
# Token Count:  551
# balanced_chunk_size:  551
# 146
# 147
# Token Count:  491
# balanced_chunk_size:  491
# 147
# 148
# Token Count:  579
# balanced_chunk_size:  579
# 148
# 149
# Token Count:  1014
# balanced_chunk_size:  507
# 149
# 152
# Token Count:  750
# balanced_chunk_size:  750
# 152
# 153
# Token Count:  722
# balanced_chunk_size:  722
# 153
# 154
# Token Count:  706
# balanced_chunk_size:  706
# 154
# 155
# Token Count:  844
# balanced_chunk_size:  844
# 155
# 156
# Token Count:  766
# balanced_chunk_size:  766
# 156
# 157
# Token Count:  535
# balanced_chunk_size:  535
# 157
# 158
# Token Count:  1171
# balanced_chunk_size:  585
# 158
# 161
# Token Count:  585
# balanced_chunk_size:  585
# 161
# 162
# Token Count:  603
# balanced_chunk_size:  603
# 162
# 163
# Token Count:  573
# balanced_chunk_size:  573
# 163
# 164
# Token Count:  739
# balanced_chunk_size:  739
# 164
# 165
# Token Count:  696
# balanced_chunk_size:  696
# 165
# 166
# Token Count:  747
# balanced_chunk_size:  747
# 166
# 167
# Token Count:  835
# balanced_chunk_size:  835
# 167
# 168
# Token Count:  747
# balanced_chunk_size:  747
# 168
# 169
# Token Count:  661
# balanced_chunk_size:  661
# 169
# 170
# Token Count:  508
# balanced_chunk_size:  508
# 170
# 171
# Token Count:  755
# balanced_chunk_size:  755
# 171
# 172
# Token Count:  492
# balanced_chunk_size:  492
# 172
# 173
# Token Count:  496
# balanced_chunk_size:  496
# 173
# 174
# Token Count:  567
# balanced_chunk_size:  567
# 174
# 175
# Token Count:  738
# balanced_chunk_size:  738
# 175
# 176
# Token Count:  548
# balanced_chunk_size:  548
# 176
# 177
# Token Count:  542
# balanced_chunk_size:  542
# 177
# 178
# Token Count:  853
# balanced_chunk_size:  853
# 178
# 179
# Token Count:  828
# balanced_chunk_size:  828
# 179
# 180
# Token Count:  506
# balanced_chunk_size:  506
# 180
# 181
# Token Count:  610
# balanced_chunk_size:  610
# 181
# 182
# Token Count:  581
# balanced_chunk_size:  581
# 182
# 183
# Token Count:  501
# balanced_chunk_size:  501
# 183
# 184
# Token Count:  536
# balanced_chunk_size:  536
# 184
# 185
# Token Count:  584
# balanced_chunk_size:  584
# 185
# 186
# Token Count:  507
# balanced_chunk_size:  507
# 186
# 187
# Token Count:  575
# balanced_chunk_size:  575
# 187
# 188
# Token Count:  557
# balanced_chunk_size:  557
# 188
# 189
# Token Count:  538
# balanced_chunk_size:  538
# 189
# 190
# Token Count:  545
# balanced_chunk_size:  545
# 190
# 191
# Token Count:  643
# balanced_chunk_size:  643
# 191
# 192
# Token Count:  529
# balanced_chunk_size:  529
# 192
# 193
# Token Count:  538
# balanced_chunk_size:  538
# 193
# 194
# Token Count:  608
# balanced_chunk_size:  608
# 194
# 195
# Token Count:  499
# balanced_chunk_size:  499
# 195
# 196
# Token Count:  680
# balanced_chunk_size:  680
# 196
# 197
# Token Count:  531
# balanced_chunk_size:  531
# 197
# 198
# Token Count:  613
# balanced_chunk_size:  613
# 198
# 199
# Token Count:  632
# balanced_chunk_size:  632
# 199
# 200
# Token Count:  540
# balanced_chunk_size:  540
# 200
# 201
# Token Count:  566
# balanced_chunk_size:  566
# 201
# 202
# Token Count:  716
# balanced_chunk_size:  716
# 202
# 203
# Token Count:  642
# balanced_chunk_size:  642
# 203
# 204
# Token Count:  804
# balanced_chunk_size:  804
# 204
# 205
# Token Count:  1078
# balanced_chunk_size:  539
# 205
# 208
# Token Count:  918
# balanced_chunk_size:  918
# 208
# 209
# Token Count:  565
# balanced_chunk_size:  565
# 209
# 210
# Token Count:  658
# balanced_chunk_size:  658
# 210
# 211
# Token Count:  563
# balanced_chunk_size:  563
# 211
# 212
# Token Count:  1322
# balanced_chunk_size:  661
# 212
# 215
# Token Count:  931
# balanced_chunk_size:  931
# 215
# 216
# Token Count:  1119
# balanced_chunk_size:  559
# 216
# 219
# Token Count:  818
# balanced_chunk_size:  818
# 219
# 220
# Token Count:  983
# balanced_chunk_size:  983
# 220
# 221
# Token Count:  534
# balanced_chunk_size:  534
# 221
# 222
# Token Count:  1086
# balanced_chunk_size:  543
# 222
# 225
# Token Count:  843
# balanced_chunk_size:  843
# 225
# 226
# Token Count:  466
# balanced_chunk_size:  466
# 0
# 1
# Token Count:  1848
# balanced_chunk_size:  924
# 1
# 3
# Token Count:  864
# balanced_chunk_size:  864
# 3
# 4
# Token Count:  726
# balanced_chunk_size:  726
# 4
# 5
# Token Count:  882
# balanced_chunk_size:  882
# 5
# 6
# Token Count:  869
# balanced_chunk_size:  869
# 6
# 7
# Token Count:  690
# balanced_chunk_size:  690
# 7
# 8
# Token Count:  736
# balanced_chunk_size:  736
# 8
# 9
# Token Count:  729
# balanced_chunk_size:  729
# 9
# 10
# Token Count:  726
# balanced_chunk_size:  726
# 10
# 11
# Token Count:  638
# balanced_chunk_size:  638
# 11
# 12
# Token Count:  635
# balanced_chunk_size:  635
# 12
# 13
# Token Count:  640
# balanced_chunk_size:  640
# 13
# 14
# Token Count:  578
# balanced_chunk_size:  578
# 14
# 15
# Token Count:  599
# balanced_chunk_size:  599
# 15
# 16
# Token Count:  695
# balanced_chunk_size:  695
# 16
# 17
# Token Count:  596
# balanced_chunk_size:  596
# 0
# 1
# Token Count:  907
# balanced_chunk_size:  907
# 1
# 2
# Token Count:  461
# balanced_chunk_size:  461
# 0
# 1
# Token Count:  1037
# balanced_chunk_size:  518
# 1
# 3
# Token Count:  631
# balanced_chunk_size:  631
# 0
# 1
# Token Count:  1463
# balanced_chunk_size:  731
# 1
# 3
# Token Count:  1305
# balanced_chunk_size:  652
# 3
# 5
# Token Count:  665
# balanced_chunk_size:  665
# 5
# 6
# Token Count:  660
# balanced_chunk_size:  660
# 6
# 7
# Token Count:  1363
# balanced_chunk_size:  681
# 7
# 9
# Token Count:  632
# balanced_chunk_size:  632
# 9
# 10
# Token Count:  632
# balanced_chunk_size:  632
# 10
# 11
# Token Count:  632
# balanced_chunk_size:  632
# 11
# 12
# Token Count:  615
# balanced_chunk_size:  615
# 12
# 13
# Token Count:  632
# balanced_chunk_size:  632
# 13
# 14
# Token Count:  2301
# balanced_chunk_size:  767
# 14
# 17
# Token Count:  806
# balanced_chunk_size:  806
# 17
# 18
# Token Count:  841
# balanced_chunk_size:  841
# 18
# 19
# Token Count:  838
# balanced_chunk_size:  838
# 19
# 20
# Token Count:  738
# balanced_chunk_size:  738
# 20
# 21
# Token Count:  574
# balanced_chunk_size:  574
# 0
# 1
# Token Count:  722
# balanced_chunk_size:  722
# 1
# 2
# Token Count:  731
# balanced_chunk_size:  731
# 2
# 3
# Token Count:  657
# balanced_chunk_size:  657
# 3
# 4
# Token Count:  672
# balanced_chunk_size:  672
# 4
# 5
# Token Count:  693
# balanced_chunk_size:  693
# 5
# 6
# Token Count:  976
# balanced_chunk_size:  976
# 6
# 7
# Token Count:  646
# balanced_chunk_size:  646
# 7
# 8
# Token Count:  1724
# balanced_chunk_size:  862
# 8
# 10
# Token Count:  3935
# balanced_chunk_size:  983
# 10
# 14
# Token Count:  620
# balanced_chunk_size:  620
# 14
# 15
# Token Count:  593
# balanced_chunk_size:  593
# 15
# 16
# Token Count:  653
# balanced_chunk_size:  653
# 16
# 17
# Token Count:  635
# balanced_chunk_size:  635
# 17
# 18
# Token Count:  736
# balanced_chunk_size:  736
# 18
# 19
# Token Count:  690
# balanced_chunk_size:  690
# 19
# 20
# Token Count:  627
# balanced_chunk_size:  627
# 20
# 21
# Token Count:  857
# balanced_chunk_size:  857
# 21
# 22
# Token Count:  1027
# balanced_chunk_size:  513
# 22
# 25
# Token Count:  1117
# balanced_chunk_size:  558
# 25
# 28
# Token Count:  1072
# balanced_chunk_size:  536
# 28
# 31
# Token Count:  1096
# balanced_chunk_size:  548
# 31
# 34
# Token Count:  880
# balanced_chunk_size:  880
# 34
# 35
# Token Count:  815
# balanced_chunk_size:  815
# 35
# 36
# Token Count:  751
# balanced_chunk_size:  751
# 36
# 37
# Token Count:  721
# balanced_chunk_size:  721
# 37
# 38
# Token Count:  932
# balanced_chunk_size:  932
# 38
# 39
# Token Count:  1151
# balanced_chunk_size:  575
# 39
# 42
# Token Count:  901
# balanced_chunk_size:  901
# 42
# 43
# Token Count:  754
# balanced_chunk_size:  754
# 43
# 44
# Token Count:  838
# balanced_chunk_size:  838
# 44
# 45
# Token Count:  761
# balanced_chunk_size:  761
# 45
# 46
# Token Count:  1094
# balanced_chunk_size:  547
# 46
# 49
# Token Count:  638
# balanced_chunk_size:  638
# 49
# 50
# Token Count:  765
# balanced_chunk_size:  765
# 50
# 51
# Token Count:  4116
# balanced_chunk_size:  823
# 51
# 57
# Token Count:  1732
# balanced_chunk_size:  866
# 57
# 60
# Token Count:  815
# balanced_chunk_size:  815
# 60
# 61
# Token Count:  845
# balanced_chunk_size:  845
# 61
# 62
# Token Count:  837
# balanced_chunk_size:  837
# 62
# 63
# Token Count:  695
# balanced_chunk_size:  695
# 63
# 64
# Token Count:  693
# balanced_chunk_size:  693
# 64
# 65
# Token Count:  1005
# balanced_chunk_size:  502
# 65
# 67
# Token Count:  627
# balanced_chunk_size:  627
# 67
# 68
# Token Count:  571
# balanced_chunk_size:  571
# 68
# 69
# Token Count:  895
# balanced_chunk_size:  895
# 69
# 70
# Token Count:  608
# balanced_chunk_size:  608
# 70
# 71
# Token Count:  717
# balanced_chunk_size:  717
# 71
# 72
# Token Count:  921
# balanced_chunk_size:  921
# 72
# 73
# Token Count:  869
# balanced_chunk_size:  869
# 73
# 74
# Token Count:  724
# balanced_chunk_size:  724
# 74
# 75
# Token Count:  606
# balanced_chunk_size:  606
# 75
# 76
# Token Count:  990
# balanced_chunk_size:  990
# 76
# 77
# Token Count:  773
# balanced_chunk_size:  773
# 77
# 78
# Token Count:  783
# balanced_chunk_size:  783
# 78
# 79
# Token Count:  636
# balanced_chunk_size:  636
# 79
# 80
# Token Count:  1112
# balanced_chunk_size:  556
# 80
# 83
# Token Count:  811
# balanced_chunk_size:  811
# 83
# 84
# Token Count:  662
# balanced_chunk_size:  662
# 84
# 85
# Token Count:  1235
# balanced_chunk_size:  617
# 85
# 88
# Token Count:  1104
# balanced_chunk_size:  552
# 88
# 91
# Token Count:  866
# balanced_chunk_size:  866
# 91
# 92
# Token Count:  738
# balanced_chunk_size:  738
# 92
# 93
# Token Count:  781
# balanced_chunk_size:  781
# 93
# 94
# Token Count:  1014
# balanced_chunk_size:  507
# 94
# 96
# Token Count:  818
# balanced_chunk_size:  818
# 96
# 97
# Token Count:  960
# balanced_chunk_size:  960
# 97
# 98
# Token Count:  696
# balanced_chunk_size:  696
# 98
# 99
# Token Count:  1015
# balanced_chunk_size:  507
# 99
# 101
# Token Count:  764
# balanced_chunk_size:  764
# 101
# 102
# Token Count:  862
# balanced_chunk_size:  862
# 102
# 103
# Token Count:  973
# balanced_chunk_size:  973
# 103
# 104
# Token Count:  875
# balanced_chunk_size:  875
# 104
# 105
# Token Count:  1310
# balanced_chunk_size:  655
# 105
# 108
# Token Count:  1023
# balanced_chunk_size:  511
# 108
# 111
# Token Count:  1037
# balanced_chunk_size:  518
# 111
# 114
# Token Count:  1045
# balanced_chunk_size:  522
# 114
# 117
# Token Count:  646
# balanced_chunk_size:  646
# 117
# 118
# Token Count:  704
# balanced_chunk_size:  704
# 118
# 119
# Token Count:  1269
# balanced_chunk_size:  634
# 119
# 122
# Token Count:  624
# balanced_chunk_size:  624
# 122
# 123
# Token Count:  874
# balanced_chunk_size:  874
# 123
# 124
# Token Count:  665
# balanced_chunk_size:  665
# 124
# 125
# Token Count:  809
# balanced_chunk_size:  809
# 125
# 126
# Token Count:  921
# balanced_chunk_size:  921
# 126
# 127
# Token Count:  937
# balanced_chunk_size:  937
# 127
# 128
# Token Count:  845
# balanced_chunk_size:  845
# 128
# 129
# Token Count:  843
# balanced_chunk_size:  843
# 129
# 130
# Token Count:  889
# balanced_chunk_size:  889
# 130
# 131
# Token Count:  933
# balanced_chunk_size:  933
# 131
# 132
# Token Count:  1114
# balanced_chunk_size:  557
# 132
# 135
# Token Count:  842
# balanced_chunk_size:  842
# 135
# 136
# Token Count:  817
# balanced_chunk_size:  817
# 136
# 137
# Token Count:  817
# balanced_chunk_size:  817
# 137
# 138
# Token Count:  1383
# balanced_chunk_size:  691
# 138
# 141
# Token Count:  568
# balanced_chunk_size:  568
# 141
# 142
# Token Count:  805
# balanced_chunk_size:  805
# 142
# 143
# Token Count:  922
# balanced_chunk_size:  922
# 143
# 144
# Token Count:  810
# balanced_chunk_size:  810
# 144
# 145
# Token Count:  1139
# balanced_chunk_size:  569
# 145
# 148
# Token Count:  1320
# balanced_chunk_size:  660
# 148
# 151
# Token Count:  1047
# balanced_chunk_size:  523
# 151
# 153
# Token Count:  864
# balanced_chunk_size:  864
# 153
# 154
# Token Count:  918
# balanced_chunk_size:  918
# 154
# 155
# Token Count:  748
# balanced_chunk_size:  748
# 155
# 156
# Token Count:  788
# balanced_chunk_size:  788
# 156
# 157
# Token Count:  946
# balanced_chunk_size:  946
# 157
# 158
# Token Count:  915
# balanced_chunk_size:  915
# 158
# 159
# Token Count:  773
# balanced_chunk_size:  773
# 159
# 160
# Token Count:  691
# balanced_chunk_size:  691
# 160
# 161
# Token Count:  1100
# balanced_chunk_size:  550
# 161
# 163
# Token Count:  525
# balanced_chunk_size:  525
# 0
# 1
# Token Count:  400
# balanced_chunk_size:  400
# 0
# 1
# Token Count:  370
# balanced_chunk_size:  370
# 0
# 1
# Token Count:  625
# balanced_chunk_size:  625
# 0
# 1
# Token Count:  472
# balanced_chunk_size:  472
# 0
# 1
# Token Count:  320
# balanced_chunk_size:  320
# 0
# 1
# Token Count:  564
# balanced_chunk_size:  564
# 0
# 1
# Token Count:  598
# balanced_chunk_size:  598
# 0
# 1
# Token Count:  573
# balanced_chunk_size:  573
# 0
# 1
# Token Count:  472
# balanced_chunk_size:  472
# 0
# 1
# Token Count:  397
# balanced_chunk_size:  397
# 0
# 1
# Token Count:  329
# balanced_chunk_size:  329
# 0
# 1
# Token Count:  364
# balanced_chunk_size:  364
# 0
# 1
# Token Count:  848
# balanced_chunk_size:  848
# 0
# 1
# Token Count:  596
# balanced_chunk_size:  596
# 0
# 1
# Token Count:  337
# balanced_chunk_size:  337
# 0
# 1
# Token Count:  576
# balanced_chunk_size:  576
# 0
# 1
# Token Count:  402
# balanced_chunk_size:  402
# 0
# 1
# Token Count:  577
# balanced_chunk_size:  577
# 0
# 1
# Token Count:  396
# balanced_chunk_size:  396
# 0
# 1
# Token Count:  433
# balanced_chunk_size:  433
# 0
# 1
# Token Count:  409
# balanced_chunk_size:  409
# 0
# 1
# Token Count:  557
# balanced_chunk_size:  557
# 0
# 1
# Token Count:  432
# balanced_chunk_size:  432
# 0
# 1
# Token Count:  532
# balanced_chunk_size:  532
# 0
# 1
# Token Count:  340
# balanced_chunk_size:  340
# 0
# 1
# Token Count:  338
# balanced_chunk_size:  338
# 0
# 1
# Token Count:  556
# balanced_chunk_size:  556
# 0
# 1
# Token Count:  491
# balanced_chunk_size:  491
# 0
# 1
# Token Count:  476
# balanced_chunk_size:  476
# 0
# 1
# Token Count:  1835
# balanced_chunk_size:  917
# 1
# 3
# Token Count:  453
# balanced_chunk_size:  453
# 3
# 4
# Token Count:  491
# balanced_chunk_size:  491
# 4
# 5
# Token Count:  615
# balanced_chunk_size:  615
# 5
# 6
# Token Count:  2124
# balanced_chunk_size:  708
# 6
# 10
# Token Count:  2265
# balanced_chunk_size:  755
# 10
# 14
# Token Count:  1083
# balanced_chunk_size:  541
# 14
# 17
# Token Count:  562
# balanced_chunk_size:  562
# 17
# 18
# Token Count:  765
# balanced_chunk_size:  765
# 18
# 19
# Token Count:  680
# balanced_chunk_size:  680
# 19
# 20
# Token Count:  1373
# balanced_chunk_size:  686
# 20
# 23
# Token Count:  613
# balanced_chunk_size:  613
# 23
# 24
# Token Count:  1161
# balanced_chunk_size:  580
# 24
# 27
# Token Count:  699
# balanced_chunk_size:  699
# 27
# 28
# Token Count:  558
# balanced_chunk_size:  558
# 28
# 29
# Token Count:  2262
# balanced_chunk_size:  754
# 29
# 33
# Token Count:  602
# balanced_chunk_size:  602
# 33
# 34
# Token Count:  1448
# balanced_chunk_size:  724
# 34
# 37
# Token Count:  603
# balanced_chunk_size:  603
# 37
# 38
# Token Count:  649
# balanced_chunk_size:  649
# 38
# 39
# Token Count:  967
# balanced_chunk_size:  967
# 39
# 40
# Token Count:  907
# balanced_chunk_size:  907
# 40
# 41
# Token Count:  1295
# balanced_chunk_size:  647
# 41
# 44
# Token Count:  679
# balanced_chunk_size:  679
# 44
# 45
# Token Count:  1946
# balanced_chunk_size:  973
# 45
# 48
# Token Count:  1246
# balanced_chunk_size:  623
# 48
# 51
# Token Count:  1306
# balanced_chunk_size:  653
# 51
# 54
# Token Count:  555
# balanced_chunk_size:  555
# 54
# 55
# Token Count:  614
# balanced_chunk_size:  614
# 55
# 56
# Token Count:  936
# balanced_chunk_size:  936
# 56
# 57
# Token Count:  777
# balanced_chunk_size:  777
# 57
# 58
# Token Count:  971
# balanced_chunk_size:  971
# 58
# 59
# Token Count:  1050
# balanced_chunk_size:  525
# 59
# 62
# Token Count:  3044
# balanced_chunk_size:  761
# 62
# 67
# Token Count:  830
# balanced_chunk_size:  830
# 67
# 68
# Token Count:  1006
# balanced_chunk_size:  503
# 68
# 71
# Token Count:  1216
# balanced_chunk_size:  608
# 71
# 74
# Token Count:  955
# balanced_chunk_size:  955
# 74
# 75
# Token Count:  1264
# balanced_chunk_size:  632
# 75
# 78
# Token Count:  1353
# balanced_chunk_size:  676
# 78
# 81
# Token Count:  1847
# balanced_chunk_size:  923
# 81
# 84
# Token Count:  602
# balanced_chunk_size:  602
# 84
# 85
# Token Count:  833
# balanced_chunk_size:  833
# 85
# 86
# Token Count:  2551
# balanced_chunk_size:  850
# 86
# 90
# Token Count:  887
# balanced_chunk_size:  887
# 90
# 91
# Token Count:  544
# balanced_chunk_size:  544
# 91
# 92
# Token Count:  878
# balanced_chunk_size:  878
# 92
# 93
# Token Count:  1085
# balanced_chunk_size:  542
# 93
# 96
# Token Count:  1115
# balanced_chunk_size:  557
# 96
# 99
# Token Count:  1240
# balanced_chunk_size:  620
# 99
# 102
# Token Count:  1046
# balanced_chunk_size:  523
# 102
# 105
# Token Count:  1334
# balanced_chunk_size:  667
# 105
# 108
# Token Count:  1499
# balanced_chunk_size:  749
# 108
# 111
# Token Count:  805
# balanced_chunk_size:  805
# 111
# 112
# Token Count:  1057
# balanced_chunk_size:  528
# 112
# 115
# Token Count:  814
# balanced_chunk_size:  814
# 115
# 116
# Token Count:  977
# balanced_chunk_size:  977
# 116
# 117
# Token Count:  2642
# balanced_chunk_size:  880
# 117
# 121
# Token Count:  1140
# balanced_chunk_size:  570
# 121
# 124
# Token Count:  993
# balanced_chunk_size:  993
# 124
# 125
# Token Count:  2139
# balanced_chunk_size:  713
# 125
# 129
# Token Count:  608
# balanced_chunk_size:  608
# 129
# 130
# Token Count:  659
# balanced_chunk_size:  659
# 130
# 131
# Token Count:  954
# balanced_chunk_size:  954
# 131
# 132
# Token Count:  1263
# balanced_chunk_size:  631
# 132
# 135
# Token Count:  1335
# balanced_chunk_size:  667
# 135
# 138
# Token Count:  573
# balanced_chunk_size:  573
# 138
# 139
# Token Count:  632
# balanced_chunk_size:  632
# 139
# 140
# Token Count:  954
# balanced_chunk_size:  954
# 140
# 141
# Token Count:  783
# balanced_chunk_size:  783
# 141
# 142
# Token Count:  1319
# balanced_chunk_size:  659
# 142
# 145
# Token Count:  1035
# balanced_chunk_size:  517
# 145
# 148
# Token Count:  387
# balanced_chunk_size:  387
# 0
# 1
# Token Count:  1269
# balanced_chunk_size:  634
# 1
# 3
# Token Count:  407
# balanced_chunk_size:  407
# 3
# 4
# Token Count:  414
# balanced_chunk_size:  414
# 4
# 5
# Token Count:  431
# balanced_chunk_size:  431
# 5
# 6
# Token Count:  431
# balanced_chunk_size:  431
# 6
# 7
# Token Count:  431
# balanced_chunk_size:  431
# 7
# 8
# Token Count:  431
# balanced_chunk_size:  431
# 8
# 9
# Token Count:  431
# balanced_chunk_size:  431
# 9
# 10
# Token Count:  1307
# balanced_chunk_size:  653
# 10
# 12
# Token Count:  569
# balanced_chunk_size:  569
# 12
# 13
# Token Count:  549
# balanced_chunk_size:  549
# 13
# 14
# Token Count:  597
# balanced_chunk_size:  597
# 14
# 15
# Token Count:  647
# balanced_chunk_size:  647
# 15
# 16
# Token Count:  737
# balanced_chunk_size:  737
# 16
# 17
# Token Count:  1108
# balanced_chunk_size:  554
# 0
# 1
# Token Count:  1618
# balanced_chunk_size:  809
# 1
# 2
# Token Count:  1288
# balanced_chunk_size:  644
# 2
# 3
# Token Count:  1312
# balanced_chunk_size:  656
# 3
# 4
# Token Count:  1342
# balanced_chunk_size:  671
# 4
# 5
# Token Count:  1225
# balanced_chunk_size:  612
# 5
# 6
# Token Count:  1263
# balanced_chunk_size:  631
# 6
# 7
# Token Count:  1286
# balanced_chunk_size:  643
# 7
# 8
# Token Count:  1273
# balanced_chunk_size:  636
# 8
# 9
# Token Count:  1343
# balanced_chunk_size:  671
# 9
# 10
# Token Count:  1325
# balanced_chunk_size:  662
# 10
# 11
# Token Count:  1365
# balanced_chunk_size:  682
# 11
# 12
# Token Count:  1319
# balanced_chunk_size:  659
# 12
# 13
# Token Count:  1442
# balanced_chunk_size:  721
# 13
# 14
# Token Count:  1277
# balanced_chunk_size:  638
# 14
# 15
# Token Count:  1236
# balanced_chunk_size:  618
# 15
# 16
# Token Count:  2251
# balanced_chunk_size:  750
# 16
# 18
# Token Count:  336
# balanced_chunk_size:  336
# 0
# 1
# Token Count:  1447
# balanced_chunk_size:  723
# 1
# 3
# Token Count:  978
# balanced_chunk_size:  978
# 3
# 4
# Token Count:  476
# balanced_chunk_size:  476
# 4
# 5
# Token Count:  711
# balanced_chunk_size:  711
# 5
# 6
# Token Count:  503
# balanced_chunk_size:  503
# 6
# 7
# Token Count:  518
# balanced_chunk_size:  518
# 7
# 8
# Token Count:  628
# balanced_chunk_size:  628
# 8
# 9
# Token Count:  532
# balanced_chunk_size:  532
# 9
# 10
# Token Count:  579
# balanced_chunk_size:  579
# 10
# 11
# Token Count:  720
# balanced_chunk_size:  720
# 11
# 12
# Token Count:  502
# balanced_chunk_size:  502
# 12
# 13
# Token Count:  343
# balanced_chunk_size:  343
# 13
# 14
# Token Count:  696
# balanced_chunk_size:  696
# 14
# 15
# Token Count:  454
# balanced_chunk_size:  454
# 15
# 16
# Token Count:  496
# balanced_chunk_size:  496
# 16
# 17
# Token Count:  1453
# balanced_chunk_size:  726
# 17
# 20
# Token Count:  1305
# balanced_chunk_size:  652
# 20
# 23
# Token Count:  480
# balanced_chunk_size:  480
# 23
# 24
# Token Count:  599
# balanced_chunk_size:  599
# 24
# 25
# Token Count:  727
# balanced_chunk_size:  727
# 25
# 26
# Token Count:  635
# balanced_chunk_size:  635
# 26
# 27
# Token Count:  1020
# balanced_chunk_size:  510
# 27
# 30
# Token Count:  629
# balanced_chunk_size:  629
# 30
# 31
# Token Count:  890
# balanced_chunk_size:  890
# 31
# 32
# Token Count:  954
# balanced_chunk_size:  954
# 32
# 33
# Token Count:  529
# balanced_chunk_size:  529
# 33
# 34
# Token Count:  523
# balanced_chunk_size:  523
# 34
# 35
# Token Count:  819
# balanced_chunk_size:  819
# 35
# 36
# Token Count:  905
# balanced_chunk_size:  905
# 36
# 37
# Token Count:  821
# balanced_chunk_size:  821
# 37
# 38
# Token Count:  885
# balanced_chunk_size:  885
# 38
# 39
# Token Count:  551
# balanced_chunk_size:  551
# 39
# 40
# Token Count:  980
# balanced_chunk_size:  980
# 40
# 41
# Token Count:  916
# balanced_chunk_size:  916
# 41
# 42
# Token Count:  676
# balanced_chunk_size:  676
# 42
# 43
# Token Count:  1252
# balanced_chunk_size:  626
# 43
# 46
# Token Count:  922
# balanced_chunk_size:  922
# 46
# 47
# Token Count:  807
# balanced_chunk_size:  807
# 47
# 48
# Token Count:  855
# balanced_chunk_size:  855
# 48
# 49
# Token Count:  747
# balanced_chunk_size:  747
# 49
# 50
# Token Count:  906
# balanced_chunk_size:  906
# 50
# 51
# Token Count:  1226
# balanced_chunk_size:  613
# 51
# 54
# Token Count:  870
# balanced_chunk_size:  870
# 54
# 55
# Token Count:  639
# balanced_chunk_size:  639
# 55
# 56
# Token Count:  1023
# balanced_chunk_size:  511
# 56
# 59
# Token Count:  423
# balanced_chunk_size:  423
# 59
# 60
# Token Count:  502
# balanced_chunk_size:  502
# 60
# 61
# Token Count:  965
# balanced_chunk_size:  965
# 61
# 62
# Token Count:  544
# balanced_chunk_size:  544
# 62
# 63
# Token Count:  870
# balanced_chunk_size:  870
# 63
# 64
# Token Count:  757
# balanced_chunk_size:  757
# 64
# 65
# Token Count:  523
# balanced_chunk_size:  523
# 65
# 66
# Token Count:  879
# balanced_chunk_size:  879
# 66
# 67
# Token Count:  579
# balanced_chunk_size:  579
# 67
# 68
# Token Count:  1130
# balanced_chunk_size:  565
# 68
# 71
# Token Count:  573
# balanced_chunk_size:  573
# 71
# 72
# Token Count:  527
# balanced_chunk_size:  527
# 72
# 73
# Token Count:  1639
# balanced_chunk_size:  819
# 73
# 76
# Token Count:  418
# balanced_chunk_size:  418
# 76
# 77
# Token Count:  462
# balanced_chunk_size:  462
# 77
# 78
# Token Count:  1309
# balanced_chunk_size:  654
# 78
# 81
# Token Count:  462
# balanced_chunk_size:  462
# 81
# 82
# Token Count:  561
# balanced_chunk_size:  561
# 82
# 83
# Token Count:  529
# balanced_chunk_size:  529
# 83
# 84
# Token Count:  425
# balanced_chunk_size:  425
# 84
# 85
# Token Count:  519
# balanced_chunk_size:  519
# 85
# 86
# Token Count:  790
# balanced_chunk_size:  790
# 86
# 87
# Token Count:  404
# balanced_chunk_size:  404
# 87
# 88
# Token Count:  844
# balanced_chunk_size:  844
# 88
# 89
# Token Count:  1357
# balanced_chunk_size:  678
# 89
# 92
# Token Count:  558
# balanced_chunk_size:  558
# 92
# 93
# Token Count:  575
# balanced_chunk_size:  575
# 93
# 94
# Token Count:  565
# balanced_chunk_size:  565
# 94
# 95
# Token Count:  429
# balanced_chunk_size:  429
# 95
# 96
# Token Count:  479
# balanced_chunk_size:  479
# 96
# 97
# Token Count:  373
# balanced_chunk_size:  373
# 97
# 98
# Token Count:  521
# balanced_chunk_size:  521
# 98
# 99
# Token Count:  483
# balanced_chunk_size:  483
# 99
# 100
# Token Count:  544
# balanced_chunk_size:  544
# 100
# 101
# Token Count:  513
# balanced_chunk_size:  513
# 101
# 102
# Token Count:  446
# balanced_chunk_size:  446
# 102
# 103
# Token Count:  483
# balanced_chunk_size:  483
# 103
# 104
# Token Count:  497
# balanced_chunk_size:  497
# 104
# 105
# Token Count:  879
# balanced_chunk_size:  879
# 105
# 106
# Token Count:  386
# balanced_chunk_size:  386
# 106
# 107
# Token Count:  494
# balanced_chunk_size:  494
# 107
# 108
# Token Count:  425
# balanced_chunk_size:  425
# 108
# 109
# Token Count:  427
# balanced_chunk_size:  427
# 109
# 110
# Token Count:  504
# balanced_chunk_size:  504
# 110
# 111
# Token Count:  369
# balanced_chunk_size:  369
# 111
# 112
# Token Count:  553
# balanced_chunk_size:  553
# 112
# 113
# Token Count:  416
# balanced_chunk_size:  416
# 0
# 1
# Token Count:  1089
# balanced_chunk_size:  544
# 1
# 3
# Token Count:  403
# balanced_chunk_size:  403
# 3
# 4
# Token Count:  430
# balanced_chunk_size:  430
# 4
# 5
# Token Count:  427
# balanced_chunk_size:  427
# 5
# 6
# Token Count:  427
# balanced_chunk_size:  427
# 6
# 7
# Token Count:  427
# balanced_chunk_size:  427
# 7
# 8
# Token Count:  427
# balanced_chunk_size:  427
# 8
# 9
# Token Count:  427
# balanced_chunk_size:  427
# 9
# 10
# Token Count:  427
# balanced_chunk_size:  427
# 10
# 11
# Token Count:  427
# balanced_chunk_size:  427
# 11
# 12
# Token Count:  793
# balanced_chunk_size:  793
# 12
# 13
# Token Count:  396
# balanced_chunk_size:  396
# 13
# 14
# Token Count:  1758
# balanced_chunk_size:  879
# 14
# 17
# Token Count:  609
# balanced_chunk_size:  609
# 17
# 18
# Token Count:  770
# balanced_chunk_size:  770
# 18
# 19
# Token Count:  704
# balanced_chunk_size:  704
# 19
# 20
# Token Count:  594
# balanced_chunk_size:  594
# 20
# 21
# Token Count:  834
# balanced_chunk_size:  834
# 21
# 22
# Token Count:  734
# balanced_chunk_size:  734
# 22
# 23
# Token Count:  408
# balanced_chunk_size:  408
# 23
# 24
# Token Count:  952
# balanced_chunk_size:  952
# 24
# 25
# Token Count:  803
# balanced_chunk_size:  803
# 25
# 26
# Token Count:  532
# balanced_chunk_size:  532
# 26
# 27
# Token Count:  486
# balanced_chunk_size:  486
# 27
# 28
# Token Count:  552
# balanced_chunk_size:  552
# 28
# 29
# Token Count:  470
# balanced_chunk_size:  470
# 29
# 30
# Token Count:  566
# balanced_chunk_size:  566
# 30
# 31
# Token Count:  661
# balanced_chunk_size:  661
# 31
# 32
# Token Count:  620
# balanced_chunk_size:  620
# 32
# 33
# Token Count:  610
# balanced_chunk_size:  610
# 33
# 34
# Token Count:  518
# balanced_chunk_size:  518
# 34
# 35
# Token Count:  643
# balanced_chunk_size:  643
# 35
# 36
# Token Count:  626
# balanced_chunk_size:  626
# 36
# 37
# Token Count:  512
# balanced_chunk_size:  512
# 37
# 38
# Token Count:  597
# balanced_chunk_size:  597
# 38
# 39
# Token Count:  551
# balanced_chunk_size:  551
# 39
# 40
# Token Count:  674
# balanced_chunk_size:  674
# 40
# 41
# Token Count:  605
# balanced_chunk_size:  605
# 41
# 42
# Token Count:  697
# balanced_chunk_size:  697
# 42
# 43
# Token Count:  800
# balanced_chunk_size:  800
# 43
# 44
# Token Count:  688
# balanced_chunk_size:  688
# 44
# 45
# Token Count:  441
# balanced_chunk_size:  441
# 45
# 46
# Token Count:  572
# balanced_chunk_size:  572
# 46
# 47
# Token Count:  749
# balanced_chunk_size:  749
# 47
# 48
# Token Count:  576
# balanced_chunk_size:  576
# 48
# 49
# Token Count:  468
# balanced_chunk_size:  468
# 49
# 50
# Token Count:  891
# balanced_chunk_size:  891
# 50
# 51
# Token Count:  629
# balanced_chunk_size:  629
# 51
# 52
# Token Count:  822
# balanced_chunk_size:  822
# 52
# 53
# Token Count:  689
# balanced_chunk_size:  689
# 53
# 54
# Token Count:  1028
# balanced_chunk_size:  514
# 54
# 57
# Token Count:  534
# balanced_chunk_size:  534
# 57
# 58
# Token Count:  908
# balanced_chunk_size:  908
# 58
# 59
# Token Count:  587
# balanced_chunk_size:  587
# 59
# 60
# Token Count:  570
# balanced_chunk_size:  570
# 60
# 61
# Token Count:  524
# balanced_chunk_size:  524
# 61
# 62
# Token Count:  618
# balanced_chunk_size:  618
# 62
# 63
# Token Count:  486
# balanced_chunk_size:  486
# 63
# 64
# Token Count:  645
# balanced_chunk_size:  645
# 64
# 65
# Token Count:  420
# balanced_chunk_size:  420
# 65
# 66
# Token Count:  1092
# balanced_chunk_size:  546
# 66
# 69
# Token Count:  578
# balanced_chunk_size:  578
# 69
# 70
# Token Count:  522
# balanced_chunk_size:  522
# 70
# 71
# Token Count:  503
# balanced_chunk_size:  503
# 71
# 72
# Token Count:  589
# balanced_chunk_size:  589
# 72
# 73
# Token Count:  736
# balanced_chunk_size:  736
# 73
# 74
# Token Count:  619
# balanced_chunk_size:  619
# 74
# 75
# Token Count:  667
# balanced_chunk_size:  667
# 75
# 76
# Token Count:  457
# balanced_chunk_size:  457
# 76
# 77
# Token Count:  426
# balanced_chunk_size:  426
# 77
# 78
# Token Count:  840
# balanced_chunk_size:  840
# 78
# 79
# Token Count:  655
# balanced_chunk_size:  655
# 79
# 80
# Token Count:  733
# balanced_chunk_size:  733
# 80
# 81
# Token Count:  518
# balanced_chunk_size:  518
# 81
# 82
# Token Count:  405
# balanced_chunk_size:  405
# 82
# 83
# Token Count:  405
# balanced_chunk_size:  405
# 83
# 84
# Token Count:  543
# balanced_chunk_size:  543
# 84
# 85
# Token Count:  477
# balanced_chunk_size:  477
# 85
# 86
# Token Count:  984
# balanced_chunk_size:  984
# 0
# 1
# Token Count:  2052
# balanced_chunk_size:  684
# 1
# 3
# Token Count:  1468
# balanced_chunk_size:  734
# 3
# 4
# Token Count:  1560
# balanced_chunk_size:  780
# 4
# 5
# Token Count:  1249
# balanced_chunk_size:  624
# 5
# 6
# Token Count:  1280
# balanced_chunk_size:  640
# 6
# 7
# Token Count:  1592
# balanced_chunk_size:  796
# 7
# 8
# Token Count:  1464
# balanced_chunk_size:  732
# 8
# 9
# Token Count:  1469
# balanced_chunk_size:  734
# 9
# 10
# Token Count:  1344
# balanced_chunk_size:  672
# 10
# 11
# Token Count:  1500
# balanced_chunk_size:  750
# 11
# 12
# Token Count:  1690
# balanced_chunk_size:  845
# 12
# 13
# Token Count:  1389
# balanced_chunk_size:  694
# 13
# 14
# Token Count:  1409
# balanced_chunk_size:  704
# 14
# 15
# Token Count:  1638
# balanced_chunk_size:  819
# 15
# 16
# Token Count:  2062
# balanced_chunk_size:  687
# 16
# 18
# Token Count:  1318
# balanced_chunk_size:  659
# 18
# 19
# Token Count:  1422
# balanced_chunk_size:  711
# 19
# 20
# Token Count:  1467
# balanced_chunk_size:  733
# 20
# 21
# Token Count:  1739
# balanced_chunk_size:  869
# 21
# 22
# Token Count:  1677
# balanced_chunk_size:  838
# 22
# 23
# Token Count:  1081
# balanced_chunk_size:  540
# 23
# 24
# Token Count:  970
# balanced_chunk_size:  970
# 24
# 25
# Token Count:  1043
# balanced_chunk_size:  521
# 25
# 26
# Token Count:  1044
# balanced_chunk_size:  522
# 26
# 27
# Token Count:  1074
# balanced_chunk_size:  537
# 27
# 28
# Token Count:  1027
# balanced_chunk_size:  513
# 28
# 29
# Token Count:  1016
# balanced_chunk_size:  508
# 29
# 30
# Token Count:  1063
# balanced_chunk_size:  531
# 30
# 31
# Token Count:  1101
# balanced_chunk_size:  550
# 31
# 32
# Token Count:  1507
# balanced_chunk_size:  753
# 32
# 33
# Token Count:  1046
# balanced_chunk_size:  523
# 33
# 34
# Token Count:  1116
# balanced_chunk_size:  558
# 34
# 35
# Token Count:  1343
# balanced_chunk_size:  671
# 35
# 36
# Token Count:  1376
# balanced_chunk_size:  688
# 36
# 37
# Token Count:  1011
# balanced_chunk_size:  505
# 37
# 38
# Token Count:  1032
# balanced_chunk_size:  516
# 38
# 39
# Token Count:  1213
# balanced_chunk_size:  606
# 39
# 40
# Token Count:  1191
# balanced_chunk_size:  595
# 40
# 41
# Token Count:  1280
# balanced_chunk_size:  640
# 41
# 42
# Token Count:  1290
# balanced_chunk_size:  645
# 42
# 43
# Token Count:  1059
# balanced_chunk_size:  529
# 43
# 44
# Token Count:  1065
# balanced_chunk_size:  532
# 44
# 45
# Token Count:  1052
# balanced_chunk_size:  526
# 45
# 46
# Token Count:  1293
# balanced_chunk_size:  646
# 46
# 47
# Token Count:  1724
# balanced_chunk_size:  862
# 47
# 48
# Token Count:  1549
# balanced_chunk_size:  774
# 48
# 49
# Token Count:  1024
# balanced_chunk_size:  512
# 49
# 50
# Token Count:  1086
# balanced_chunk_size:  543
# 50
# 51
# Token Count:  1092
# balanced_chunk_size:  546
# 51
# 52
# Token Count:  1142
# balanced_chunk_size:  571
# 52
# 53
# Token Count:  1104
# balanced_chunk_size:  552
# 53
# 54
# Token Count:  1141
# balanced_chunk_size:  570
# 54
# 55
# Token Count:  1092
# balanced_chunk_size:  546
# 55
# 56
# Token Count:  1220
# balanced_chunk_size:  610
# 56
# 57
# Token Count:  1076
# balanced_chunk_size:  538
# 57
# 58
# Token Count:  1104
# balanced_chunk_size:  552
# 58
# 59
# Token Count:  1114
# balanced_chunk_size:  557
# 59
# 60
# Token Count:  1126
# balanced_chunk_size:  563
# 60
# 61
# Token Count:  1156
# balanced_chunk_size:  578
# 61
# 62
# Token Count:  1179
# balanced_chunk_size:  589
# 62
# 63
# Token Count:  1109
# balanced_chunk_size:  554
# 63
# 64
# Token Count:  1152
# balanced_chunk_size:  576
# 64
# 65
# Token Count:  1121
# balanced_chunk_size:  560
# 65
# 66
# Token Count:  1533
# balanced_chunk_size:  766
# 66
# 67
# Token Count:  1730
# balanced_chunk_size:  865
# 67
# 68
# Token Count:  1264
# balanced_chunk_size:  632
# 68
# 69
# Token Count:  2221
# balanced_chunk_size:  740
# 69
# 72
# Token Count:  1464
# balanced_chunk_size:  732
# 72
# 73
# Token Count:  1874
# balanced_chunk_size:  937
# 73
# 74
# Token Count:  1734
# balanced_chunk_size:  867
# 74
# 75
# Token Count:  1675
# balanced_chunk_size:  837
# 75
# 76
# Token Count:  1373
# balanced_chunk_size:  686
# 76
# 77
# Token Count:  1539
# balanced_chunk_size:  769
# 77
# 78
# Token Count:  318
# balanced_chunk_size:  318
# 0
# 1
# Token Count:  1387
# balanced_chunk_size:  693
# 1
# 3
# Token Count:  532
# balanced_chunk_size:  532
# 3
# 4
# Token Count:  538
# balanced_chunk_size:  538
# 4
# 5
# Token Count:  568
# balanced_chunk_size:  568
# 5
# 6
# Token Count:  504
# balanced_chunk_size:  504
# 6
# 7
# Token Count:  571
# balanced_chunk_size:  571
# 7
# 8
# Token Count:  555
# balanced_chunk_size:  555
# 8
# 9
# Token Count:  1103
# balanced_chunk_size:  551
# 9
# 11
# Token Count:  519
# balanced_chunk_size:  519
# 11
# 12
# Token Count:  662
# balanced_chunk_size:  662
# 12
# 13
# Token Count:  439
# balanced_chunk_size:  439
# 13
# 14
# Token Count:  550
# balanced_chunk_size:  550
# 14
# 15
# Token Count:  421
# balanced_chunk_size:  421
# 15
# 16
# Token Count:  1026
# balanced_chunk_size:  513
# 16
# 18
# Token Count:  542
# balanced_chunk_size:  542
# 18
# 19
# Token Count:  434
# balanced_chunk_size:  434
# 19
# 20
# Token Count:  694
# balanced_chunk_size:  694
# 20
# 21
# Token Count:  722
# balanced_chunk_size:  722
# 21
# 22
# Token Count:  676
# balanced_chunk_size:  676
# 22
# 23
# Token Count:  547
# balanced_chunk_size:  547
# 23
# 24
# Token Count:  635
# balanced_chunk_size:  635
# 24
# 25
# Token Count:  460
# balanced_chunk_size:  460
# 25
# 26
# Token Count:  1348
# balanced_chunk_size:  674
# 26
# 29
# Token Count:  834
# balanced_chunk_size:  834
# 29
# 30
# Token Count:  794
# balanced_chunk_size:  794
# 30
# 31
# Token Count:  819
# balanced_chunk_size:  819
# 31
# 32
# Token Count:  845
# balanced_chunk_size:  845
# 32
# 33
# Token Count:  718
# balanced_chunk_size:  718
# 33
# 34
# Token Count:  595
# balanced_chunk_size:  595
# 34
# 35
# Token Count:  644
# balanced_chunk_size:  644
# 35
# 36
# Token Count:  630
# balanced_chunk_size:  630
# 36
# 37
# Token Count:  1014
# balanced_chunk_size:  507
# 37
# 40
# Token Count:  484
# balanced_chunk_size:  484
# 40
# 41
# Token Count:  1243
# balanced_chunk_size:  621
# 41
# 44
# Token Count:  786
# balanced_chunk_size:  786
# 44
# 45
# Token Count:  567
# balanced_chunk_size:  567
# 45
# 46
# Token Count:  525
# balanced_chunk_size:  525
# 46
# 47
# Token Count:  1169
# balanced_chunk_size:  584
# 47
# 50
# Token Count:  687
# balanced_chunk_size:  687
# 50
# 51
# Token Count:  828
# balanced_chunk_size:  828
# 51
# 52
# Token Count:  854
# balanced_chunk_size:  854
# 52
# 53
# Token Count:  917
# balanced_chunk_size:  917
# 53
# 54
# Token Count:  925
# balanced_chunk_size:  925
# 54
# 55
# Token Count:  522
# balanced_chunk_size:  522
# 55
# 56
# Token Count:  670
# balanced_chunk_size:  670
# 56
# 57
# Token Count:  1016
# balanced_chunk_size:  508
# 57
# 60
# Token Count:  1137
# balanced_chunk_size:  568
# 60
# 63
# Token Count:  416
# balanced_chunk_size:  416
# 63
# 64
# Token Count:  1005
# balanced_chunk_size:  502
# 64
# 67
# Token Count:  823
# balanced_chunk_size:  823
# 67
# 68
# Token Count:  966
# balanced_chunk_size:  966
# 68
# 69
# Token Count:  1086
# balanced_chunk_size:  543
# 69
# 72
# Token Count:  477
# balanced_chunk_size:  477
# 72
# 73
# Token Count:  675
# balanced_chunk_size:  675
# 73
# 74
# Token Count:  732
# balanced_chunk_size:  732
# 74
# 75
# Token Count:  1169
# balanced_chunk_size:  584
# 75
# 78
# Token Count:  785
# balanced_chunk_size:  785
# 78
# 79
# Token Count:  534
# balanced_chunk_size:  534
# 79
# 80
# Token Count:  1182
# balanced_chunk_size:  591
# 80
# 83
# Token Count:  663
# balanced_chunk_size:  663
# 83
# 84
# Token Count:  453
# balanced_chunk_size:  453
# 84
# 85
# Token Count:  449
# balanced_chunk_size:  449
# 85
# 86
# Token Count:  506
# balanced_chunk_size:  506
# 86
# 87
# Token Count:  524
# balanced_chunk_size:  524
# 87
# 88
# Token Count:  887
# balanced_chunk_size:  887
# 88
# 89
# Token Count:  751
# balanced_chunk_size:  751
# 89
# 90
# Token Count:  988
# balanced_chunk_size:  988
# 90
# 91
# Token Count:  365
# balanced_chunk_size:  365
# 91
# 92
# Token Count:  420
# balanced_chunk_size:  420
# 92
# 93
# Token Count:  481
# balanced_chunk_size:  481
# 93
# 94
# Token Count:  362
# balanced_chunk_size:  362
# 94
# 95
# Token Count:  654
# balanced_chunk_size:  654
# 95
# 96
# Token Count:  387
# balanced_chunk_size:  387
# 96
# 97
# Token Count:  371
# balanced_chunk_size:  371
# 97
# 98
# Token Count:  407
# balanced_chunk_size:  407
# 98
# 99
# Token Count:  1029
# balanced_chunk_size:  514
# 99
# 102
# Token Count:  952
# balanced_chunk_size:  952
# 102
# 103
# Token Count:  714
# balanced_chunk_size:  714
# 103
# 104
# Token Count:  810
# balanced_chunk_size:  810
# 104
# 105
# Token Count:  365
# balanced_chunk_size:  365
# 105
# 106
# Token Count:  362
# balanced_chunk_size:  362
# 106
# 107
# Token Count:  657
# balanced_chunk_size:  657
# 107
# 108
# Token Count:  635
# balanced_chunk_size:  635
# 108
# 109
# Token Count:  1136
# balanced_chunk_size:  568
# 109
# 112
# Token Count:  652
# balanced_chunk_size:  652
# 112
# 113
# Token Count:  422
# balanced_chunk_size:  422
# 113
# 114
# Token Count:  691
# balanced_chunk_size:  691
# 114
# 115
# Token Count:  900
# balanced_chunk_size:  900
# 115
# 116
# Token Count:  1018
# balanced_chunk_size:  509
# 116
# 119
# Token Count:  423
# balanced_chunk_size:  423
# 119
# 120
# Token Count:  364
# balanced_chunk_size:  364
# 120
# 121
# Token Count:  479
# balanced_chunk_size:  479
# 121
# 122
# Token Count:  386
# balanced_chunk_size:  386
# 122
# 123
# Token Count:  454
# balanced_chunk_size:  454
# 123
# 124
# Token Count:  364
# balanced_chunk_size:  364
# 124
# 125
# Token Count:  408
# balanced_chunk_size:  408
# 0
# 1
# Token Count:  1326
# balanced_chunk_size:  663
# 1
# 3
# Token Count:  813
# balanced_chunk_size:  813
# 3
# 4
# Token Count:  810
# balanced_chunk_size:  810
# 4
# 5
# Token Count:  1013
# balanced_chunk_size:  506
# 5
# 8
# Token Count:  1047
# balanced_chunk_size:  523
# 8
# 11
# Token Count:  743
# balanced_chunk_size:  743
# 11
# 12
# Token Count:  635
# balanced_chunk_size:  635
# 12
# 13
# Token Count:  446
# balanced_chunk_size:  446
# 13
# 14
# Token Count:  1179
# balanced_chunk_size:  589
# 14
# 17
# Token Count:  493
# balanced_chunk_size:  493
# 17
# 18
# Token Count:  814
# balanced_chunk_size:  814
# 18
# 19
# Token Count:  876
# balanced_chunk_size:  876
# 19
# 20
# Token Count:  523
# balanced_chunk_size:  523
# 20
# 21
# Token Count:  955
# balanced_chunk_size:  955
# 21
# 22
# Token Count:  580
# balanced_chunk_size:  580
# 22
# 23
# Token Count:  1420
# balanced_chunk_size:  710
# 23
# 26
# Token Count:  1039
# balanced_chunk_size:  519
# 26
# 29
# Token Count:  829
# balanced_chunk_size:  829
# 29
# 30
# Token Count:  697
# balanced_chunk_size:  697
# 30
# 31
# Token Count:  892
# balanced_chunk_size:  892
# 31
# 32
# Token Count:  629
# balanced_chunk_size:  629
# 32
# 33
# Token Count:  517
# balanced_chunk_size:  517
# 33
# 34
# Token Count:  1138
# balanced_chunk_size:  569
# 34
# 37
# Token Count:  1248
# balanced_chunk_size:  624
# 37
# 40
# Token Count:  956
# balanced_chunk_size:  956
# 40
# 41
# Token Count:  516
# balanced_chunk_size:  516
# 41
# 42
# Token Count:  1626
# balanced_chunk_size:  813
# 42
# 45
# Token Count:  1552
# balanced_chunk_size:  776
# 45
# 48
# Token Count:  1295
# balanced_chunk_size:  647
# 48
# 51
# Token Count:  1340
# balanced_chunk_size:  670
# 51
# 54
# Token Count:  2062
# balanced_chunk_size:  687
# 54
# 58
# Token Count:  952
# balanced_chunk_size:  952
# 58
# 59
# Token Count:  534
# balanced_chunk_size:  534
# 59
# 60
# Token Count:  534
# balanced_chunk_size:  534
# 60
# 61
# Token Count:  918
# balanced_chunk_size:  918
# 61
# 62
# Token Count:  515
# balanced_chunk_size:  515
# 62
# 63
# Token Count:  857
# balanced_chunk_size:  857
# 63
# 64
# Token Count:  925
# balanced_chunk_size:  925
# 64
# 65
# Token Count:  856
# balanced_chunk_size:  856
# 65
# 66
# Token Count:  1111
# balanced_chunk_size:  555
# 66
# 69
# Token Count:  864
# balanced_chunk_size:  864
# 69
# 70
# Token Count:  593
# balanced_chunk_size:  593
# 70
# 71
# Token Count:  580
# balanced_chunk_size:  580
# 71
# 72
# Token Count:  1340
# balanced_chunk_size:  670
# 72
# 75
# Token Count:  1103
# balanced_chunk_size:  551
# 75
# 78
# Token Count:  838
# balanced_chunk_size:  838
# 78
# 79
# Token Count:  526
# balanced_chunk_size:  526
# 79
# 80
# Token Count:  764
# balanced_chunk_size:  764
# 80
# 81
# Token Count:  788
# balanced_chunk_size:  788
# 81
# 82
# Token Count:  964
# balanced_chunk_size:  964
# 82
# 83
# Token Count:  1011
# balanced_chunk_size:  505
# 83
# 86
# Token Count:  746
# balanced_chunk_size:  746
# 86
# 87
# Token Count:  876
# balanced_chunk_size:  876
# 87
# 88
# Token Count:  582
# balanced_chunk_size:  582
# 88
# 89
# Token Count:  1191
# balanced_chunk_size:  595
# 89
# 92
# Token Count:  1075
# balanced_chunk_size:  537
# 92
# 95
# Token Count:  708
# balanced_chunk_size:  708
# 95
# 96
# Token Count:  1277
# balanced_chunk_size:  638
# 96
# 99
# Token Count:  499
# balanced_chunk_size:  499
# 99
# 100
# Token Count:  1152
# balanced_chunk_size:  576
# 100
# 103
# Token Count:  1010
# balanced_chunk_size:  505
# 103
# 106
# Token Count:  712
# balanced_chunk_size:  712
# 106
# 107
# Token Count:  738
# balanced_chunk_size:  738
# 107
# 108
# Token Count:  925
# balanced_chunk_size:  925
# 108
# 109
# Token Count:  481
# balanced_chunk_size:  481
# 109
# 110
# Token Count:  705
# balanced_chunk_size:  705
# 110
# 111
# Token Count:  477
# balanced_chunk_size:  477
# 111
# 112
# Token Count:  701
# balanced_chunk_size:  701
# 112
# 113
# Token Count:  481
# balanced_chunk_size:  481
# 113
# 114
# Token Count:  705
# balanced_chunk_size:  705
# 114
# 115
# Token Count:  667
# balanced_chunk_size:  667
# 115
# 116
# Token Count:  477
# balanced_chunk_size:  477
# 116
# 117
# Token Count:  1228
# balanced_chunk_size:  614
# 117
# 120
# Token Count:  616
# balanced_chunk_size:  616
# 120
# 121
# Token Count:  553
# balanced_chunk_size:  553
# 121
# 122
# Token Count:  581
# balanced_chunk_size:  581
# 122
# 123
# Token Count:  529
# balanced_chunk_size:  529
# 123
# 124
# Token Count:  646
# balanced_chunk_size:  646
# 124
# 125
# Token Count:  923
# balanced_chunk_size:  923
# 125
# 126
# Token Count:  613
# balanced_chunk_size:  613
# 126
# 127
# Token Count:  576
# balanced_chunk_size:  576
# 127
# 128
# Token Count:  533
# balanced_chunk_size:  533
# 128
# 129
# Token Count:  532
# balanced_chunk_size:  532
# 129
# 130
# Token Count:  622
# balanced_chunk_size:  622
# 130
# 131
# Token Count:  689
# balanced_chunk_size:  689
# 131
# 132
# Token Count:  587
# balanced_chunk_size:  587
# 132
# 133
# Token Count:  576
# balanced_chunk_size:  576
# 133
# 134
# Token Count:  547
# balanced_chunk_size:  547
# 134
# 135
# Token Count:  627
# balanced_chunk_size:  627
# 135
# 136
# Token Count:  449
# balanced_chunk_size:  449
# 136
# 137
# Token Count:  557
# balanced_chunk_size:  557
# 137
# 138
# Token Count:  493
# balanced_chunk_size:  493
# 138
# 139
# Token Count:  578
# balanced_chunk_size:  578
# 139
# 140
# Token Count:  397
# balanced_chunk_size:  397
# 0
# 1
# Token Count:  1461
# balanced_chunk_size:  730
# 1
# 3
# Token Count:  481
# balanced_chunk_size:  481
# 3
# 4
# Token Count:  513
# balanced_chunk_size:  513
# 4
# 5
# Token Count:  349
# balanced_chunk_size:  349
# 5
# 6
# Token Count:  354
# balanced_chunk_size:  354
# 6
# 7
# Token Count:  419
# balanced_chunk_size:  419
# 7
# 8
# Token Count:  522
# balanced_chunk_size:  522
# 8
# 9
# Token Count:  742
# balanced_chunk_size:  742
# 9
# 10
# Token Count:  906
# balanced_chunk_size:  906
# 10
# 11
# Token Count:  739
# balanced_chunk_size:  739
# 11
# 12
# Token Count:  515
# balanced_chunk_size:  515
# 12
# 13
# Token Count:  680
# balanced_chunk_size:  680
# 13
# 14
# Token Count:  1020
# balanced_chunk_size:  510
# 14
# 17
# Token Count:  496
# balanced_chunk_size:  496
# 17
# 18
# Token Count:  420
# balanced_chunk_size:  420
# 18
# 19
# Token Count:  487
# balanced_chunk_size:  487
# 19
# 20
# Token Count:  484
# balanced_chunk_size:  484
# 20
# 21
# Token Count:  438
# balanced_chunk_size:  438
# 21
# 22
# Token Count:  405
# balanced_chunk_size:  405
# 22
# 23
# Token Count:  418
# balanced_chunk_size:  418
# 23
# 24
# Token Count:  450
# balanced_chunk_size:  450
# 24
# 25
# Token Count:  566
# balanced_chunk_size:  566
# 25
# 26
# Token Count:  660
# balanced_chunk_size:  660
# 26
# 27
# Token Count:  430
# balanced_chunk_size:  430
# 27
# 28
# Token Count:  538
# balanced_chunk_size:  538
# 28
# 29
# Token Count:  506
# balanced_chunk_size:  506
# 29
# 30
# Token Count:  365
# balanced_chunk_size:  365
# 30
# 31
# Token Count:  376
# balanced_chunk_size:  376
# 31
# 32
# Token Count:  462
# balanced_chunk_size:  462
# 32
# 33
# Token Count:  462
# balanced_chunk_size:  462
# 33
# 34
# Token Count:  480
# balanced_chunk_size:  480
# 34
# 35
# Token Count:  376
# balanced_chunk_size:  376
# 35
# 36
# Token Count:  388
# balanced_chunk_size:  388
# 36
# 37
# Token Count:  524
# balanced_chunk_size:  524
# 37
# 38
# Token Count:  394
# balanced_chunk_size:  394
# 38
# 39
# Token Count:  500
# balanced_chunk_size:  500
# 39
# 40
# Token Count:  407
# balanced_chunk_size:  407
# 40
# 41
# Token Count:  489
# balanced_chunk_size:  489
# 41
# 42
# Token Count:  487
# balanced_chunk_size:  487
# 42
# 43
# Token Count:  405
# balanced_chunk_size:  405
# 43
# 44
# Token Count:  430
# balanced_chunk_size:  430
# 44
# 45
# Token Count:  450
# balanced_chunk_size:  450
# 45
# 46
# Token Count:  463
# balanced_chunk_size:  463
# 46
# 47
# Token Count:  356
# balanced_chunk_size:  356
# 47
# 48
# Token Count:  436
# balanced_chunk_size:  436
# 48
# 49
# Token Count:  559
# balanced_chunk_size:  559
# 49
# 50
# Token Count:  381
# balanced_chunk_size:  381
# 50
# 51
# Token Count:  425
# balanced_chunk_size:  425
# 51
# 52
# Token Count:  416
# balanced_chunk_size:  416
# 52
# 53
# Token Count:  382
# balanced_chunk_size:  382
# 53
# 54
# Token Count:  479
# balanced_chunk_size:  479
# 54
# 55
# Token Count:  1063
# balanced_chunk_size:  531
# 55
# 58
# Token Count:  339
# balanced_chunk_size:  339
# 58
# 59
# Token Count:  629
# ...
# balanced_chunk_size:  750
# 63
# 64
# Token Count:  1299
# balanced_chunk_size:  649
# 64
# 65
# Token Count:  724
# balanced_chunk_size:  724
# 65
# 66
# Token Count:  736
# balanced_chunk_size:  736
# 66
# 67
# Token Count:  736
# balanced_chunk_size:  736
# 67
# 68
# Token Count:  736
# balanced_chunk_size:  736
# 68
# 69
# Token Count:  2022
# balanced_chunk_size:  674
# 69
# 73
# Token Count:  736
# balanced_chunk_size:  736
# 73
# 74
# Token Count:  736
# balanced_chunk_size:  736
# 74
# 75
# Token Count:  1284
# balanced_chunk_size:  642
# 75
# 76
# Token Count:  1516
# balanced_chunk_size:  758
# 76
# 79
# Token Count:  1358
# balanced_chunk_size:  679
# 79
# 80
# Token Count:  737
# balanced_chunk_size:  737
# 80
# 81
# Token Count:  825
# balanced_chunk_size:  825
# 81
# 82
# Token Count:  730
# balanced_chunk_size:  730
# 82
# 83
# Token Count:  733
# balanced_chunk_size:  733
# 83
# 84
# Token Count:  1774
# balanced_chunk_size:  887
# 84
# 87
# Token Count:  1199
# balanced_chunk_size:  599
# 87
# 88
# Token Count:  1291
# balanced_chunk_size:  645
# 88
# 89
# Token Count:  1760
# balanced_chunk_size:  880
# 89
# 92
# Token Count:  1716
# balanced_chunk_size:  858
# 92
# 95
# Token Count:  1271
# balanced_chunk_size:  635
# 95
# 96
# Token Count:  1598
# balanced_chunk_size:  799
# 96
# 99
# Token Count:  736
# balanced_chunk_size:  736
# 99
# 100
# Token Count:  1705
# balanced_chunk_size:  852
# 100
# 103
# Token Count:  1052
# balanced_chunk_size:  526
# 103
# 104
# Token Count:  2001
# balanced_chunk_size:  667
# 104
# 108
# Token Count:  724
# balanced_chunk_size:  724
# 108
# 109
# Token Count:  997
# balanced_chunk_size:  997
# 109
# 110
# Token Count:  1448
# balanced_chunk_size:  724
# 110
# 113
# Token Count:  1582
# balanced_chunk_size:  791
# 113
# 116
# Token Count:  1630
# balanced_chunk_size:  815
# 116
# 119
# Token Count:  1011
# balanced_chunk_size:  505
# 119
# 120
# Token Count:  736
# balanced_chunk_size:  736
# 120
# 121
# Token Count:  736
# balanced_chunk_size:  736
# 121
# 122
# Token Count:  781
# balanced_chunk_size:  781
# 122
# 123
# Token Count:  1133
# balanced_chunk_size:  566
# 123
# 124
# Token Count:  755
# balanced_chunk_size:  755
# 124
# 125
# Token Count:  1406
# balanced_chunk_size:  703
# 125
# 127
# Token Count:  2146
# balanced_chunk_size:  715
# 127
# 131
# Token Count:  732
# balanced_chunk_size:  732
# 131
# 132
# Token Count:  888
# balanced_chunk_size:  888
# 132
# 133
# Token Count:  940
# balanced_chunk_size:  940
# 133
# 134
# Token Count:  1185
# balanced_chunk_size:  592
# 134
# 135
# Token Count:  742
# balanced_chunk_size:  742
# 135
# 136
# Token Count:  882
# balanced_chunk_size:  882
# 136
# 137
# Token Count:  1304
# balanced_chunk_size:  652
# 137
# 138
# Token Count:  724
# balanced_chunk_size:  724
# 138
# 139
# Token Count:  1017
# balanced_chunk_size:  508
# 139
# 140
# Token Count:  990
# balanced_chunk_size:  990
# 140
# 141
# Token Count:  771
# balanced_chunk_size:  771
# 141
# 142
# Token Count:  813
# balanced_chunk_size:  813
# 142
# 143
# Token Count:  724
# balanced_chunk_size:  724
# 143
# 144
# Token Count:  744
# balanced_chunk_size:  744
# 144
# 145
# Token Count:  803
# balanced_chunk_size:  803
# 145
# 146
# Token Count:  1028
# balanced_chunk_size:  514
# 146
# 147
# Token Count:  724
# balanced_chunk_size:  724
# 147
# 148
# Token Count:  953
# balanced_chunk_size:  953
# 148
# 149
# Token Count:  980
# balanced_chunk_size:  980
# 149
# 150
# Token Count:  929
# balanced_chunk_size:  929
# 150
# 151
# Token Count:  841
# balanced_chunk_size:  841
# 151
# 152
# Token Count:  1876
# balanced_chunk_size:  938
# 152
# 155
# Token Count:  1697
# balanced_chunk_size:  848
# 155
# 158
# Token Count:  1398
# balanced_chunk_size:  699
# 158
# 160
# Token Count:  1459
# balanced_chunk_size:  729
# 160
# 163
# Token Count:  1910
# balanced_chunk_size:  955
# 163
# 166
# Token Count:  937
# balanced_chunk_size:  937
# 166
# 167
# Token Count:  1479
# balanced_chunk_size:  739
# 167
# 170
# Token Count:  1703
# balanced_chunk_size:  851
# 170
# 173
# Token Count:  1178
# balanced_chunk_size:  589
# 173
# 174
# Token Count:  1697
# balanced_chunk_size:  848
# 174
# 177
# Token Count:  798
# balanced_chunk_size:  798
# 177
# 178
# Token Count:  1364
# balanced_chunk_size:  682
# 178
# 179
# Token Count:  1403
# balanced_chunk_size:  701
# 179
# 181
# Token Count:  2031
# balanced_chunk_size:  677
# 181
# 185
# Token Count:  1753
# balanced_chunk_size:  876
# 185
# 188
# Token Count:  1086
# balanced_chunk_size:  543
# 188
# 189
# Token Count:  964
# balanced_chunk_size:  964
# 189
# 190
# Token Count:  1256
# balanced_chunk_size:  628
# 190
# 191
# Token Count:  1428
# balanced_chunk_size:  714
# 191
# 194
# Token Count:  911
# balanced_chunk_size:  911
# 194
# 195
# Token Count:  372
# balanced_chunk_size:  372
# 0
# 1
# Token Count:  1648
# balanced_chunk_size:  824
# 1
# 3
# Token Count:  1647
# balanced_chunk_size:  823
# 3
# 5
# Token Count:  501
# balanced_chunk_size:  501
# 5
# 6
# Token Count:  570
# balanced_chunk_size:  570
# 6
# 7
# Token Count:  529
# balanced_chunk_size:  529
# 7
# 8
# Token Count:  543
# balanced_chunk_size:  543
# 8
# 9
# Token Count:  519
# balanced_chunk_size:  519
# 9
# 10
# Token Count:  461
# balanced_chunk_size:  461
# 10
# 11
# Token Count:  873
# balanced_chunk_size:  873
# 11
# 12
# Token Count:  482
# balanced_chunk_size:  482
# 12
# 13
# Token Count:  526
# balanced_chunk_size:  526
# 13
# 14
# Token Count:  560
# balanced_chunk_size:  560
# 14
# 15
# Token Count:  845
# balanced_chunk_size:  845
# 15
# 16
# Token Count:  1119
# balanced_chunk_size:  559
# 16
# 19
# Token Count:  379
# balanced_chunk_size:  379
# 19
# 20
# Token Count:  413
# balanced_chunk_size:  413
# 20
# 21
# Token Count:  2412
# balanced_chunk_size:  804
# 21
# 25
# Token Count:  1935
# balanced_chunk_size:  967
# 25
# 28
# Token Count:  1374
# balanced_chunk_size:  687
# 28
# 31
# Token Count:  1449
# balanced_chunk_size:  724
# 31
# 34
# Token Count:  1475
# balanced_chunk_size:  737
# 34
# 37
# Token Count:  1270
# balanced_chunk_size:  635
# 37
# 40
# Token Count:  709
# balanced_chunk_size:  709
# 40
# 41
# Token Count:  1603
# balanced_chunk_size:  801
# 41
# 44
# Token Count:  711
# balanced_chunk_size:  711
# 44
# 45
# Token Count:  1101
# balanced_chunk_size:  550
# 45
# 48
# Token Count:  576
# balanced_chunk_size:  576
# 48
# 49
# Token Count:  467
# balanced_chunk_size:  467
# 49
# 50
# Token Count:  1399
# balanced_chunk_size:  699
# 50
# 53
# Token Count:  1047
# balanced_chunk_size:  523
# 53
# 56
# Token Count:  1699
# balanced_chunk_size:  849
# 56
# 59
# Token Count:  945
# balanced_chunk_size:  945
# 59
# 60
# Token Count:  1416
# balanced_chunk_size:  708
# 60
# 63
# Token Count:  1295
# balanced_chunk_size:  647
# 63
# 66
# Token Count:  1116
# balanced_chunk_size:  558
# 66
# 69
# Token Count:  511
# balanced_chunk_size:  511
# 69
# 70
# Token Count:  883
# balanced_chunk_size:  883
# 70
# 71
# Token Count:  983
# balanced_chunk_size:  983
# 71
# 72
# Token Count:  860
# balanced_chunk_size:  860
# 72
# 73
# Token Count:  1350
# balanced_chunk_size:  675
# 73
# 76
# Token Count:  915
# balanced_chunk_size:  915
# 76
# 77
# Token Count:  1457
# balanced_chunk_size:  728
# 77
# 80
# Token Count:  994
# balanced_chunk_size:  994
# 80
# 81
# Token Count:  1274
# balanced_chunk_size:  637
# 81
# 84
# Token Count:  1355
# balanced_chunk_size:  677
# 84
# 87
# Token Count:  1765
# balanced_chunk_size:  882
# 87
# 90
# Token Count:  1100
# balanced_chunk_size:  550
# 90
# 93
# Token Count:  1260
# balanced_chunk_size:  630
# 93
# 96
# Token Count:  922
# balanced_chunk_size:  922
# 96
# 97
# Token Count:  1200
# balanced_chunk_size:  600
# 97
# 100
# Token Count:  969
# balanced_chunk_size:  969
# 100
# 101
# Token Count:  986
# balanced_chunk_size:  986
# 101
# 102
# Token Count:  1617
# balanced_chunk_size:  808
# 102
# 105
# Token Count:  739
# balanced_chunk_size:  739
# 105
# 106
# Token Count:  985
# balanced_chunk_size:  985
# 106
# 107
# Token Count:  1232
# balanced_chunk_size:  616
# 107
# 110
# Token Count:  718
# balanced_chunk_size:  718
# 110
# 111
# Token Count:  1418
# balanced_chunk_size:  709
# 111
# 114
# Token Count:  2490
# balanced_chunk_size:  830
# 114
# 118
# Token Count:  1270
# balanced_chunk_size:  635
# 118
# 121
# Token Count:  1557
# balanced_chunk_size:  778
# 121
# 124
# Token Count:  1497
# balanced_chunk_size:  748
# 124
# 127
# Token Count:  1060
# balanced_chunk_size:  530
# 127
# 130
# Token Count:  1834
# balanced_chunk_size:  917
# 130
# 133
# Token Count:  1019
# balanced_chunk_size:  509
# 133
# 136
# Token Count:  1208
# balanced_chunk_size:  604
# 136
# 139
# Token Count:  778
# balanced_chunk_size:  778
# 139
# 140
# Token Count:  409
# balanced_chunk_size:  409
# 140
# 141
# Token Count:  1088
# balanced_chunk_size:  544
# 141
# 144
# Token Count:  1522
# balanced_chunk_size:  761
# 144
# 147
# Token Count:  1217
# balanced_chunk_size:  608
# 147
# 150
# Token Count:  409
# balanced_chunk_size:  409
# 150
# 151
# Token Count:  1875
# balanced_chunk_size:  937
# 151
# 154
# Token Count:  1459
# balanced_chunk_size:  729
# 154
# 157
# Token Count:  2293
# balanced_chunk_size:  764
# 157
# 161
# Token Count:  1153
# balanced_chunk_size:  576
# 161
# 164
# Token Count:  1235
# balanced_chunk_size:  617
# 164
# 167
# Token Count:  1144
# balanced_chunk_size:  572
# 167
# 170
# Token Count:  698
# balanced_chunk_size:  698
# 170
# 171
# Token Count:  574
# balanced_chunk_size:  574
# 171
# 172
# Token Count:  1396
# balanced_chunk_size:  698
# 172
# 175
# Token Count:  940
# balanced_chunk_size:  940
# 175
# 176
# Token Count:  1849
# balanced_chunk_size:  924
# 176
# 179
# Token Count:  651
# balanced_chunk_size:  651
# 179
# 180
# Token Count:  1201
# balanced_chunk_size:  600
# 180
# 183
# Token Count:  1485
# balanced_chunk_size:  742
# 183
# 186
# Token Count:  1003
# balanced_chunk_size:  501
# 186
# 189
# Token Count:  1304
# balanced_chunk_size:  652
# 189
# 192
# Token Count:  727
# balanced_chunk_size:  727
# 192
# 193
# Token Count:  690
# balanced_chunk_size:  690
# 193
# 194
# Token Count:  1612
# balanced_chunk_size:  806
# 194
# 197
# Token Count:  852
# balanced_chunk_size:  852
# 197
# 198
# Token Count:  1173
# balanced_chunk_size:  586
# 198
# 201
# Token Count:  1336
# balanced_chunk_size:  668
# 201
# 204
# Token Count:  975
# balanced_chunk_size:  975
# 204
# 205
# Token Count:  407
# balanced_chunk_size:  407
# 205
# 206
# Token Count:  1036
# balanced_chunk_size:  518
# 206
# 209
# Token Count:  1057
# balanced_chunk_size:  528
# 209
# 212
# Token Count:  914
# balanced_chunk_size:  914
# 212
# 213
# Token Count:  1014
# balanced_chunk_size:  507
# 213
# 216
# Token Count:  1021
# balanced_chunk_size:  510
# 216
# 219
# Token Count:  1123
# balanced_chunk_size:  561
# 219
# 222
# Token Count:  788
# balanced_chunk_size:  788
# 222
# 223
# Token Count:  1274
# balanced_chunk_size:  637
# 223
# 226
# Token Count:  1019
# balanced_chunk_size:  509
# 226
# 229
# Token Count:  1012
# balanced_chunk_size:  506
# 229
# 232
# Token Count:  946
# balanced_chunk_size:  946
# 232
# 233
# Token Count:  1078
# balanced_chunk_size:  539
# 233
# 236
# Token Count:  1047
# balanced_chunk_size:  523
# 236
# 239
# Token Count:  1115
# balanced_chunk_size:  557
# 239
# 242
# Token Count:  1053
# balanced_chunk_size:  526
# 242
# 245
# Token Count:  1003
# balanced_chunk_size:  501
# 245
# 248
# Token Count:  943
# balanced_chunk_size:  943
# 248
# 249
# Token Count:  1094
# balanced_chunk_size:  547
# 249
# 252
# Token Count:  767
# balanced_chunk_size:  767
# 252
# 253
# Token Count:  788
# balanced_chunk_size:  788
# 253
# 254
# Token Count:  771
# balanced_chunk_size:  771
# 254
# 255
# Token Count:  1247
# balanced_chunk_size:  623
# 255
# 258
# Token Count:  814
# balanced_chunk_size:  814
# 258
# 259
# Token Count:  866
# balanced_chunk_size:  866
# 259
# 260
# Token Count:  981
# balanced_chunk_size:  981
# 260
# 261
# Token Count:  774
# balanced_chunk_size:  774
# 261
# 262
# Token Count:  693
# balanced_chunk_size:  693
# 262
# 263
# Token Count:  678
# balanced_chunk_size:  678
# 263
# 264
# Token Count:  859
# balanced_chunk_size:  859
# 264
# 265
# Token Count:  795
# balanced_chunk_size:  795
# 265
# 266
# Token Count:  1121
# balanced_chunk_size:  560
# 266
# 269
# Token Count:  1472
# balanced_chunk_size:  736
# 269
# 272
# Token Count:  718
# balanced_chunk_size:  718
# 272
# 273
# Token Count:  1178
# balanced_chunk_size:  589
# 273
# 276
# Token Count:  1284
# balanced_chunk_size:  642
# 276
# 279
# Token Count:  1073
# balanced_chunk_size:  536
# 279
# 282
# Token Count:  903
# balanced_chunk_size:  903
# 282
# 283
# Token Count:  1134
# balanced_chunk_size:  567
# 283
# 286
# Token Count:  1320
# balanced_chunk_size:  660
# 286
# 289
# Token Count:  1466
# balanced_chunk_size:  733
# 289
# 292
# Token Count:  934
# balanced_chunk_size:  934
# 292
# 293
# Token Count:  1167
# balanced_chunk_size:  583
# 293
# 296
# Token Count:  877
# balanced_chunk_size:  877
# 296
# 297
# Token Count:  670
# balanced_chunk_size:  670
# 297
# 298
# Token Count:  1077
# balanced_chunk_size:  538
# 298
# 301
# Token Count:  1208
# balanced_chunk_size:  604
# 301
# 304
# Token Count:  1088
# balanced_chunk_size:  544
# 304
# 307
# Token Count:  1243
# balanced_chunk_size:  621
# 307
# 310
# Token Count:  724
# balanced_chunk_size:  724
# 310
# 311
# Token Count:  987
# balanced_chunk_size:  987
# 311
# 312
# Token Count:  393
# balanced_chunk_size:  393
# 0
# 1
# Token Count:  1000
# balanced_chunk_size:  1000
# 1
# 2
# Token Count:  567
# balanced_chunk_size:  567
# 2
# 3
# Token Count:  736
# balanced_chunk_size:  736
# 3
# 4
# Token Count:  608
# balanced_chunk_size:  608
# 4
# 5
# Token Count:  1050
# balanced_chunk_size:  525
# 5
# 7
# Token Count:  690
# balanced_chunk_size:  690
# 7
# 8
# Token Count:  694
# balanced_chunk_size:  694
# 8
# 9
# Token Count:  664
# balanced_chunk_size:  664
# 9
# 10
# Token Count:  509
# balanced_chunk_size:  509
# 10
# 11
# Token Count:  545
# balanced_chunk_size:  545
# 11
# 12
# Token Count:  435
# balanced_chunk_size:  435
# 12
# 13
# Token Count:  835
# balanced_chunk_size:  835
# 13
# 14
# Token Count:  474
# balanced_chunk_size:  474
# 14
# 15
# Token Count:  533
# balanced_chunk_size:  533
# 15
# 16
# Token Count:  597
# balanced_chunk_size:  597
# 16
# 17
# Token Count:  792
# balanced_chunk_size:  792
# 17
# 18
# Token Count:  1254
# balanced_chunk_size:  627
# 18
# 21
# Token Count:  780
# balanced_chunk_size:  780
# 21
# 22
# Token Count:  946
# balanced_chunk_size:  946
# 22
# 23
# Token Count:  635
# balanced_chunk_size:  635
# 23
# 24
# Token Count:  373
# balanced_chunk_size:  373
# 24
# 25
# Token Count:  460
# balanced_chunk_size:  460
# 25
# 26
# Token Count:  907
# balanced_chunk_size:  907
# 26
# 27
# Token Count:  810
# balanced_chunk_size:  810
# 27
# 28
# Token Count:  497
# balanced_chunk_size:  497
# 28
# 29
# Token Count:  728
# balanced_chunk_size:  728
# 29
# 30
# Token Count:  467
# balanced_chunk_size:  467
# 30
# 31
# Token Count:  487
# balanced_chunk_size:  487
# 31
# 32
# Token Count:  1068
# balanced_chunk_size:  534
# 32
# 35
# Token Count:  878
# balanced_chunk_size:  878
# 35
# 36
# Token Count:  857
# balanced_chunk_size:  857
# 36
# 37
# Token Count:  1405
# balanced_chunk_size:  702
# 37
# 40
# Token Count:  945
# balanced_chunk_size:  945
# 40
# 41
# Token Count:  1522
# balanced_chunk_size:  761
# 41
# 44
# Token Count:  506
# balanced_chunk_size:  506
# 44
# 45
# Token Count:  663
# balanced_chunk_size:  663
# 45
# 46
# Token Count:  1009
# balanced_chunk_size:  504
# 46
# 49
# Token Count:  893
# balanced_chunk_size:  893
# 49
# 50
# Token Count:  533
# balanced_chunk_size:  533
# 50
# 51
# Token Count:  947
# balanced_chunk_size:  947
# 51
# 52
# Token Count:  1526
# balanced_chunk_size:  763
# 52
# 55
# Token Count:  408
# balanced_chunk_size:  408
# 55
# 56
# Token Count:  604
# balanced_chunk_size:  604
# 56
# 57
# Token Count:  444
# balanced_chunk_size:  444
# 57
# 58
# Token Count:  455
# balanced_chunk_size:  455
# 58
# 59
# Token Count:  475
# balanced_chunk_size:  475
# 59
# 60
# Token Count:  1031
# balanced_chunk_size:  515
# 60
# 63
# Token Count:  1105
# balanced_chunk_size:  552
# 63
# 66
# Token Count:  630
# balanced_chunk_size:  630
# 66
# 67
# Token Count:  418
# balanced_chunk_size:  418
# 67
# 68
# Token Count:  707
# balanced_chunk_size:  707
# 68
# 69
# Token Count:  418
# balanced_chunk_size:  418
# 69
# 70
# Token Count:  438
# balanced_chunk_size:  438
# 70
# 71
# Token Count:  587
# balanced_chunk_size:  587
# 71
# 72
# Token Count:  393
# balanced_chunk_size:  393
# 72
# 73
# Token Count:  1328
# balanced_chunk_size:  664
# 73
# 76
# Token Count:  467
# balanced_chunk_size:  467
# 76
# 77
# Token Count:  393
# balanced_chunk_size:  393
# 77
# 78
# Token Count:  393
# balanced_chunk_size:  393
# 78
# 79
# Token Count:  2127
# balanced_chunk_size:  709
# 79
# 83
# Token Count:  430
# balanced_chunk_size:  430
# 83
# 84
# Token Count:  2265
# balanced_chunk_size:  755
# 84
# 88
# Token Count:  640
# balanced_chunk_size:  640
# 88
# 89
# Token Count:  903
# balanced_chunk_size:  903
# 89
# 90
# Token Count:  1467
# balanced_chunk_size:  733
# 90
# 93
# Token Count:  1299
# balanced_chunk_size:  649
# 93
# 96
# Token Count:  891
# balanced_chunk_size:  891
# 96
# 97
# Token Count:  759
# balanced_chunk_size:  759
# 97
# 98
# Token Count:  556
# balanced_chunk_size:  556
# 98
# 99
# Token Count:  896
# balanced_chunk_size:  896
# 99
# 100
# Token Count:  1340
# balanced_chunk_size:  670
# 100
# 103
# Token Count:  711
# balanced_chunk_size:  711
# 103
# 104
# Token Count:  431
# balanced_chunk_size:  431
# 0
# 1
# Token Count:  2438
# balanced_chunk_size:  812
# 1
# 4
# Token Count:  524
# balanced_chunk_size:  524
# 4
# 5
# Token Count:  645
# balanced_chunk_size:  645
# 5
# 6
# Token Count:  611
# balanced_chunk_size:  611
# 6
# 7
# Token Count:  603
# balanced_chunk_size:  603
# 7
# 8
# Token Count:  560
# balanced_chunk_size:  560
# 8
# 9
# Token Count:  663
# balanced_chunk_size:  663
# 9
# 10
# Token Count:  774
# balanced_chunk_size:  774
# 10
# 11
# Token Count:  588
# balanced_chunk_size:  588
# 11
# 12
# Token Count:  1825
# balanced_chunk_size:  912
# 12
# 14

# %%
for i, doc in enumerate(all_documents, start=1):
    if i > 2:
        break
    print(f"Document {i}")
    print("Page Content:", doc.page_content)
    print("Metadata: ", doc.metadata)
print("Wtf")
